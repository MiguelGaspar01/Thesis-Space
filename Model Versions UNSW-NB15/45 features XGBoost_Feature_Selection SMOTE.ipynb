# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
#pip install git+https://github.com/KindXiaoming/pykan.git
import sys

# %%
import random
import numpy as np
import torch
import os

def set_global_seed(seed=42):
    """Set seed for reproducibility across NumPy, PyTorch, and OS operations."""
    
    # Set Python random seed
    random.seed(seed)
    
    # Set NumPy random seed
    np.random.seed(seed)
    
    # Set PyTorch random seed
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # If using CUDA
    
    # Ensure deterministic behavior in PyTorch (optional, can slow training)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    # Set environment variable for other libraries
    os.environ["PYTHONHASHSEED"] = str(seed)

# Set global seed
set_global_seed(42)

# %%
test_data_X = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess\processed_test_data_X_data.csv")
train_data_X = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess\processed_train_data_X_data.csv")
test_labels_encoded = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess\processed_test_data_y_data.csv")
train_labels_encoded = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess\processed_train_data_y_data.csv")

# %%
train_data_y_binary = train_labels_encoded["label"]
test_data_y_binary = test_labels_encoded["label"]

# %%
test_data_y = test_labels_encoded["attack_cat"]

# %%
train_data_y = train_labels_encoded["attack_cat"]

# %%
from imblearn.combine import SMOTEENN
from collections import Counter
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy="not majority", random_state=42, k_neighbors=5)

train_data_X, train_data_y = smote.fit_resample(train_data_X, train_data_y)

# %%
train_data_y.value_counts()
# Out:
# attack_cat
# 6    56000
# 1    56000
# 0    56000
# 4    56000
# 8    56000
# 7    56000
# 3    56000
# 2    56000
# 9    56000
# 5    56000
# Name: count, dtype: int64

# %% [markdown]
# # Modelling

# %%
train_data_X.shape
# Out:
# (560000, 56)

# %%
import xgboost as xgb
import numpy as np

# Train an XGBoost model
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)
xgb_model.fit(train_data_X, train_data_y)

# Get feature importances
feature_importances = xgb_model.feature_importances_
top_40_features = np.argsort(feature_importances)[-45:]

# Print selected features
selected_features = train_data_X.columns[top_40_features]
print("Selected Features:", selected_features.tolist())
# Out:
# c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:22:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Selected Features: ['remainder__is_ftp_login', 'remainder__sjit', 'remainder__ct_dst_ltm', 'remainder__djit', 'remainder__dpkts', 'encoder__state_ECO', 'remainder__sload', 'remainder__trans_depth', 'remainder__ct_src_ltm', 'remainder__sinpkt', 'remainder__ct_dst_sport_ltm', 'remainder__dload', 'encoder__service_smtp', 'remainder__dinpkt', 'remainder__rate', 'remainder__dur', 'remainder__ct_srv_src', 'encoder__proto_sctp', 'remainder__ct_src_dport_ltm', 'remainder__synack', 'encoder__proto_arp', 'remainder__dloss', 'encoder__state_REQ', 'remainder__response_body_len', 'remainder__spkts', 'encoder__state_INT', 'remainder__ct_srv_dst', 'encoder__proto_unas', 'remainder__smean', 'remainder__ct_flw_http_mthd', 'remainder__ct_dst_src_ltm', 'encoder__state_CON', 'remainder__dmean', 'encoder__proto_ospf', 'remainder__sloss', 'remainder__dbytes', 'encoder__proto_tcp', 'remainder__dttl', 'remainder__sbytes', 'encoder__service_ftp-data', 'encoder__proto_udp', 'remainder__ct_state_ttl', 'remainder__sttl', 'encoder__service_http', 'encoder__service_dns']

# %% [markdown]
# ## Modelling EfficentKan

# %%
#train_X_tensor = torch.tensor(train_data_X[features].values, dtype=torch.float32).squeeze()
#test_X_tensor = torch.tensor(test_data_X[features].values, dtype=torch.float32).squeeze() #changed to have all features

train_X_tensor = torch.tensor(train_data_X[selected_features].values, dtype=torch.float32).squeeze()
test_X_tensor = torch.tensor(test_data_X[selected_features].values, dtype=torch.float32).squeeze()

train_Y_tensor = torch.tensor(train_data_y.values, dtype=torch.long).squeeze()

test_Y_tensor = torch.tensor(test_data_y.values, dtype=torch.long).squeeze()
#a dictionary with the 4 datasets

# %%
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
# Create TensorDatasets
train_dataset = TensorDataset(train_X_tensor, train_Y_tensor)
test_dataset = TensorDataset(test_X_tensor, test_Y_tensor)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# ## Modelling with efficient Kan

# %%
from efficient_kan import KAN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from tqdm import tqdm

# Define model
model = KAN([40, 64, 10])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define optimizer
optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
# Define learning rate scheduler
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.8)

# Define loss
criterion = nn.CrossEntropyLoss()

# %%
model.grid_size, model.spline_order
# Out:
# (5, 3)

# %%
from sklearn.model_selection import KFold

# %%
model = KAN([40, 20,10, 5,10],grid_size = 6, spline_order = 3, scale_noise=0.2, scale_base=0.2, scale_spline=0.2) #best

# %%
from sklearn.metrics import f1_score
loss_over_train = []
loss_over_test = []
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    correct = 0  # For accuracy tracking
    total = 0
    epoch_loss = 0
    
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        epoch_loss += loss.item()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


        
        # Calculate accuracy
        _, predicted = torch.max(pred, 1)
        correct += (predicted == y).sum().item()
        total += y.size(0)
        
    mean_loss = epoch_loss / len(dataloader) 
    loss_over_train.append(mean_loss)

    accuracy = correct / total * 100
    print(f"Train Accuracy: {accuracy:.4f}%")

def test_loop(dataloader, model, loss_fn):
    model.eval()  # Set the model to evaluation mode
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            
            # Collect all predictions and true labels for F1-score calculation
            all_preds.extend(pred.argmax(1).cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    mean_loss = test_loss / num_batches  # Divide by the number of batches
    loss_over_test.append(mean_loss)

    test_loss /= num_batches
    correct /= size
    f1 = f1_score(all_labels, all_preds, average='weighted') * 100  # Weighted F1-score to handle class imbalance
    f1_macro = f1_score(all_labels, all_preds, average='macro') * 100  # Macro F1-score to handle class imbalance

    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f}, F1-score: {f1:.2f}%, Macro_F1-Score: {f1_macro: .2f}%  \n")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, ConcatDataset
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score

# Number of folds
k_folds = 5
epochs = 200  # Number of training epochs per fold
batch_size = 32  # Adjust batch size as needed

# Define K-Fold cross-validator
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# Define loss function and learning parameters
loss_fn = nn.CrossEntropyLoss()
learning_rate = 0.0001
weight_decay = 1e-4

# Combine datasets (Only Train Data)
dataset = train_dataset  # Use only training dataset

# Store results across folds
fold_accuracies = []
fold_f1_scores = []
fold_f1_macro_scores = []
fold_losses = []

# K-Fold cross-validation loop
for fold, (train_ids, val_ids) in enumerate(kfold.split(dataset)):
    print(f"\nFold {fold + 1}/{k_folds}\n" + "-" * 30)
    print("initializing model...")
    model = KAN([45, 20,10, 5,10],grid_size = 6, spline_order = 3, scale_noise=0.2, scale_base=0.2, scale_spline=0.2) #best
    # Create data subsets for the current fold
    train_subset = Subset(dataset, train_ids)
    val_subset = Subset(dataset, val_ids)

    # Create data loaders for the current fold
    train_dataloader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    # Re-initialize model and optimizer for each fold
     # Replace with your model class
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    # Training function
    def train_loop(dataloader, model, loss_fn, optimizer):
        model.train()
        correct, total = 0, 0
        epoch_loss = 0

        for batch, (X, y) in enumerate(dataloader):
            pred = model(X)
            loss = loss_fn(pred, y)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            epoch_loss += loss.item()

            _, predicted = torch.max(pred, 1)
            correct += (predicted == y).sum().item()
            total += y.size(0)

        return correct / total * 100, epoch_loss / len(dataloader)

    # Validation function
    def val_loop(dataloader, model, loss_fn):
        model.eval()
        correct, total = 0, 0
        val_loss = 0
        all_preds, all_labels = [], []

        with torch.no_grad():
            for X, y in dataloader:
                pred = model(X)
                val_loss += loss_fn(pred, y).item()
                correct += (pred.argmax(1) == y).type(torch.float).sum().item()

                all_preds.extend(pred.argmax(1).cpu().numpy())
                all_labels.extend(y.cpu().numpy())

        accuracy = correct / len(dataloader.dataset) * 100
        f1 = f1_score(all_labels, all_preds, average='weighted') * 100
        f1_macro = f1_score(all_labels, all_preds, average='macro') * 100
        mean_loss = val_loss / len(dataloader)

        return accuracy, f1, f1_macro, mean_loss

    # Train and validate for this fold
    for epoch in range(epochs):
        train_acc, train_loss = train_loop(train_dataloader, model, loss_fn, optimizer)
        val_acc, f1, f1_macro, val_loss = val_loop(val_dataloader, model, loss_fn)

        print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}%, Val Acc={val_acc:.2f}%, F1={f1:.2f}%, Macro F1={f1_macro:.2f}%")

    # Store fold results
    fold_accuracies.append(val_acc)
    fold_f1_scores.append(f1)
    fold_f1_macro_scores.append(f1_macro)
    fold_losses.append(val_loss)

# Print final results
print("\nCross-Validation Results:")
print(f"Avg Validation Accuracy: {sum(fold_accuracies) / k_folds:.2f}%")
print(f"Avg Weighted F1-score: {sum(fold_f1_scores) / k_folds:.2f}%")
print(f"Avg Macro F1-score: {sum(fold_f1_macro_scores) / k_folds:.2f}%")
print(f"Avg Validation Loss: {sum(fold_losses) / k_folds:.6f}")
# Out:
# Fold 1/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=54.40%, Val Acc=63.44%, F1=62.37%, Macro F1=62.34%
# Epoch 2: Train Acc=65.64%, Val Acc=66.73%, F1=66.96%, Macro F1=66.95%
# Epoch 3: Train Acc=67.28%, Val Acc=67.77%, F1=67.83%, Macro F1=67.81%
# Epoch 4: Train Acc=68.33%, Val Acc=68.90%, F1=68.24%, Macro F1=68.21%
# Epoch 5: Train Acc=68.98%, Val Acc=68.99%, F1=68.43%, Macro F1=68.41%
# Epoch 6: Train Acc=69.46%, Val Acc=69.60%, F1=69.98%, Macro F1=69.97%
# Epoch 7: Train Acc=69.86%, Val Acc=70.02%, F1=70.41%, Macro F1=70.40%
# Epoch 8: Train Acc=70.11%, Val Acc=70.46%, F1=70.74%, Macro F1=70.73%
# Epoch 9: Train Acc=70.32%, Val Acc=70.38%, F1=70.72%, Macro F1=70.71%
# Epoch 10: Train Acc=70.59%, Val Acc=70.57%, F1=69.89%, Macro F1=69.86%
# Epoch 11: Train Acc=70.81%, Val Acc=70.74%, F1=71.39%, Macro F1=71.39%
# Epoch 12: Train Acc=70.94%, Val Acc=70.92%, F1=71.03%, Macro F1=71.02%
# Epoch 13: Train Acc=71.10%, Val Acc=71.07%, F1=71.03%, Macro F1=71.02%
# Epoch 14: Train Acc=71.21%, Val Acc=71.25%, F1=71.87%, Macro F1=71.86%
# Epoch 15: Train Acc=71.37%, Val Acc=71.22%, F1=71.95%, Macro F1=71.95%
# Epoch 16: Train Acc=71.45%, Val Acc=71.60%, F1=71.99%, Macro F1=71.99%
# Epoch 17: Train Acc=71.60%, Val Acc=71.44%, F1=71.28%, Macro F1=71.26%
# Epoch 18: Train Acc=71.62%, Val Acc=71.38%, F1=71.68%, Macro F1=71.67%
# Epoch 19: Train Acc=71.75%, Val Acc=71.53%, F1=71.30%, Macro F1=71.28%
# Epoch 20: Train Acc=71.77%, Val Acc=71.71%, F1=72.32%, Macro F1=72.32%
# Epoch 21: Train Acc=71.82%, Val Acc=71.39%, F1=72.09%, Macro F1=72.09%
# Epoch 22: Train Acc=71.89%, Val Acc=71.89%, F1=72.26%, Macro F1=72.25%
# Epoch 23: Train Acc=71.93%, Val Acc=71.53%, F1=71.05%, Macro F1=71.03%
# Epoch 24: Train Acc=71.98%, Val Acc=71.90%, F1=72.54%, Macro F1=72.53%
# Epoch 25: Train Acc=72.01%, Val Acc=71.77%, F1=72.48%, Macro F1=72.47%
# Epoch 26: Train Acc=72.12%, Val Acc=71.91%, F1=72.61%, Macro F1=72.61%
# Epoch 27: Train Acc=72.09%, Val Acc=72.03%, F1=72.52%, Macro F1=72.52%
# Epoch 28: Train Acc=72.11%, Val Acc=71.97%, F1=72.70%, Macro F1=72.70%
# Epoch 29: Train Acc=72.14%, Val Acc=71.64%, F1=71.48%, Macro F1=71.46%
# Epoch 30: Train Acc=72.22%, Val Acc=71.92%, F1=71.93%, Macro F1=71.92%
# Epoch 31: Train Acc=72.18%, Val Acc=71.77%, F1=72.53%, Macro F1=72.53%
# Epoch 32: Train Acc=72.25%, Val Acc=72.09%, F1=72.71%, Macro F1=72.71%
# Epoch 33: Train Acc=72.24%, Val Acc=72.02%, F1=72.74%, Macro F1=72.74%
# Epoch 34: Train Acc=72.28%, Val Acc=71.88%, F1=72.58%, Macro F1=72.58%
# Epoch 35: Train Acc=72.32%, Val Acc=72.18%, F1=72.83%, Macro F1=72.83%
# Epoch 36: Train Acc=72.30%, Val Acc=71.83%, F1=72.47%, Macro F1=72.47%
# Epoch 37: Train Acc=72.36%, Val Acc=72.24%, F1=72.38%, Macro F1=72.37%
# Epoch 38: Train Acc=72.43%, Val Acc=72.23%, F1=72.76%, Macro F1=72.75%
# Epoch 39: Train Acc=72.41%, Val Acc=72.16%, F1=72.91%, Macro F1=72.91%
# Epoch 40: Train Acc=72.47%, Val Acc=72.15%, F1=72.84%, Macro F1=72.84%
# Epoch 41: Train Acc=72.39%, Val Acc=72.15%, F1=72.28%, Macro F1=72.27%
# Epoch 42: Train Acc=72.47%, Val Acc=72.38%, F1=72.58%, Macro F1=72.56%
# Epoch 43: Train Acc=72.50%, Val Acc=72.54%, F1=72.95%, Macro F1=72.94%
# Epoch 44: Train Acc=72.45%, Val Acc=72.27%, F1=72.42%, Macro F1=72.41%
# Epoch 45: Train Acc=72.49%, Val Acc=72.21%, F1=72.95%, Macro F1=72.95%
# Epoch 46: Train Acc=72.49%, Val Acc=72.17%, F1=72.21%, Macro F1=72.20%
# Epoch 47: Train Acc=72.56%, Val Acc=72.13%, F1=72.94%, Macro F1=72.94%
# Epoch 48: Train Acc=72.56%, Val Acc=72.31%, F1=72.24%, Macro F1=72.22%
# Epoch 49: Train Acc=72.57%, Val Acc=72.39%, F1=72.53%, Macro F1=72.52%
# Epoch 50: Train Acc=72.57%, Val Acc=72.22%, F1=72.74%, Macro F1=72.74%
# Epoch 51: Train Acc=72.55%, Val Acc=72.21%, F1=72.81%, Macro F1=72.81%
# Epoch 52: Train Acc=72.56%, Val Acc=72.26%, F1=72.13%, Macro F1=72.11%
# Epoch 53: Train Acc=72.61%, Val Acc=72.24%, F1=72.97%, Macro F1=72.97%
# Epoch 54: Train Acc=72.64%, Val Acc=72.33%, F1=73.05%, Macro F1=73.04%
# Epoch 55: Train Acc=72.64%, Val Acc=72.45%, F1=72.40%, Macro F1=72.38%
# Epoch 56: Train Acc=72.66%, Val Acc=72.19%, F1=72.93%, Macro F1=72.93%
# Epoch 57: Train Acc=72.60%, Val Acc=72.26%, F1=72.78%, Macro F1=72.77%
# Epoch 58: Train Acc=72.65%, Val Acc=72.46%, F1=72.77%, Macro F1=72.76%
# Epoch 59: Train Acc=72.67%, Val Acc=72.34%, F1=72.64%, Macro F1=72.63%
# Epoch 60: Train Acc=72.70%, Val Acc=72.24%, F1=73.03%, Macro F1=73.03%
# Epoch 61: Train Acc=72.66%, Val Acc=72.36%, F1=72.56%, Macro F1=72.56%
# Epoch 62: Train Acc=72.68%, Val Acc=72.49%, F1=72.40%, Macro F1=72.38%
# Epoch 63: Train Acc=72.71%, Val Acc=72.50%, F1=73.15%, Macro F1=73.14%
# Epoch 64: Train Acc=72.74%, Val Acc=72.52%, F1=73.16%, Macro F1=73.15%
# Epoch 65: Train Acc=72.72%, Val Acc=72.39%, F1=73.09%, Macro F1=73.09%
# Epoch 66: Train Acc=72.76%, Val Acc=72.47%, F1=73.11%, Macro F1=73.11%
# Epoch 67: Train Acc=72.77%, Val Acc=72.53%, F1=73.05%, Macro F1=73.05%
# Epoch 68: Train Acc=72.76%, Val Acc=72.17%, F1=72.76%, Macro F1=72.75%
# Epoch 69: Train Acc=72.74%, Val Acc=72.63%, F1=73.40%, Macro F1=73.40%
# Epoch 70: Train Acc=72.79%, Val Acc=72.44%, F1=73.19%, Macro F1=73.19%
# Epoch 71: Train Acc=72.77%, Val Acc=72.56%, F1=73.31%, Macro F1=73.31%
# Epoch 72: Train Acc=72.81%, Val Acc=72.50%, F1=72.99%, Macro F1=72.99%
# Epoch 73: Train Acc=72.83%, Val Acc=72.88%, F1=73.51%, Macro F1=73.51%
# Epoch 74: Train Acc=72.84%, Val Acc=72.42%, F1=73.14%, Macro F1=73.14%
# Epoch 75: Train Acc=72.82%, Val Acc=72.41%, F1=73.16%, Macro F1=73.16%
# Epoch 76: Train Acc=72.86%, Val Acc=72.71%, F1=73.21%, Macro F1=73.20%
# Epoch 77: Train Acc=72.88%, Val Acc=72.70%, F1=73.38%, Macro F1=73.38%
# Epoch 78: Train Acc=72.87%, Val Acc=72.23%, F1=72.80%, Macro F1=72.80%
# Epoch 79: Train Acc=72.89%, Val Acc=72.51%, F1=73.28%, Macro F1=73.29%
# Epoch 80: Train Acc=72.94%, Val Acc=72.56%, F1=73.21%, Macro F1=73.21%
# Epoch 81: Train Acc=72.87%, Val Acc=72.47%, F1=73.18%, Macro F1=73.18%
# Epoch 82: Train Acc=72.90%, Val Acc=72.58%, F1=72.45%, Macro F1=72.44%
# Epoch 83: Train Acc=72.89%, Val Acc=72.52%, F1=73.21%, Macro F1=73.22%
# Epoch 84: Train Acc=72.92%, Val Acc=72.33%, F1=72.63%, Macro F1=72.63%
# Epoch 85: Train Acc=72.91%, Val Acc=72.63%, F1=73.41%, Macro F1=73.41%
# Epoch 86: Train Acc=72.96%, Val Acc=72.71%, F1=73.24%, Macro F1=73.23%
# Epoch 87: Train Acc=72.96%, Val Acc=72.76%, F1=73.47%, Macro F1=73.47%
# Epoch 88: Train Acc=72.94%, Val Acc=72.93%, F1=73.50%, Macro F1=73.50%
# Epoch 89: Train Acc=72.97%, Val Acc=72.67%, F1=72.75%, Macro F1=72.73%
# Epoch 90: Train Acc=72.99%, Val Acc=72.86%, F1=73.36%, Macro F1=73.35%
# Epoch 91: Train Acc=72.98%, Val Acc=72.68%, F1=73.12%, Macro F1=73.11%
# Epoch 92: Train Acc=72.96%, Val Acc=72.68%, F1=73.26%, Macro F1=73.26%
# Epoch 93: Train Acc=73.00%, Val Acc=72.56%, F1=73.36%, Macro F1=73.36%
# Epoch 94: Train Acc=73.03%, Val Acc=72.83%, F1=73.57%, Macro F1=73.57%
# Epoch 95: Train Acc=73.01%, Val Acc=72.88%, F1=73.59%, Macro F1=73.58%
# Epoch 96: Train Acc=73.03%, Val Acc=72.60%, F1=72.91%, Macro F1=72.91%
# Epoch 97: Train Acc=73.00%, Val Acc=72.85%, F1=73.56%, Macro F1=73.56%
# Epoch 98: Train Acc=73.02%, Val Acc=72.73%, F1=72.70%, Macro F1=72.69%
# Epoch 99: Train Acc=73.05%, Val Acc=72.38%, F1=73.19%, Macro F1=73.20%
# Epoch 100: Train Acc=73.02%, Val Acc=72.44%, F1=73.05%, Macro F1=73.04%
# Epoch 101: Train Acc=73.07%, Val Acc=72.83%, F1=73.34%, Macro F1=73.33%
# Epoch 102: Train Acc=73.03%, Val Acc=72.86%, F1=73.32%, Macro F1=73.32%
# Epoch 103: Train Acc=73.04%, Val Acc=72.86%, F1=73.40%, Macro F1=73.40%
# Epoch 104: Train Acc=73.10%, Val Acc=72.82%, F1=73.47%, Macro F1=73.47%
# Epoch 105: Train Acc=73.07%, Val Acc=72.92%, F1=73.46%, Macro F1=73.46%
# Epoch 106: Train Acc=73.09%, Val Acc=72.91%, F1=73.58%, Macro F1=73.58%
# Epoch 107: Train Acc=73.09%, Val Acc=72.88%, F1=73.54%, Macro F1=73.54%
# Epoch 108: Train Acc=73.09%, Val Acc=72.75%, F1=73.23%, Macro F1=73.23%
# Epoch 109: Train Acc=73.05%, Val Acc=72.94%, F1=73.63%, Macro F1=73.63%
# Epoch 110: Train Acc=73.05%, Val Acc=72.95%, F1=73.55%, Macro F1=73.55%
# Epoch 111: Train Acc=73.09%, Val Acc=72.89%, F1=73.42%, Macro F1=73.41%
# Epoch 112: Train Acc=73.16%, Val Acc=72.71%, F1=73.37%, Macro F1=73.36%
# Epoch 113: Train Acc=73.13%, Val Acc=72.89%, F1=73.63%, Macro F1=73.63%
# Epoch 114: Train Acc=73.12%, Val Acc=72.96%, F1=73.44%, Macro F1=73.44%
# Epoch 115: Train Acc=73.10%, Val Acc=72.93%, F1=73.48%, Macro F1=73.47%
# Epoch 116: Train Acc=73.17%, Val Acc=72.77%, F1=73.36%, Macro F1=73.35%
# Epoch 117: Train Acc=73.15%, Val Acc=72.74%, F1=73.44%, Macro F1=73.44%
# Epoch 118: Train Acc=73.15%, Val Acc=73.05%, F1=73.66%, Macro F1=73.66%
# Epoch 119: Train Acc=73.19%, Val Acc=72.82%, F1=73.13%, Macro F1=73.11%
# Epoch 120: Train Acc=73.15%, Val Acc=72.88%, F1=73.39%, Macro F1=73.38%
# Epoch 121: Train Acc=73.15%, Val Acc=72.93%, F1=73.41%, Macro F1=73.41%
# Epoch 122: Train Acc=73.14%, Val Acc=72.92%, F1=73.35%, Macro F1=73.34%
# Epoch 123: Train Acc=73.18%, Val Acc=72.94%, F1=73.52%, Macro F1=73.52%
# Epoch 124: Train Acc=73.20%, Val Acc=72.81%, F1=73.36%, Macro F1=73.36%
# Epoch 125: Train Acc=73.22%, Val Acc=72.78%, F1=73.24%, Macro F1=73.23%
# Epoch 126: Train Acc=73.15%, Val Acc=72.93%, F1=73.42%, Macro F1=73.42%
# Epoch 127: Train Acc=73.22%, Val Acc=73.08%, F1=73.70%, Macro F1=73.70%
# Epoch 128: Train Acc=73.18%, Val Acc=72.82%, F1=73.51%, Macro F1=73.52%
# Epoch 129: Train Acc=73.17%, Val Acc=72.71%, F1=73.46%, Macro F1=73.46%
# Epoch 130: Train Acc=73.26%, Val Acc=72.75%, F1=73.54%, Macro F1=73.54%
# Epoch 131: Train Acc=73.21%, Val Acc=72.77%, F1=73.61%, Macro F1=73.61%
# Epoch 132: Train Acc=73.21%, Val Acc=72.71%, F1=73.43%, Macro F1=73.43%
# Epoch 133: Train Acc=73.19%, Val Acc=72.95%, F1=73.70%, Macro F1=73.70%
# Epoch 134: Train Acc=73.19%, Val Acc=72.98%, F1=73.63%, Macro F1=73.63%
# Epoch 135: Train Acc=73.22%, Val Acc=73.08%, F1=73.81%, Macro F1=73.81%
# Epoch 136: Train Acc=73.24%, Val Acc=72.82%, F1=73.40%, Macro F1=73.39%
# Epoch 137: Train Acc=73.23%, Val Acc=72.95%, F1=73.52%, Macro F1=73.52%
# Epoch 138: Train Acc=73.21%, Val Acc=72.69%, F1=73.38%, Macro F1=73.38%
# Epoch 139: Train Acc=73.23%, Val Acc=73.06%, F1=73.64%, Macro F1=73.63%
# Epoch 140: Train Acc=73.23%, Val Acc=72.71%, F1=73.09%, Macro F1=73.08%
# Epoch 141: Train Acc=73.25%, Val Acc=72.93%, F1=73.56%, Macro F1=73.56%
# Epoch 142: Train Acc=73.27%, Val Acc=72.92%, F1=73.56%, Macro F1=73.56%
# Epoch 143: Train Acc=73.26%, Val Acc=72.89%, F1=73.63%, Macro F1=73.63%
# Epoch 144: Train Acc=73.26%, Val Acc=72.97%, F1=73.50%, Macro F1=73.50%
# Epoch 145: Train Acc=73.25%, Val Acc=73.04%, F1=73.68%, Macro F1=73.68%
# Epoch 146: Train Acc=73.27%, Val Acc=73.04%, F1=73.49%, Macro F1=73.49%
# Epoch 147: Train Acc=73.29%, Val Acc=72.90%, F1=73.58%, Macro F1=73.57%
# Epoch 148: Train Acc=73.26%, Val Acc=73.22%, F1=73.89%, Macro F1=73.89%
# Epoch 149: Train Acc=73.26%, Val Acc=72.87%, F1=73.59%, Macro F1=73.59%
# Epoch 150: Train Acc=73.31%, Val Acc=72.86%, F1=73.27%, Macro F1=73.26%
# Epoch 151: Train Acc=73.31%, Val Acc=72.90%, F1=73.59%, Macro F1=73.59%
# Epoch 152: Train Acc=73.31%, Val Acc=73.06%, F1=73.61%, Macro F1=73.61%
# Epoch 153: Train Acc=73.31%, Val Acc=72.90%, F1=73.61%, Macro F1=73.60%
# Epoch 154: Train Acc=73.35%, Val Acc=72.99%, F1=73.63%, Macro F1=73.63%
# Epoch 155: Train Acc=73.32%, Val Acc=72.94%, F1=73.46%, Macro F1=73.45%
# Epoch 156: Train Acc=73.34%, Val Acc=73.00%, F1=73.53%, Macro F1=73.52%
# Epoch 157: Train Acc=73.30%, Val Acc=72.90%, F1=73.48%, Macro F1=73.47%
# Epoch 158: Train Acc=73.33%, Val Acc=73.11%, F1=73.82%, Macro F1=73.81%
# Epoch 159: Train Acc=73.36%, Val Acc=72.66%, F1=73.08%, Macro F1=73.08%
# Epoch 160: Train Acc=73.34%, Val Acc=73.12%, F1=73.60%, Macro F1=73.60%
# Epoch 161: Train Acc=73.33%, Val Acc=73.09%, F1=73.52%, Macro F1=73.51%
# Epoch 162: Train Acc=73.38%, Val Acc=73.12%, F1=73.52%, Macro F1=73.51%
# Epoch 163: Train Acc=73.37%, Val Acc=73.24%, F1=73.94%, Macro F1=73.93%
# Epoch 164: Train Acc=73.38%, Val Acc=72.99%, F1=73.29%, Macro F1=73.28%
# Epoch 165: Train Acc=73.37%, Val Acc=72.99%, F1=73.73%, Macro F1=73.73%
# Epoch 166: Train Acc=73.35%, Val Acc=73.04%, F1=73.67%, Macro F1=73.66%
# Epoch 167: Train Acc=73.38%, Val Acc=72.69%, F1=73.15%, Macro F1=73.14%
# Epoch 168: Train Acc=73.36%, Val Acc=72.91%, F1=73.63%, Macro F1=73.63%
# Epoch 169: Train Acc=73.35%, Val Acc=73.21%, F1=73.77%, Macro F1=73.76%
# Epoch 170: Train Acc=73.33%, Val Acc=72.85%, F1=73.01%, Macro F1=73.00%
# Epoch 171: Train Acc=73.37%, Val Acc=73.12%, F1=73.84%, Macro F1=73.85%
# Epoch 172: Train Acc=73.40%, Val Acc=73.04%, F1=73.49%, Macro F1=73.49%
# Epoch 173: Train Acc=73.37%, Val Acc=73.07%, F1=73.63%, Macro F1=73.63%
# Epoch 174: Train Acc=73.39%, Val Acc=73.16%, F1=73.71%, Macro F1=73.70%
# Epoch 175: Train Acc=73.44%, Val Acc=73.13%, F1=73.91%, Macro F1=73.90%
# Epoch 176: Train Acc=73.41%, Val Acc=73.04%, F1=73.71%, Macro F1=73.70%
# Epoch 177: Train Acc=73.42%, Val Acc=73.10%, F1=73.87%, Macro F1=73.87%
# Epoch 178: Train Acc=73.37%, Val Acc=72.92%, F1=73.52%, Macro F1=73.51%
# Epoch 179: Train Acc=73.43%, Val Acc=73.06%, F1=73.66%, Macro F1=73.65%
# Epoch 180: Train Acc=73.41%, Val Acc=73.14%, F1=73.82%, Macro F1=73.82%
# Epoch 181: Train Acc=73.42%, Val Acc=72.95%, F1=73.71%, Macro F1=73.71%
# Epoch 182: Train Acc=73.42%, Val Acc=73.05%, F1=73.71%, Macro F1=73.71%
# Epoch 183: Train Acc=73.41%, Val Acc=73.34%, F1=74.00%, Macro F1=73.99%
# Epoch 184: Train Acc=73.46%, Val Acc=73.24%, F1=73.96%, Macro F1=73.96%
# Epoch 185: Train Acc=73.43%, Val Acc=73.19%, F1=73.76%, Macro F1=73.76%
# Epoch 186: Train Acc=73.42%, Val Acc=72.76%, F1=73.54%, Macro F1=73.54%
# Epoch 187: Train Acc=73.46%, Val Acc=73.08%, F1=73.40%, Macro F1=73.38%
# Epoch 188: Train Acc=73.47%, Val Acc=73.09%, F1=73.81%, Macro F1=73.81%
# Epoch 189: Train Acc=73.45%, Val Acc=73.17%, F1=73.83%, Macro F1=73.82%
# Epoch 190: Train Acc=73.42%, Val Acc=73.03%, F1=73.82%, Macro F1=73.82%
# Epoch 191: Train Acc=73.44%, Val Acc=73.02%, F1=73.64%, Macro F1=73.64%
# Epoch 192: Train Acc=73.47%, Val Acc=73.27%, F1=73.75%, Macro F1=73.74%
# Epoch 193: Train Acc=73.49%, Val Acc=73.02%, F1=73.61%, Macro F1=73.60%
# Epoch 194: Train Acc=73.48%, Val Acc=72.96%, F1=73.59%, Macro F1=73.58%
# Epoch 195: Train Acc=73.48%, Val Acc=73.15%, F1=73.71%, Macro F1=73.71%
# Epoch 196: Train Acc=73.44%, Val Acc=73.03%, F1=73.47%, Macro F1=73.47%
# Epoch 197: Train Acc=73.50%, Val Acc=73.29%, F1=73.79%, Macro F1=73.78%
# Epoch 198: Train Acc=73.48%, Val Acc=73.01%, F1=73.75%, Macro F1=73.75%
# Epoch 199: Train Acc=73.51%, Val Acc=73.22%, F1=73.90%, Macro F1=73.90%
# Epoch 200: Train Acc=73.47%, Val Acc=73.20%, F1=73.90%, Macro F1=73.90%
#
# Fold 2/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=53.12%, Val Acc=59.68%, F1=57.44%, Macro F1=57.30%
# Epoch 2: Train Acc=64.60%, Val Acc=66.96%, F1=66.03%, Macro F1=65.98%
# Epoch 3: Train Acc=68.04%, Val Acc=68.57%, F1=68.87%, Macro F1=68.82%
# Epoch 4: Train Acc=69.26%, Val Acc=69.57%, F1=68.80%, Macro F1=68.76%
# Epoch 5: Train Acc=69.81%, Val Acc=69.86%, F1=69.98%, Macro F1=69.93%
# Epoch 6: Train Acc=70.17%, Val Acc=70.33%, F1=70.48%, Macro F1=70.44%
# Epoch 7: Train Acc=70.40%, Val Acc=70.43%, F1=70.33%, Macro F1=70.29%
# Epoch 8: Train Acc=70.55%, Val Acc=70.80%, F1=70.62%, Macro F1=70.57%
# Epoch 9: Train Acc=70.74%, Val Acc=70.93%, F1=71.20%, Macro F1=71.16%
# Epoch 10: Train Acc=70.87%, Val Acc=70.92%, F1=71.42%, Macro F1=71.38%
# Epoch 11: Train Acc=71.06%, Val Acc=71.12%, F1=70.90%, Macro F1=70.86%
# Epoch 12: Train Acc=71.16%, Val Acc=71.19%, F1=71.58%, Macro F1=71.54%
# Epoch 13: Train Acc=71.27%, Val Acc=71.54%, F1=72.05%, Macro F1=72.01%
# Epoch 14: Train Acc=71.37%, Val Acc=71.56%, F1=71.93%, Macro F1=71.89%
# Epoch 15: Train Acc=71.45%, Val Acc=71.41%, F1=72.06%, Macro F1=72.01%
# Epoch 16: Train Acc=71.49%, Val Acc=71.46%, F1=71.76%, Macro F1=71.72%
# Epoch 17: Train Acc=71.54%, Val Acc=71.68%, F1=71.93%, Macro F1=71.89%
# Epoch 18: Train Acc=71.64%, Val Acc=71.93%, F1=72.43%, Macro F1=72.39%
# Epoch 19: Train Acc=71.72%, Val Acc=71.69%, F1=71.79%, Macro F1=71.75%
# Epoch 20: Train Acc=71.76%, Val Acc=71.94%, F1=72.30%, Macro F1=72.26%
# Epoch 21: Train Acc=71.87%, Val Acc=71.73%, F1=72.21%, Macro F1=72.17%
# Epoch 22: Train Acc=71.87%, Val Acc=71.53%, F1=72.26%, Macro F1=72.22%
# Epoch 23: Train Acc=71.88%, Val Acc=71.95%, F1=72.35%, Macro F1=72.31%
# Epoch 24: Train Acc=71.90%, Val Acc=71.89%, F1=72.32%, Macro F1=72.28%
# Epoch 25: Train Acc=71.95%, Val Acc=72.24%, F1=72.47%, Macro F1=72.43%
# Epoch 26: Train Acc=72.02%, Val Acc=71.94%, F1=72.49%, Macro F1=72.45%
# Epoch 27: Train Acc=72.05%, Val Acc=72.38%, F1=72.90%, Macro F1=72.86%
# Epoch 28: Train Acc=72.09%, Val Acc=72.19%, F1=72.52%, Macro F1=72.48%
# Epoch 29: Train Acc=72.10%, Val Acc=72.18%, F1=72.27%, Macro F1=72.23%
# Epoch 30: Train Acc=72.16%, Val Acc=72.16%, F1=72.39%, Macro F1=72.36%
# Epoch 31: Train Acc=72.15%, Val Acc=72.30%, F1=72.61%, Macro F1=72.57%
# Epoch 32: Train Acc=72.17%, Val Acc=72.29%, F1=72.42%, Macro F1=72.38%
# Epoch 33: Train Acc=72.21%, Val Acc=72.24%, F1=72.51%, Macro F1=72.47%
# Epoch 34: Train Acc=72.26%, Val Acc=72.29%, F1=72.56%, Macro F1=72.52%
# Epoch 35: Train Acc=72.24%, Val Acc=72.23%, F1=72.50%, Macro F1=72.46%
# Epoch 36: Train Acc=72.28%, Val Acc=72.42%, F1=72.77%, Macro F1=72.73%
# Epoch 37: Train Acc=72.31%, Val Acc=72.38%, F1=72.67%, Macro F1=72.63%
# Epoch 38: Train Acc=72.31%, Val Acc=72.43%, F1=72.76%, Macro F1=72.73%
# Epoch 39: Train Acc=72.34%, Val Acc=72.33%, F1=72.92%, Macro F1=72.88%
# Epoch 40: Train Acc=72.34%, Val Acc=72.44%, F1=72.87%, Macro F1=72.84%
# Epoch 41: Train Acc=72.40%, Val Acc=72.42%, F1=72.87%, Macro F1=72.83%
# Epoch 42: Train Acc=72.37%, Val Acc=72.43%, F1=72.77%, Macro F1=72.74%
# Epoch 43: Train Acc=72.37%, Val Acc=72.58%, F1=73.04%, Macro F1=73.01%
# Epoch 44: Train Acc=72.44%, Val Acc=72.60%, F1=73.22%, Macro F1=73.19%
# Epoch 45: Train Acc=72.44%, Val Acc=72.47%, F1=72.89%, Macro F1=72.85%
# Epoch 46: Train Acc=72.44%, Val Acc=72.61%, F1=73.04%, Macro F1=73.00%
# Epoch 47: Train Acc=72.45%, Val Acc=72.50%, F1=72.87%, Macro F1=72.83%
# Epoch 48: Train Acc=72.44%, Val Acc=72.44%, F1=73.03%, Macro F1=72.99%
# Epoch 49: Train Acc=72.49%, Val Acc=72.48%, F1=72.82%, Macro F1=72.78%
# Epoch 50: Train Acc=72.52%, Val Acc=72.43%, F1=72.88%, Macro F1=72.84%
# Epoch 51: Train Acc=72.52%, Val Acc=72.56%, F1=73.05%, Macro F1=73.01%
# Epoch 52: Train Acc=72.50%, Val Acc=72.47%, F1=72.92%, Macro F1=72.88%
# Epoch 53: Train Acc=72.55%, Val Acc=72.73%, F1=73.28%, Macro F1=73.24%
# Epoch 54: Train Acc=72.54%, Val Acc=72.63%, F1=73.21%, Macro F1=73.18%
# Epoch 55: Train Acc=72.57%, Val Acc=72.46%, F1=72.71%, Macro F1=72.67%
# Epoch 56: Train Acc=72.58%, Val Acc=72.47%, F1=72.92%, Macro F1=72.88%
# Epoch 57: Train Acc=72.59%, Val Acc=72.52%, F1=73.00%, Macro F1=72.96%
# Epoch 58: Train Acc=72.62%, Val Acc=72.74%, F1=73.31%, Macro F1=73.28%
# Epoch 59: Train Acc=72.62%, Val Acc=72.57%, F1=72.90%, Macro F1=72.87%
# Epoch 60: Train Acc=72.63%, Val Acc=72.64%, F1=73.10%, Macro F1=73.06%
# Epoch 61: Train Acc=72.66%, Val Acc=72.64%, F1=73.13%, Macro F1=73.09%
# Epoch 62: Train Acc=72.65%, Val Acc=72.73%, F1=73.29%, Macro F1=73.25%
# Epoch 63: Train Acc=72.64%, Val Acc=72.53%, F1=72.99%, Macro F1=72.95%
# Epoch 64: Train Acc=72.65%, Val Acc=72.93%, F1=73.52%, Macro F1=73.49%
# Epoch 65: Train Acc=72.68%, Val Acc=72.65%, F1=73.08%, Macro F1=73.04%
# Epoch 66: Train Acc=72.71%, Val Acc=72.77%, F1=73.36%, Macro F1=73.32%
# Epoch 67: Train Acc=72.71%, Val Acc=72.79%, F1=73.21%, Macro F1=73.17%
# Epoch 68: Train Acc=72.72%, Val Acc=72.93%, F1=73.33%, Macro F1=73.29%
# Epoch 69: Train Acc=72.74%, Val Acc=72.70%, F1=73.29%, Macro F1=73.25%
# Epoch 70: Train Acc=72.74%, Val Acc=72.72%, F1=73.24%, Macro F1=73.20%
# Epoch 71: Train Acc=72.79%, Val Acc=72.91%, F1=73.49%, Macro F1=73.45%
# Epoch 72: Train Acc=72.76%, Val Acc=72.88%, F1=73.30%, Macro F1=73.27%
# Epoch 73: Train Acc=72.79%, Val Acc=72.76%, F1=73.19%, Macro F1=73.15%
# Epoch 74: Train Acc=72.78%, Val Acc=72.82%, F1=73.30%, Macro F1=73.26%
# Epoch 75: Train Acc=72.82%, Val Acc=72.89%, F1=73.42%, Macro F1=73.39%
# Epoch 76: Train Acc=72.79%, Val Acc=72.93%, F1=73.50%, Macro F1=73.46%
# Epoch 77: Train Acc=72.83%, Val Acc=72.86%, F1=73.51%, Macro F1=73.47%
# Epoch 78: Train Acc=72.82%, Val Acc=73.10%, F1=73.67%, Macro F1=73.64%
# Epoch 79: Train Acc=72.88%, Val Acc=72.80%, F1=73.17%, Macro F1=73.13%
# Epoch 80: Train Acc=72.86%, Val Acc=72.73%, F1=73.15%, Macro F1=73.11%
# Epoch 81: Train Acc=72.88%, Val Acc=72.93%, F1=73.39%, Macro F1=73.36%
# Epoch 82: Train Acc=72.85%, Val Acc=73.04%, F1=73.67%, Macro F1=73.63%
# Epoch 83: Train Acc=72.86%, Val Acc=72.80%, F1=73.35%, Macro F1=73.31%
# Epoch 84: Train Acc=72.91%, Val Acc=72.87%, F1=73.33%, Macro F1=73.29%
# Epoch 85: Train Acc=72.90%, Val Acc=73.02%, F1=73.49%, Macro F1=73.45%
# Epoch 86: Train Acc=72.93%, Val Acc=72.57%, F1=72.94%, Macro F1=72.90%
# Epoch 87: Train Acc=72.93%, Val Acc=73.02%, F1=73.58%, Macro F1=73.54%
# Epoch 88: Train Acc=72.94%, Val Acc=72.72%, F1=73.38%, Macro F1=73.34%
# Epoch 89: Train Acc=72.95%, Val Acc=73.04%, F1=73.67%, Macro F1=73.64%
# Epoch 90: Train Acc=72.95%, Val Acc=72.65%, F1=73.34%, Macro F1=73.30%
# Epoch 91: Train Acc=72.97%, Val Acc=72.90%, F1=73.27%, Macro F1=73.23%
# Epoch 92: Train Acc=72.96%, Val Acc=73.01%, F1=73.47%, Macro F1=73.43%
# Epoch 93: Train Acc=72.98%, Val Acc=73.07%, F1=73.49%, Macro F1=73.45%
# Epoch 94: Train Acc=73.01%, Val Acc=72.95%, F1=73.58%, Macro F1=73.54%
# Epoch 95: Train Acc=73.01%, Val Acc=72.98%, F1=73.39%, Macro F1=73.35%
# Epoch 96: Train Acc=73.02%, Val Acc=73.05%, F1=73.66%, Macro F1=73.62%
# Epoch 97: Train Acc=73.00%, Val Acc=73.01%, F1=73.66%, Macro F1=73.62%
# Epoch 98: Train Acc=73.04%, Val Acc=73.00%, F1=73.53%, Macro F1=73.50%
# Epoch 99: Train Acc=73.05%, Val Acc=73.02%, F1=73.59%, Macro F1=73.55%
# Epoch 100: Train Acc=73.04%, Val Acc=73.06%, F1=73.68%, Macro F1=73.64%
# Epoch 101: Train Acc=73.06%, Val Acc=73.04%, F1=73.64%, Macro F1=73.60%
# Epoch 102: Train Acc=73.03%, Val Acc=72.94%, F1=72.90%, Macro F1=72.86%
# Epoch 103: Train Acc=73.10%, Val Acc=73.15%, F1=73.74%, Macro F1=73.70%
# Epoch 104: Train Acc=73.08%, Val Acc=73.16%, F1=73.54%, Macro F1=73.51%
# Epoch 105: Train Acc=73.08%, Val Acc=73.03%, F1=73.37%, Macro F1=73.34%
# Epoch 106: Train Acc=73.09%, Val Acc=73.15%, F1=73.65%, Macro F1=73.61%
# Epoch 107: Train Acc=73.10%, Val Acc=72.95%, F1=73.60%, Macro F1=73.56%
# Epoch 108: Train Acc=73.11%, Val Acc=73.04%, F1=73.42%, Macro F1=73.38%
# Epoch 109: Train Acc=73.15%, Val Acc=72.90%, F1=73.12%, Macro F1=73.08%
# Epoch 110: Train Acc=73.11%, Val Acc=72.98%, F1=73.50%, Macro F1=73.46%
# Epoch 111: Train Acc=73.14%, Val Acc=73.08%, F1=73.52%, Macro F1=73.49%
# Epoch 112: Train Acc=73.13%, Val Acc=73.11%, F1=73.77%, Macro F1=73.74%
# Epoch 113: Train Acc=73.15%, Val Acc=73.16%, F1=73.87%, Macro F1=73.83%
# Epoch 114: Train Acc=73.14%, Val Acc=72.90%, F1=73.18%, Macro F1=73.15%
# Epoch 115: Train Acc=73.18%, Val Acc=73.18%, F1=73.82%, Macro F1=73.78%
# Epoch 116: Train Acc=73.13%, Val Acc=73.17%, F1=73.74%, Macro F1=73.70%
# Epoch 117: Train Acc=73.15%, Val Acc=73.22%, F1=73.80%, Macro F1=73.77%
# Epoch 118: Train Acc=73.18%, Val Acc=73.08%, F1=73.68%, Macro F1=73.64%
# Epoch 119: Train Acc=73.16%, Val Acc=73.09%, F1=73.72%, Macro F1=73.68%
# Epoch 120: Train Acc=73.16%, Val Acc=72.91%, F1=73.43%, Macro F1=73.39%
# Epoch 121: Train Acc=73.21%, Val Acc=72.87%, F1=73.07%, Macro F1=73.04%
# Epoch 122: Train Acc=73.22%, Val Acc=73.19%, F1=73.82%, Macro F1=73.78%
# Epoch 123: Train Acc=73.21%, Val Acc=73.07%, F1=73.41%, Macro F1=73.38%
# Epoch 124: Train Acc=73.25%, Val Acc=73.26%, F1=73.87%, Macro F1=73.83%
# Epoch 125: Train Acc=73.23%, Val Acc=73.18%, F1=73.64%, Macro F1=73.60%
# Epoch 126: Train Acc=73.21%, Val Acc=73.16%, F1=73.80%, Macro F1=73.76%
# Epoch 127: Train Acc=73.26%, Val Acc=73.07%, F1=73.64%, Macro F1=73.61%
# Epoch 128: Train Acc=73.23%, Val Acc=73.28%, F1=73.90%, Macro F1=73.86%
# Epoch 129: Train Acc=73.24%, Val Acc=73.34%, F1=73.99%, Macro F1=73.95%
# Epoch 130: Train Acc=73.26%, Val Acc=73.32%, F1=73.67%, Macro F1=73.64%
# Epoch 131: Train Acc=73.25%, Val Acc=73.05%, F1=73.76%, Macro F1=73.72%
# Epoch 132: Train Acc=73.28%, Val Acc=73.19%, F1=73.63%, Macro F1=73.59%
# Epoch 133: Train Acc=73.28%, Val Acc=73.29%, F1=73.99%, Macro F1=73.95%
# Epoch 134: Train Acc=73.24%, Val Acc=73.12%, F1=73.78%, Macro F1=73.74%
# Epoch 135: Train Acc=73.27%, Val Acc=73.12%, F1=73.77%, Macro F1=73.74%
# Epoch 136: Train Acc=73.28%, Val Acc=73.10%, F1=73.25%, Macro F1=73.22%
# Epoch 137: Train Acc=73.31%, Val Acc=73.18%, F1=73.77%, Macro F1=73.73%
# Epoch 138: Train Acc=73.31%, Val Acc=73.31%, F1=73.98%, Macro F1=73.94%
# Epoch 139: Train Acc=73.29%, Val Acc=73.39%, F1=73.73%, Macro F1=73.69%
# Epoch 140: Train Acc=73.31%, Val Acc=73.22%, F1=73.82%, Macro F1=73.78%
# Epoch 141: Train Acc=73.28%, Val Acc=73.17%, F1=73.67%, Macro F1=73.63%
# Epoch 142: Train Acc=73.30%, Val Acc=73.30%, F1=73.70%, Macro F1=73.66%
# Epoch 143: Train Acc=73.35%, Val Acc=73.19%, F1=73.86%, Macro F1=73.82%
# Epoch 144: Train Acc=73.33%, Val Acc=73.24%, F1=73.80%, Macro F1=73.77%
# Epoch 145: Train Acc=73.30%, Val Acc=73.42%, F1=74.11%, Macro F1=74.07%
# Epoch 146: Train Acc=73.32%, Val Acc=73.16%, F1=73.71%, Macro F1=73.68%
# Epoch 147: Train Acc=73.32%, Val Acc=73.32%, F1=73.88%, Macro F1=73.84%
# Epoch 148: Train Acc=73.34%, Val Acc=73.20%, F1=73.83%, Macro F1=73.79%
# Epoch 149: Train Acc=73.35%, Val Acc=73.34%, F1=73.99%, Macro F1=73.96%
# Epoch 150: Train Acc=73.37%, Val Acc=73.25%, F1=73.85%, Macro F1=73.81%
# Epoch 151: Train Acc=73.35%, Val Acc=73.26%, F1=73.91%, Macro F1=73.87%
# Epoch 152: Train Acc=73.37%, Val Acc=73.30%, F1=73.90%, Macro F1=73.87%
# Epoch 153: Train Acc=73.33%, Val Acc=73.46%, F1=73.83%, Macro F1=73.80%
# Epoch 154: Train Acc=73.40%, Val Acc=73.31%, F1=73.93%, Macro F1=73.90%
# Epoch 155: Train Acc=73.36%, Val Acc=73.33%, F1=73.96%, Macro F1=73.92%
# Epoch 156: Train Acc=73.40%, Val Acc=73.34%, F1=73.95%, Macro F1=73.91%
# Epoch 157: Train Acc=73.37%, Val Acc=73.02%, F1=73.42%, Macro F1=73.38%
# Epoch 158: Train Acc=73.36%, Val Acc=73.07%, F1=73.69%, Macro F1=73.66%
# Epoch 159: Train Acc=73.40%, Val Acc=73.49%, F1=74.16%, Macro F1=74.13%
# Epoch 160: Train Acc=73.38%, Val Acc=73.26%, F1=73.67%, Macro F1=73.63%
# Epoch 161: Train Acc=73.35%, Val Acc=73.30%, F1=73.77%, Macro F1=73.74%
# Epoch 162: Train Acc=73.37%, Val Acc=73.33%, F1=73.44%, Macro F1=73.40%
# Epoch 163: Train Acc=73.35%, Val Acc=73.38%, F1=74.03%, Macro F1=73.99%
# Epoch 164: Train Acc=73.39%, Val Acc=73.50%, F1=74.04%, Macro F1=74.00%
# Epoch 165: Train Acc=73.42%, Val Acc=73.48%, F1=73.93%, Macro F1=73.89%
# Epoch 166: Train Acc=73.47%, Val Acc=73.32%, F1=74.01%, Macro F1=73.97%
# Epoch 167: Train Acc=73.42%, Val Acc=73.26%, F1=73.81%, Macro F1=73.77%
# Epoch 168: Train Acc=73.43%, Val Acc=73.23%, F1=73.52%, Macro F1=73.48%
# Epoch 169: Train Acc=73.39%, Val Acc=73.32%, F1=73.88%, Macro F1=73.84%
# Epoch 170: Train Acc=73.42%, Val Acc=73.44%, F1=74.06%, Macro F1=74.02%
# Epoch 171: Train Acc=73.41%, Val Acc=73.45%, F1=74.03%, Macro F1=73.99%
# Epoch 172: Train Acc=73.42%, Val Acc=73.46%, F1=74.09%, Macro F1=74.05%
# Epoch 173: Train Acc=73.45%, Val Acc=73.54%, F1=74.15%, Macro F1=74.11%
# Epoch 174: Train Acc=73.47%, Val Acc=73.33%, F1=73.83%, Macro F1=73.79%
# Epoch 175: Train Acc=73.42%, Val Acc=73.29%, F1=73.69%, Macro F1=73.66%
# Epoch 176: Train Acc=73.47%, Val Acc=73.21%, F1=73.90%, Macro F1=73.86%
# Epoch 177: Train Acc=73.40%, Val Acc=73.34%, F1=73.85%, Macro F1=73.82%
# Epoch 178: Train Acc=73.46%, Val Acc=73.47%, F1=73.87%, Macro F1=73.84%
# Epoch 179: Train Acc=73.46%, Val Acc=73.50%, F1=73.89%, Macro F1=73.85%
# Epoch 180: Train Acc=73.45%, Val Acc=73.31%, F1=73.62%, Macro F1=73.59%
# Epoch 181: Train Acc=73.50%, Val Acc=73.36%, F1=73.96%, Macro F1=73.93%
# Epoch 182: Train Acc=73.46%, Val Acc=73.42%, F1=74.11%, Macro F1=74.08%
# Epoch 183: Train Acc=73.48%, Val Acc=73.40%, F1=74.07%, Macro F1=74.03%
# Epoch 184: Train Acc=73.44%, Val Acc=73.46%, F1=74.12%, Macro F1=74.08%
# Epoch 185: Train Acc=73.42%, Val Acc=73.42%, F1=74.06%, Macro F1=74.02%
# Epoch 186: Train Acc=73.45%, Val Acc=73.39%, F1=73.84%, Macro F1=73.80%
# Epoch 187: Train Acc=73.49%, Val Acc=73.31%, F1=73.69%, Macro F1=73.65%
# Epoch 188: Train Acc=73.46%, Val Acc=73.47%, F1=74.07%, Macro F1=74.03%
# Epoch 189: Train Acc=73.47%, Val Acc=73.41%, F1=74.02%, Macro F1=73.99%
# Epoch 190: Train Acc=73.52%, Val Acc=73.55%, F1=74.09%, Macro F1=74.05%
# Epoch 191: Train Acc=73.53%, Val Acc=73.52%, F1=74.14%, Macro F1=74.11%
# Epoch 192: Train Acc=73.47%, Val Acc=73.58%, F1=74.19%, Macro F1=74.16%
# Epoch 193: Train Acc=73.46%, Val Acc=73.55%, F1=74.04%, Macro F1=74.00%
# Epoch 194: Train Acc=73.52%, Val Acc=73.42%, F1=74.03%, Macro F1=73.99%
# Epoch 195: Train Acc=73.48%, Val Acc=73.59%, F1=74.14%, Macro F1=74.11%
# Epoch 196: Train Acc=73.45%, Val Acc=73.44%, F1=74.05%, Macro F1=74.01%
# Epoch 197: Train Acc=73.52%, Val Acc=73.51%, F1=74.14%, Macro F1=74.10%
# Epoch 198: Train Acc=73.49%, Val Acc=73.47%, F1=73.96%, Macro F1=73.92%
# Epoch 199: Train Acc=73.50%, Val Acc=73.14%, F1=73.59%, Macro F1=73.55%
# Epoch 200: Train Acc=73.51%, Val Acc=73.50%, F1=74.09%, Macro F1=74.05%
#
# Fold 3/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=54.29%, Val Acc=62.81%, F1=62.80%, Macro F1=62.79%
# Epoch 2: Train Acc=64.45%, Val Acc=66.42%, F1=66.77%, Macro F1=66.75%
# Epoch 3: Train Acc=67.18%, Val Acc=67.80%, F1=67.53%, Macro F1=67.51%
# Epoch 4: Train Acc=68.15%, Val Acc=68.52%, F1=68.51%, Macro F1=68.49%
# Epoch 5: Train Acc=68.80%, Val Acc=69.07%, F1=69.05%, Macro F1=69.03%
# Epoch 6: Train Acc=69.25%, Val Acc=69.26%, F1=69.77%, Macro F1=69.75%
# Epoch 7: Train Acc=69.57%, Val Acc=69.73%, F1=69.31%, Macro F1=69.29%
# Epoch 8: Train Acc=69.82%, Val Acc=69.90%, F1=69.75%, Macro F1=69.73%
# Epoch 9: Train Acc=70.08%, Val Acc=69.92%, F1=69.22%, Macro F1=69.20%
# Epoch 10: Train Acc=70.26%, Val Acc=70.22%, F1=69.96%, Macro F1=69.93%
# Epoch 11: Train Acc=70.45%, Val Acc=70.66%, F1=71.21%, Macro F1=71.18%
# Epoch 12: Train Acc=70.52%, Val Acc=70.67%, F1=71.22%, Macro F1=71.20%
# Epoch 13: Train Acc=70.68%, Val Acc=70.73%, F1=70.72%, Macro F1=70.69%
# Epoch 14: Train Acc=70.79%, Val Acc=70.80%, F1=70.98%, Macro F1=70.95%
# Epoch 15: Train Acc=70.88%, Val Acc=70.88%, F1=71.32%, Macro F1=71.29%
# Epoch 16: Train Acc=71.01%, Val Acc=70.96%, F1=71.27%, Macro F1=71.25%
# Epoch 17: Train Acc=71.06%, Val Acc=71.11%, F1=71.15%, Macro F1=71.12%
# Epoch 18: Train Acc=71.18%, Val Acc=71.36%, F1=71.86%, Macro F1=71.83%
# Epoch 19: Train Acc=71.19%, Val Acc=71.26%, F1=71.87%, Macro F1=71.85%
# Epoch 20: Train Acc=71.25%, Val Acc=71.32%, F1=71.79%, Macro F1=71.76%
# Epoch 21: Train Acc=71.33%, Val Acc=71.44%, F1=71.67%, Macro F1=71.64%
# Epoch 22: Train Acc=71.32%, Val Acc=71.19%, F1=71.62%, Macro F1=71.59%
# Epoch 23: Train Acc=71.39%, Val Acc=71.09%, F1=71.82%, Macro F1=71.79%
# Epoch 24: Train Acc=71.49%, Val Acc=71.24%, F1=70.84%, Macro F1=70.82%
# Epoch 25: Train Acc=71.47%, Val Acc=71.31%, F1=71.47%, Macro F1=71.44%
# Epoch 26: Train Acc=71.55%, Val Acc=71.40%, F1=71.55%, Macro F1=71.52%
# Epoch 27: Train Acc=71.57%, Val Acc=71.40%, F1=72.02%, Macro F1=71.99%
# Epoch 28: Train Acc=71.67%, Val Acc=71.31%, F1=71.60%, Macro F1=71.57%
# Epoch 29: Train Acc=71.65%, Val Acc=71.46%, F1=71.72%, Macro F1=71.69%
# Epoch 30: Train Acc=71.68%, Val Acc=71.61%, F1=71.80%, Macro F1=71.77%
# Epoch 31: Train Acc=71.73%, Val Acc=71.57%, F1=72.00%, Macro F1=71.98%
# Epoch 32: Train Acc=71.81%, Val Acc=71.59%, F1=71.58%, Macro F1=71.56%
# Epoch 33: Train Acc=71.77%, Val Acc=71.75%, F1=72.17%, Macro F1=72.15%
# Epoch 34: Train Acc=71.78%, Val Acc=71.75%, F1=71.82%, Macro F1=71.79%
# Epoch 35: Train Acc=71.82%, Val Acc=71.70%, F1=72.26%, Macro F1=72.23%
# Epoch 36: Train Acc=71.85%, Val Acc=71.80%, F1=72.35%, Macro F1=72.32%
# Epoch 37: Train Acc=71.89%, Val Acc=71.71%, F1=71.28%, Macro F1=71.25%
# Epoch 38: Train Acc=71.89%, Val Acc=71.79%, F1=72.28%, Macro F1=72.25%
# Epoch 39: Train Acc=71.95%, Val Acc=71.89%, F1=72.25%, Macro F1=72.22%
# Epoch 40: Train Acc=71.98%, Val Acc=72.11%, F1=72.40%, Macro F1=72.37%
# Epoch 41: Train Acc=72.01%, Val Acc=71.94%, F1=72.60%, Macro F1=72.58%
# Epoch 42: Train Acc=72.00%, Val Acc=72.08%, F1=72.25%, Macro F1=72.23%
# Epoch 43: Train Acc=72.06%, Val Acc=72.04%, F1=72.72%, Macro F1=72.69%
# Epoch 44: Train Acc=72.06%, Val Acc=72.00%, F1=72.53%, Macro F1=72.50%
# Epoch 45: Train Acc=72.06%, Val Acc=72.03%, F1=72.23%, Macro F1=72.21%
# Epoch 46: Train Acc=72.08%, Val Acc=72.11%, F1=72.70%, Macro F1=72.67%
# Epoch 47: Train Acc=72.09%, Val Acc=71.92%, F1=72.52%, Macro F1=72.49%
# Epoch 48: Train Acc=72.09%, Val Acc=72.21%, F1=72.66%, Macro F1=72.64%
# Epoch 49: Train Acc=72.13%, Val Acc=72.11%, F1=72.47%, Macro F1=72.45%
# Epoch 50: Train Acc=72.17%, Val Acc=71.96%, F1=72.05%, Macro F1=72.03%
# Epoch 51: Train Acc=72.15%, Val Acc=72.13%, F1=72.64%, Macro F1=72.61%
# Epoch 52: Train Acc=72.22%, Val Acc=72.11%, F1=72.77%, Macro F1=72.74%
# Epoch 53: Train Acc=72.19%, Val Acc=72.35%, F1=72.91%, Macro F1=72.88%
# Epoch 54: Train Acc=72.22%, Val Acc=72.18%, F1=72.70%, Macro F1=72.68%
# Epoch 55: Train Acc=72.23%, Val Acc=72.19%, F1=72.59%, Macro F1=72.56%
# Epoch 56: Train Acc=72.28%, Val Acc=72.37%, F1=72.77%, Macro F1=72.75%
# Epoch 57: Train Acc=72.28%, Val Acc=72.22%, F1=72.74%, Macro F1=72.71%
# Epoch 58: Train Acc=72.28%, Val Acc=72.21%, F1=72.81%, Macro F1=72.78%
# Epoch 59: Train Acc=72.35%, Val Acc=72.25%, F1=72.66%, Macro F1=72.63%
# Epoch 60: Train Acc=72.31%, Val Acc=72.27%, F1=72.60%, Macro F1=72.57%
# Epoch 61: Train Acc=72.33%, Val Acc=72.22%, F1=72.60%, Macro F1=72.57%
# Epoch 62: Train Acc=72.37%, Val Acc=72.39%, F1=72.85%, Macro F1=72.82%
# Epoch 63: Train Acc=72.42%, Val Acc=72.31%, F1=72.49%, Macro F1=72.47%
# Epoch 64: Train Acc=72.35%, Val Acc=72.27%, F1=72.94%, Macro F1=72.91%
# Epoch 65: Train Acc=72.39%, Val Acc=72.22%, F1=72.64%, Macro F1=72.61%
# Epoch 66: Train Acc=72.40%, Val Acc=72.39%, F1=72.86%, Macro F1=72.84%
# Epoch 67: Train Acc=72.38%, Val Acc=72.05%, F1=72.62%, Macro F1=72.59%
# Epoch 68: Train Acc=72.42%, Val Acc=72.52%, F1=73.02%, Macro F1=73.00%
# Epoch 69: Train Acc=72.44%, Val Acc=72.13%, F1=72.84%, Macro F1=72.81%
# Epoch 70: Train Acc=72.44%, Val Acc=72.36%, F1=72.72%, Macro F1=72.70%
# Epoch 71: Train Acc=72.47%, Val Acc=72.25%, F1=72.23%, Macro F1=72.20%
# Epoch 72: Train Acc=72.51%, Val Acc=72.41%, F1=72.52%, Macro F1=72.50%
# Epoch 73: Train Acc=72.53%, Val Acc=72.25%, F1=72.82%, Macro F1=72.79%
# Epoch 74: Train Acc=72.51%, Val Acc=72.62%, F1=73.20%, Macro F1=73.17%
# Epoch 75: Train Acc=72.51%, Val Acc=72.56%, F1=73.24%, Macro F1=73.21%
# Epoch 76: Train Acc=72.56%, Val Acc=72.37%, F1=73.07%, Macro F1=73.04%
# Epoch 77: Train Acc=72.55%, Val Acc=72.32%, F1=72.51%, Macro F1=72.48%
# Epoch 78: Train Acc=72.54%, Val Acc=72.35%, F1=73.10%, Macro F1=73.08%
# Epoch 79: Train Acc=72.57%, Val Acc=72.65%, F1=73.28%, Macro F1=73.25%
# Epoch 80: Train Acc=72.56%, Val Acc=72.62%, F1=73.11%, Macro F1=73.08%
# Epoch 81: Train Acc=72.58%, Val Acc=72.49%, F1=73.08%, Macro F1=73.05%
# Epoch 82: Train Acc=72.60%, Val Acc=72.29%, F1=72.96%, Macro F1=72.94%
# Epoch 83: Train Acc=72.61%, Val Acc=72.44%, F1=73.20%, Macro F1=73.17%
# Epoch 84: Train Acc=72.66%, Val Acc=72.53%, F1=73.09%, Macro F1=73.07%
# Epoch 85: Train Acc=72.64%, Val Acc=72.63%, F1=73.07%, Macro F1=73.04%
# Epoch 86: Train Acc=72.65%, Val Acc=72.27%, F1=72.43%, Macro F1=72.40%
# Epoch 87: Train Acc=72.61%, Val Acc=72.51%, F1=72.90%, Macro F1=72.87%
# Epoch 88: Train Acc=72.69%, Val Acc=72.31%, F1=72.92%, Macro F1=72.89%
# Epoch 89: Train Acc=72.63%, Val Acc=72.79%, F1=73.33%, Macro F1=73.30%
# Epoch 90: Train Acc=72.64%, Val Acc=72.62%, F1=73.19%, Macro F1=73.17%
# Epoch 91: Train Acc=72.65%, Val Acc=72.73%, F1=73.23%, Macro F1=73.20%
# Epoch 92: Train Acc=72.67%, Val Acc=72.71%, F1=72.98%, Macro F1=72.95%
# Epoch 93: Train Acc=72.68%, Val Acc=72.48%, F1=72.95%, Macro F1=72.92%
# Epoch 94: Train Acc=72.70%, Val Acc=72.61%, F1=73.32%, Macro F1=73.29%
# Epoch 95: Train Acc=72.71%, Val Acc=72.51%, F1=73.12%, Macro F1=73.09%
# Epoch 96: Train Acc=72.73%, Val Acc=72.57%, F1=73.21%, Macro F1=73.19%
# Epoch 97: Train Acc=72.75%, Val Acc=72.66%, F1=73.36%, Macro F1=73.33%
# Epoch 98: Train Acc=72.73%, Val Acc=72.79%, F1=73.36%, Macro F1=73.33%
# Epoch 99: Train Acc=72.74%, Val Acc=72.55%, F1=72.68%, Macro F1=72.65%
# Epoch 100: Train Acc=72.76%, Val Acc=72.51%, F1=72.95%, Macro F1=72.92%
# Epoch 101: Train Acc=72.78%, Val Acc=72.47%, F1=72.59%, Macro F1=72.56%
# Epoch 102: Train Acc=72.75%, Val Acc=72.60%, F1=73.33%, Macro F1=73.30%
# Epoch 103: Train Acc=72.73%, Val Acc=72.61%, F1=73.22%, Macro F1=73.20%
# Epoch 104: Train Acc=72.79%, Val Acc=72.58%, F1=73.11%, Macro F1=73.08%
# Epoch 105: Train Acc=72.78%, Val Acc=72.67%, F1=73.12%, Macro F1=73.09%
# Epoch 106: Train Acc=72.80%, Val Acc=72.89%, F1=73.48%, Macro F1=73.45%
# Epoch 107: Train Acc=72.80%, Val Acc=72.88%, F1=73.50%, Macro F1=73.47%
# Epoch 108: Train Acc=72.80%, Val Acc=72.62%, F1=72.98%, Macro F1=72.96%
# Epoch 109: Train Acc=72.84%, Val Acc=72.65%, F1=73.28%, Macro F1=73.26%
# Epoch 110: Train Acc=72.80%, Val Acc=72.74%, F1=73.41%, Macro F1=73.38%
# Epoch 111: Train Acc=72.79%, Val Acc=72.74%, F1=73.34%, Macro F1=73.31%
# Epoch 112: Train Acc=72.88%, Val Acc=72.78%, F1=73.44%, Macro F1=73.42%
# Epoch 113: Train Acc=72.82%, Val Acc=72.89%, F1=73.52%, Macro F1=73.49%
# Epoch 114: Train Acc=72.86%, Val Acc=72.88%, F1=73.47%, Macro F1=73.44%
# Epoch 115: Train Acc=72.82%, Val Acc=72.84%, F1=73.26%, Macro F1=73.23%
# Epoch 116: Train Acc=72.87%, Val Acc=72.88%, F1=73.46%, Macro F1=73.43%
# Epoch 117: Train Acc=72.87%, Val Acc=72.88%, F1=73.19%, Macro F1=73.16%
# Epoch 118: Train Acc=72.85%, Val Acc=72.87%, F1=73.39%, Macro F1=73.37%
# Epoch 119: Train Acc=72.90%, Val Acc=72.60%, F1=73.35%, Macro F1=73.32%
# Epoch 120: Train Acc=72.88%, Val Acc=72.65%, F1=73.30%, Macro F1=73.27%
# Epoch 121: Train Acc=72.90%, Val Acc=72.82%, F1=73.25%, Macro F1=73.22%
# Epoch 122: Train Acc=72.89%, Val Acc=72.77%, F1=73.30%, Macro F1=73.28%
# Epoch 123: Train Acc=72.95%, Val Acc=72.90%, F1=73.60%, Macro F1=73.57%
# Epoch 124: Train Acc=72.94%, Val Acc=72.81%, F1=73.01%, Macro F1=72.98%
# Epoch 125: Train Acc=72.95%, Val Acc=72.92%, F1=73.62%, Macro F1=73.59%
# Epoch 126: Train Acc=72.93%, Val Acc=72.74%, F1=72.99%, Macro F1=72.96%
# Epoch 127: Train Acc=72.95%, Val Acc=72.62%, F1=73.37%, Macro F1=73.34%
# Epoch 128: Train Acc=72.93%, Val Acc=72.73%, F1=73.40%, Macro F1=73.37%
# Epoch 129: Train Acc=72.99%, Val Acc=72.93%, F1=73.63%, Macro F1=73.60%
# Epoch 130: Train Acc=72.94%, Val Acc=72.89%, F1=73.55%, Macro F1=73.52%
# Epoch 131: Train Acc=72.96%, Val Acc=72.82%, F1=73.56%, Macro F1=73.53%
# Epoch 132: Train Acc=72.95%, Val Acc=73.11%, F1=73.63%, Macro F1=73.61%
# Epoch 133: Train Acc=72.97%, Val Acc=72.78%, F1=73.53%, Macro F1=73.51%
# Epoch 134: Train Acc=72.99%, Val Acc=72.97%, F1=73.58%, Macro F1=73.55%
# Epoch 135: Train Acc=72.98%, Val Acc=72.69%, F1=73.43%, Macro F1=73.40%
# Epoch 136: Train Acc=73.03%, Val Acc=72.89%, F1=73.59%, Macro F1=73.56%
# Epoch 137: Train Acc=72.99%, Val Acc=72.92%, F1=73.38%, Macro F1=73.36%
# Epoch 138: Train Acc=73.07%, Val Acc=72.90%, F1=73.53%, Macro F1=73.51%
# Epoch 139: Train Acc=72.98%, Val Acc=73.05%, F1=73.63%, Macro F1=73.60%
# Epoch 140: Train Acc=73.06%, Val Acc=72.86%, F1=73.24%, Macro F1=73.22%
# Epoch 141: Train Acc=73.05%, Val Acc=72.86%, F1=73.58%, Macro F1=73.55%
# Epoch 142: Train Acc=73.01%, Val Acc=72.88%, F1=73.05%, Macro F1=73.02%
# Epoch 143: Train Acc=73.05%, Val Acc=73.01%, F1=73.64%, Macro F1=73.61%
# Epoch 144: Train Acc=73.02%, Val Acc=72.97%, F1=73.48%, Macro F1=73.45%
# Epoch 145: Train Acc=73.05%, Val Acc=72.95%, F1=73.63%, Macro F1=73.60%
# Epoch 146: Train Acc=73.08%, Val Acc=73.08%, F1=73.44%, Macro F1=73.41%
# Epoch 147: Train Acc=73.08%, Val Acc=73.01%, F1=73.58%, Macro F1=73.55%
# Epoch 148: Train Acc=73.07%, Val Acc=72.87%, F1=73.37%, Macro F1=73.34%
# Epoch 149: Train Acc=73.11%, Val Acc=73.01%, F1=73.64%, Macro F1=73.61%
# Epoch 150: Train Acc=73.10%, Val Acc=72.70%, F1=73.10%, Macro F1=73.07%
# Epoch 151: Train Acc=73.12%, Val Acc=72.97%, F1=73.68%, Macro F1=73.65%
# Epoch 152: Train Acc=73.09%, Val Acc=73.00%, F1=73.31%, Macro F1=73.29%
# Epoch 153: Train Acc=73.10%, Val Acc=72.87%, F1=73.53%, Macro F1=73.50%
# Epoch 154: Train Acc=73.11%, Val Acc=73.12%, F1=73.81%, Macro F1=73.78%
# Epoch 155: Train Acc=73.14%, Val Acc=73.02%, F1=73.72%, Macro F1=73.69%
# Epoch 156: Train Acc=73.12%, Val Acc=72.99%, F1=73.43%, Macro F1=73.40%
# Epoch 157: Train Acc=73.16%, Val Acc=72.81%, F1=73.49%, Macro F1=73.46%
# Epoch 158: Train Acc=73.17%, Val Acc=73.00%, F1=73.65%, Macro F1=73.63%
# Epoch 159: Train Acc=73.12%, Val Acc=73.17%, F1=73.60%, Macro F1=73.57%
# Epoch 160: Train Acc=73.19%, Val Acc=73.19%, F1=73.84%, Macro F1=73.81%
# Epoch 161: Train Acc=73.15%, Val Acc=72.67%, F1=73.03%, Macro F1=73.00%
# Epoch 162: Train Acc=73.16%, Val Acc=73.09%, F1=73.68%, Macro F1=73.66%
# Epoch 163: Train Acc=73.17%, Val Acc=72.92%, F1=73.54%, Macro F1=73.52%
# Epoch 164: Train Acc=73.12%, Val Acc=72.97%, F1=73.63%, Macro F1=73.61%
# Epoch 165: Train Acc=73.16%, Val Acc=72.94%, F1=73.44%, Macro F1=73.41%
# Epoch 166: Train Acc=73.15%, Val Acc=73.06%, F1=73.72%, Macro F1=73.69%
# Epoch 167: Train Acc=73.17%, Val Acc=72.84%, F1=73.04%, Macro F1=73.01%
# Epoch 168: Train Acc=73.17%, Val Acc=72.90%, F1=73.61%, Macro F1=73.58%
# Epoch 169: Train Acc=73.19%, Val Acc=73.02%, F1=73.72%, Macro F1=73.70%
# Epoch 170: Train Acc=73.19%, Val Acc=73.09%, F1=73.67%, Macro F1=73.65%
# Epoch 171: Train Acc=73.19%, Val Acc=73.16%, F1=73.78%, Macro F1=73.75%
# Epoch 172: Train Acc=73.21%, Val Acc=73.22%, F1=73.83%, Macro F1=73.80%
# Epoch 173: Train Acc=73.23%, Val Acc=73.22%, F1=73.75%, Macro F1=73.73%
# Epoch 174: Train Acc=73.20%, Val Acc=72.95%, F1=73.36%, Macro F1=73.33%
# Epoch 175: Train Acc=73.22%, Val Acc=73.00%, F1=73.54%, Macro F1=73.51%
# Epoch 176: Train Acc=73.25%, Val Acc=73.11%, F1=73.79%, Macro F1=73.76%
# Epoch 177: Train Acc=73.18%, Val Acc=72.88%, F1=73.53%, Macro F1=73.50%
# Epoch 178: Train Acc=73.23%, Val Acc=73.08%, F1=73.69%, Macro F1=73.66%
# Epoch 179: Train Acc=73.24%, Val Acc=72.98%, F1=73.68%, Macro F1=73.65%
# Epoch 180: Train Acc=73.24%, Val Acc=73.12%, F1=73.80%, Macro F1=73.77%
# Epoch 181: Train Acc=73.19%, Val Acc=73.17%, F1=73.80%, Macro F1=73.77%
# Epoch 182: Train Acc=73.22%, Val Acc=73.04%, F1=73.70%, Macro F1=73.67%
# Epoch 183: Train Acc=73.27%, Val Acc=72.91%, F1=73.59%, Macro F1=73.57%
# Epoch 184: Train Acc=73.22%, Val Acc=73.04%, F1=73.68%, Macro F1=73.65%
# Epoch 185: Train Acc=73.24%, Val Acc=72.99%, F1=73.51%, Macro F1=73.48%
# Epoch 186: Train Acc=73.21%, Val Acc=73.24%, F1=73.74%, Macro F1=73.72%
# Epoch 187: Train Acc=73.25%, Val Acc=73.25%, F1=73.83%, Macro F1=73.80%
# Epoch 188: Train Acc=73.27%, Val Acc=72.99%, F1=73.56%, Macro F1=73.53%
# Epoch 189: Train Acc=73.28%, Val Acc=73.29%, F1=73.93%, Macro F1=73.90%
# Epoch 190: Train Acc=73.26%, Val Acc=72.71%, F1=73.44%, Macro F1=73.41%
# Epoch 191: Train Acc=73.30%, Val Acc=73.22%, F1=73.71%, Macro F1=73.69%
# Epoch 192: Train Acc=73.28%, Val Acc=73.12%, F1=73.76%, Macro F1=73.73%
# Epoch 193: Train Acc=73.31%, Val Acc=73.04%, F1=73.67%, Macro F1=73.65%
# Epoch 194: Train Acc=73.28%, Val Acc=73.18%, F1=73.87%, Macro F1=73.84%
# Epoch 195: Train Acc=73.26%, Val Acc=73.10%, F1=73.73%, Macro F1=73.70%
# Epoch 196: Train Acc=73.34%, Val Acc=73.06%, F1=73.70%, Macro F1=73.68%
# Epoch 197: Train Acc=73.30%, Val Acc=73.14%, F1=73.80%, Macro F1=73.78%
# Epoch 198: Train Acc=73.33%, Val Acc=72.95%, F1=73.53%, Macro F1=73.51%
# Epoch 199: Train Acc=73.30%, Val Acc=73.18%, F1=73.60%, Macro F1=73.58%
# Epoch 200: Train Acc=73.29%, Val Acc=73.10%, F1=73.76%, Macro F1=73.74%
#
# Fold 4/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=53.38%, Val Acc=61.66%, F1=61.75%, Macro F1=61.75%
# Epoch 2: Train Acc=64.06%, Val Acc=66.24%, F1=66.02%, Macro F1=66.02%
# Epoch 3: Train Acc=67.13%, Val Acc=68.02%, F1=68.45%, Macro F1=68.44%
# Epoch 4: Train Acc=68.20%, Val Acc=68.77%, F1=68.74%, Macro F1=68.74%
# Epoch 5: Train Acc=68.82%, Val Acc=69.31%, F1=69.76%, Macro F1=69.75%
# Epoch 6: Train Acc=69.34%, Val Acc=69.72%, F1=69.38%, Macro F1=69.38%
# Epoch 7: Train Acc=69.75%, Val Acc=70.08%, F1=69.45%, Macro F1=69.45%
# Epoch 8: Train Acc=69.99%, Val Acc=70.17%, F1=70.09%, Macro F1=70.08%
# Epoch 9: Train Acc=70.20%, Val Acc=70.26%, F1=69.27%, Macro F1=69.27%
# Epoch 10: Train Acc=70.39%, Val Acc=70.49%, F1=70.13%, Macro F1=70.13%
# Epoch 11: Train Acc=70.51%, Val Acc=70.91%, F1=71.13%, Macro F1=71.12%
# Epoch 12: Train Acc=70.64%, Val Acc=71.08%, F1=71.15%, Macro F1=71.14%
# Epoch 13: Train Acc=70.77%, Val Acc=70.98%, F1=71.58%, Macro F1=71.56%
# Epoch 14: Train Acc=70.82%, Val Acc=71.06%, F1=70.99%, Macro F1=70.98%
# Epoch 15: Train Acc=70.95%, Val Acc=71.22%, F1=71.52%, Macro F1=71.51%
# Epoch 16: Train Acc=71.10%, Val Acc=71.24%, F1=70.82%, Macro F1=70.82%
# Epoch 17: Train Acc=71.19%, Val Acc=71.39%, F1=71.91%, Macro F1=71.90%
# Epoch 18: Train Acc=71.21%, Val Acc=71.28%, F1=70.76%, Macro F1=70.76%
# Epoch 19: Train Acc=71.26%, Val Acc=71.29%, F1=71.88%, Macro F1=71.86%
# Epoch 20: Train Acc=71.33%, Val Acc=71.39%, F1=71.96%, Macro F1=71.95%
# Epoch 21: Train Acc=71.42%, Val Acc=71.56%, F1=71.02%, Macro F1=71.01%
# Epoch 22: Train Acc=71.49%, Val Acc=71.51%, F1=71.40%, Macro F1=71.39%
# Epoch 23: Train Acc=71.50%, Val Acc=71.76%, F1=72.29%, Macro F1=72.27%
# Epoch 24: Train Acc=71.53%, Val Acc=71.80%, F1=72.14%, Macro F1=72.13%
# Epoch 25: Train Acc=71.58%, Val Acc=71.90%, F1=71.90%, Macro F1=71.89%
# Epoch 26: Train Acc=71.65%, Val Acc=71.81%, F1=71.91%, Macro F1=71.90%
# Epoch 27: Train Acc=71.66%, Val Acc=71.74%, F1=72.37%, Macro F1=72.35%
# Epoch 28: Train Acc=71.72%, Val Acc=71.99%, F1=72.55%, Macro F1=72.53%
# Epoch 29: Train Acc=71.73%, Val Acc=71.62%, F1=71.35%, Macro F1=71.35%
# Epoch 30: Train Acc=71.78%, Val Acc=71.97%, F1=72.21%, Macro F1=72.20%
# Epoch 31: Train Acc=71.79%, Val Acc=71.97%, F1=72.13%, Macro F1=72.12%
# Epoch 32: Train Acc=71.82%, Val Acc=71.89%, F1=71.89%, Macro F1=71.88%
# Epoch 33: Train Acc=71.85%, Val Acc=71.70%, F1=71.46%, Macro F1=71.45%
# Epoch 34: Train Acc=71.89%, Val Acc=72.01%, F1=72.19%, Macro F1=72.18%
# Epoch 35: Train Acc=71.92%, Val Acc=72.03%, F1=72.40%, Macro F1=72.38%
# Epoch 36: Train Acc=71.93%, Val Acc=72.18%, F1=72.73%, Macro F1=72.71%
# Epoch 37: Train Acc=71.96%, Val Acc=72.19%, F1=72.77%, Macro F1=72.76%
# Epoch 38: Train Acc=71.96%, Val Acc=71.97%, F1=72.26%, Macro F1=72.25%
# Epoch 39: Train Acc=72.04%, Val Acc=71.98%, F1=72.60%, Macro F1=72.58%
# Epoch 40: Train Acc=71.97%, Val Acc=72.17%, F1=72.78%, Macro F1=72.76%
# Epoch 41: Train Acc=72.04%, Val Acc=72.02%, F1=71.86%, Macro F1=71.85%
# Epoch 42: Train Acc=72.09%, Val Acc=71.98%, F1=72.50%, Macro F1=72.49%
# Epoch 43: Train Acc=72.04%, Val Acc=72.08%, F1=72.66%, Macro F1=72.65%
# Epoch 44: Train Acc=72.06%, Val Acc=72.15%, F1=72.82%, Macro F1=72.80%
# Epoch 45: Train Acc=72.11%, Val Acc=72.03%, F1=72.57%, Macro F1=72.56%
# Epoch 46: Train Acc=72.17%, Val Acc=72.39%, F1=72.85%, Macro F1=72.83%
# Epoch 47: Train Acc=72.23%, Val Acc=72.18%, F1=72.04%, Macro F1=72.04%
# Epoch 48: Train Acc=72.23%, Val Acc=71.83%, F1=72.49%, Macro F1=72.47%
# Epoch 49: Train Acc=72.22%, Val Acc=72.41%, F1=72.94%, Macro F1=72.93%
# Epoch 50: Train Acc=72.26%, Val Acc=72.27%, F1=72.85%, Macro F1=72.84%
# Epoch 51: Train Acc=72.24%, Val Acc=72.14%, F1=72.12%, Macro F1=72.11%
# Epoch 52: Train Acc=72.29%, Val Acc=72.52%, F1=72.85%, Macro F1=72.84%
# Epoch 53: Train Acc=72.29%, Val Acc=72.59%, F1=72.93%, Macro F1=72.92%
# Epoch 54: Train Acc=72.34%, Val Acc=72.32%, F1=72.44%, Macro F1=72.43%
# Epoch 55: Train Acc=72.32%, Val Acc=72.47%, F1=72.71%, Macro F1=72.70%
# Epoch 56: Train Acc=72.38%, Val Acc=72.28%, F1=72.65%, Macro F1=72.64%
# Epoch 57: Train Acc=72.41%, Val Acc=72.46%, F1=72.67%, Macro F1=72.65%
# Epoch 58: Train Acc=72.39%, Val Acc=72.52%, F1=73.19%, Macro F1=73.18%
# Epoch 59: Train Acc=72.39%, Val Acc=72.51%, F1=73.10%, Macro F1=73.09%
# Epoch 60: Train Acc=72.41%, Val Acc=72.59%, F1=73.01%, Macro F1=72.99%
# Epoch 61: Train Acc=72.43%, Val Acc=72.46%, F1=72.43%, Macro F1=72.42%
# Epoch 62: Train Acc=72.43%, Val Acc=72.26%, F1=72.43%, Macro F1=72.42%
# Epoch 63: Train Acc=72.50%, Val Acc=72.66%, F1=73.06%, Macro F1=73.05%
# Epoch 64: Train Acc=72.49%, Val Acc=72.63%, F1=72.82%, Macro F1=72.81%
# Epoch 65: Train Acc=72.50%, Val Acc=72.46%, F1=72.89%, Macro F1=72.88%
# Epoch 66: Train Acc=72.52%, Val Acc=72.70%, F1=73.30%, Macro F1=73.29%
# Epoch 67: Train Acc=72.51%, Val Acc=72.46%, F1=72.80%, Macro F1=72.79%
# Epoch 68: Train Acc=72.50%, Val Acc=72.75%, F1=73.42%, Macro F1=73.40%
# ...
# Epoch 181: Train Acc=73.17%, Val Acc=72.96%, F1=73.34%, Macro F1=73.33%
# Epoch 182: Train Acc=73.19%, Val Acc=73.34%, F1=73.78%, Macro F1=73.77%
# Epoch 183: Train Acc=73.19%, Val Acc=73.07%, F1=73.81%, Macro F1=73.79%
# Epoch 184: Train Acc=73.20%, Val Acc=73.07%, F1=73.23%, Macro F1=73.22%
# Epoch 185: Train Acc=73.20%, Val Acc=73.09%, F1=73.85%, Macro F1=73.83%
# Epoch 186: Train Acc=73.19%, Val Acc=73.31%, F1=73.91%, Macro F1=73.90%
# Epoch 187: Train Acc=73.22%, Val Acc=72.93%, F1=73.59%, Macro F1=73.58%
# Epoch 188: Train Acc=73.20%, Val Acc=73.31%, F1=73.80%, Macro F1=73.78%
# Epoch 189: Train Acc=73.21%, Val Acc=73.06%, F1=73.77%, Macro F1=73.76%
# Epoch 190: Train Acc=73.21%, Val Acc=73.18%, F1=73.90%, Macro F1=73.88%
# Epoch 191: Train Acc=73.21%, Val Acc=73.28%, F1=73.81%, Macro F1=73.80%
# Epoch 192: Train Acc=73.24%, Val Acc=73.09%, F1=73.77%, Macro F1=73.75%
# Epoch 193: Train Acc=73.21%, Val Acc=73.12%, F1=73.26%, Macro F1=73.25%
# Epoch 194: Train Acc=73.22%, Val Acc=73.37%, F1=73.78%, Macro F1=73.77%
# Epoch 195: Train Acc=73.22%, Val Acc=73.22%, F1=73.71%, Macro F1=73.70%
# Epoch 196: Train Acc=73.23%, Val Acc=73.23%, F1=73.73%, Macro F1=73.71%
# Epoch 197: Train Acc=73.20%, Val Acc=73.12%, F1=73.58%, Macro F1=73.57%
# Epoch 198: Train Acc=73.22%, Val Acc=73.22%, F1=73.74%, Macro F1=73.73%
# Epoch 199: Train Acc=73.21%, Val Acc=73.33%, F1=74.03%, Macro F1=74.01%
# Epoch 200: Train Acc=73.27%, Val Acc=73.24%, F1=73.70%, Macro F1=73.69%
#
# Fold 5/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=55.07%, Val Acc=63.99%, F1=63.11%, Macro F1=63.21%
# Epoch 2: Train Acc=65.79%, Val Acc=67.21%, F1=66.41%, Macro F1=66.50%
# Epoch 3: Train Acc=68.06%, Val Acc=68.45%, F1=68.66%, Macro F1=68.75%
# Epoch 4: Train Acc=68.78%, Val Acc=68.96%, F1=68.52%, Macro F1=68.61%
# Epoch 5: Train Acc=69.26%, Val Acc=69.33%, F1=69.66%, Macro F1=69.75%
# Epoch 6: Train Acc=69.61%, Val Acc=69.85%, F1=69.88%, Macro F1=69.96%
# Epoch 7: Train Acc=69.89%, Val Acc=69.92%, F1=69.90%, Macro F1=69.99%
# Epoch 8: Train Acc=70.17%, Val Acc=70.19%, F1=69.69%, Macro F1=69.78%
# Epoch 9: Train Acc=70.30%, Val Acc=70.47%, F1=70.20%, Macro F1=70.29%
# Epoch 10: Train Acc=70.50%, Val Acc=70.45%, F1=70.01%, Macro F1=70.10%
# Epoch 11: Train Acc=70.59%, Val Acc=70.34%, F1=70.24%, Macro F1=70.33%
# Epoch 12: Train Acc=70.76%, Val Acc=70.57%, F1=70.75%, Macro F1=70.83%
# Epoch 13: Train Acc=70.84%, Val Acc=70.79%, F1=70.75%, Macro F1=70.84%
# Epoch 14: Train Acc=70.91%, Val Acc=70.79%, F1=70.41%, Macro F1=70.50%
# Epoch 15: Train Acc=71.00%, Val Acc=70.87%, F1=70.85%, Macro F1=70.94%
# Epoch 16: Train Acc=71.06%, Val Acc=70.83%, F1=71.37%, Macro F1=71.46%
# Epoch 17: Train Acc=71.17%, Val Acc=71.03%, F1=71.05%, Macro F1=71.14%
# Epoch 18: Train Acc=71.20%, Val Acc=71.13%, F1=71.05%, Macro F1=71.14%
# Epoch 19: Train Acc=71.29%, Val Acc=71.16%, F1=71.82%, Macro F1=71.90%
# Epoch 20: Train Acc=71.34%, Val Acc=71.16%, F1=71.13%, Macro F1=71.22%
# Epoch 21: Train Acc=71.38%, Val Acc=71.21%, F1=71.65%, Macro F1=71.74%
# Epoch 22: Train Acc=71.45%, Val Acc=71.19%, F1=71.44%, Macro F1=71.52%
# Epoch 23: Train Acc=71.48%, Val Acc=70.80%, F1=71.54%, Macro F1=71.63%
# Epoch 24: Train Acc=71.51%, Val Acc=71.47%, F1=71.38%, Macro F1=71.47%
# Epoch 25: Train Acc=71.58%, Val Acc=71.43%, F1=71.89%, Macro F1=71.98%
# Epoch 26: Train Acc=71.67%, Val Acc=71.51%, F1=71.68%, Macro F1=71.77%
# Epoch 27: Train Acc=71.74%, Val Acc=71.51%, F1=71.73%, Macro F1=71.82%
# Epoch 28: Train Acc=71.71%, Val Acc=71.27%, F1=70.90%, Macro F1=70.99%
# Epoch 29: Train Acc=71.80%, Val Acc=71.53%, F1=72.08%, Macro F1=72.17%
# Epoch 30: Train Acc=71.81%, Val Acc=71.55%, F1=71.24%, Macro F1=71.33%
# Epoch 31: Train Acc=71.88%, Val Acc=71.68%, F1=71.43%, Macro F1=71.52%
# Epoch 32: Train Acc=71.88%, Val Acc=71.76%, F1=72.31%, Macro F1=72.39%
# Epoch 33: Train Acc=71.89%, Val Acc=71.64%, F1=71.96%, Macro F1=72.05%
# Epoch 34: Train Acc=71.91%, Val Acc=71.62%, F1=72.20%, Macro F1=72.28%
# Epoch 35: Train Acc=71.96%, Val Acc=71.73%, F1=71.91%, Macro F1=72.00%
# Epoch 36: Train Acc=72.04%, Val Acc=71.81%, F1=72.27%, Macro F1=72.36%
# Epoch 37: Train Acc=72.02%, Val Acc=71.64%, F1=72.23%, Macro F1=72.31%
# Epoch 38: Train Acc=72.04%, Val Acc=71.90%, F1=72.39%, Macro F1=72.48%
# Epoch 39: Train Acc=72.08%, Val Acc=71.65%, F1=71.78%, Macro F1=71.87%
# Epoch 40: Train Acc=72.08%, Val Acc=71.92%, F1=72.39%, Macro F1=72.47%
# Epoch 41: Train Acc=72.18%, Val Acc=71.82%, F1=72.25%, Macro F1=72.34%
# Epoch 42: Train Acc=72.16%, Val Acc=71.40%, F1=71.23%, Macro F1=71.32%
# Epoch 43: Train Acc=72.17%, Val Acc=71.99%, F1=72.60%, Macro F1=72.68%
# Epoch 44: Train Acc=72.18%, Val Acc=72.10%, F1=72.64%, Macro F1=72.73%
# Epoch 45: Train Acc=72.23%, Val Acc=71.96%, F1=72.20%, Macro F1=72.29%
# Epoch 46: Train Acc=72.23%, Val Acc=72.00%, F1=72.00%, Macro F1=72.09%
# Epoch 47: Train Acc=72.28%, Val Acc=71.91%, F1=72.43%, Macro F1=72.52%
# Epoch 48: Train Acc=72.31%, Val Acc=72.05%, F1=72.32%, Macro F1=72.41%
# Epoch 49: Train Acc=72.32%, Val Acc=72.13%, F1=72.35%, Macro F1=72.43%
# Epoch 50: Train Acc=72.34%, Val Acc=72.19%, F1=72.58%, Macro F1=72.67%
# Epoch 51: Train Acc=72.36%, Val Acc=72.15%, F1=72.33%, Macro F1=72.42%
# Epoch 52: Train Acc=72.43%, Val Acc=71.97%, F1=71.90%, Macro F1=71.99%
# Epoch 53: Train Acc=72.46%, Val Acc=72.17%, F1=72.71%, Macro F1=72.80%
# Epoch 54: Train Acc=72.39%, Val Acc=72.29%, F1=72.80%, Macro F1=72.88%
# Epoch 55: Train Acc=72.41%, Val Acc=72.13%, F1=72.81%, Macro F1=72.89%
# Epoch 56: Train Acc=72.48%, Val Acc=72.16%, F1=72.99%, Macro F1=73.08%
# Epoch 57: Train Acc=72.50%, Val Acc=72.39%, F1=73.18%, Macro F1=73.27%
# Epoch 58: Train Acc=72.47%, Val Acc=72.16%, F1=72.73%, Macro F1=72.81%
# Epoch 59: Train Acc=72.50%, Val Acc=72.16%, F1=72.79%, Macro F1=72.88%
# Epoch 60: Train Acc=72.49%, Val Acc=72.16%, F1=72.39%, Macro F1=72.48%
# Epoch 61: Train Acc=72.53%, Val Acc=72.38%, F1=72.93%, Macro F1=73.01%
# Epoch 62: Train Acc=72.50%, Val Acc=72.30%, F1=73.07%, Macro F1=73.15%
# Epoch 63: Train Acc=72.49%, Val Acc=72.33%, F1=73.00%, Macro F1=73.09%
# Epoch 64: Train Acc=72.58%, Val Acc=72.29%, F1=73.04%, Macro F1=73.13%
# Epoch 65: Train Acc=72.57%, Val Acc=72.31%, F1=73.05%, Macro F1=73.14%
# Epoch 66: Train Acc=72.63%, Val Acc=72.03%, F1=72.59%, Macro F1=72.68%
# Epoch 67: Train Acc=72.52%, Val Acc=72.05%, F1=72.82%, Macro F1=72.90%
# Epoch 68: Train Acc=72.60%, Val Acc=72.38%, F1=72.86%, Macro F1=72.94%
# Epoch 69: Train Acc=72.65%, Val Acc=70.69%, F1=71.31%, Macro F1=71.39%
# Epoch 70: Train Acc=72.64%, Val Acc=72.34%, F1=72.97%, Macro F1=73.06%
# Epoch 71: Train Acc=72.63%, Val Acc=72.39%, F1=73.01%, Macro F1=73.09%
# Epoch 72: Train Acc=72.64%, Val Acc=72.47%, F1=73.18%, Macro F1=73.26%
# Epoch 73: Train Acc=72.68%, Val Acc=72.09%, F1=72.87%, Macro F1=72.95%
# Epoch 74: Train Acc=72.71%, Val Acc=72.36%, F1=73.12%, Macro F1=73.20%
# Epoch 75: Train Acc=72.65%, Val Acc=72.51%, F1=73.31%, Macro F1=73.40%
# Epoch 76: Train Acc=72.72%, Val Acc=72.43%, F1=72.98%, Macro F1=73.07%
# Epoch 77: Train Acc=72.72%, Val Acc=72.50%, F1=72.99%, Macro F1=73.07%
# Epoch 78: Train Acc=72.71%, Val Acc=72.53%, F1=73.05%, Macro F1=73.14%
# Epoch 79: Train Acc=72.72%, Val Acc=72.45%, F1=73.09%, Macro F1=73.17%
# Epoch 80: Train Acc=72.71%, Val Acc=72.48%, F1=73.04%, Macro F1=73.12%
# Epoch 81: Train Acc=72.80%, Val Acc=72.41%, F1=72.74%, Macro F1=72.83%
# Epoch 82: Train Acc=72.73%, Val Acc=72.33%, F1=73.09%, Macro F1=73.17%
# Epoch 83: Train Acc=72.76%, Val Acc=72.43%, F1=72.82%, Macro F1=72.91%
# Epoch 84: Train Acc=72.77%, Val Acc=72.11%, F1=72.71%, Macro F1=72.80%
# Epoch 85: Train Acc=72.74%, Val Acc=72.44%, F1=72.50%, Macro F1=72.58%
# Epoch 86: Train Acc=72.78%, Val Acc=72.49%, F1=73.12%, Macro F1=73.20%
# Epoch 87: Train Acc=72.83%, Val Acc=72.59%, F1=73.33%, Macro F1=73.42%
# Epoch 88: Train Acc=72.87%, Val Acc=72.44%, F1=72.86%, Macro F1=72.95%
# Epoch 89: Train Acc=72.87%, Val Acc=72.55%, F1=73.31%, Macro F1=73.40%
# Epoch 90: Train Acc=72.85%, Val Acc=72.59%, F1=73.33%, Macro F1=73.41%
# Epoch 91: Train Acc=72.81%, Val Acc=72.59%, F1=73.28%, Macro F1=73.37%
# Epoch 92: Train Acc=72.84%, Val Acc=72.67%, F1=73.24%, Macro F1=73.32%
# Epoch 93: Train Acc=72.86%, Val Acc=72.63%, F1=73.09%, Macro F1=73.17%
# Epoch 94: Train Acc=72.85%, Val Acc=72.60%, F1=73.15%, Macro F1=73.23%
# Epoch 95: Train Acc=72.83%, Val Acc=72.57%, F1=73.19%, Macro F1=73.27%
# Epoch 96: Train Acc=72.85%, Val Acc=72.59%, F1=73.31%, Macro F1=73.39%
# Epoch 97: Train Acc=72.89%, Val Acc=72.49%, F1=73.29%, Macro F1=73.38%
# Epoch 98: Train Acc=72.90%, Val Acc=72.79%, F1=73.48%, Macro F1=73.56%
# Epoch 99: Train Acc=72.91%, Val Acc=72.68%, F1=73.42%, Macro F1=73.51%
# Epoch 100: Train Acc=72.89%, Val Acc=72.45%, F1=73.23%, Macro F1=73.32%
# Epoch 101: Train Acc=72.92%, Val Acc=72.59%, F1=73.33%, Macro F1=73.42%
# Epoch 102: Train Acc=72.92%, Val Acc=72.39%, F1=73.03%, Macro F1=73.12%
# Epoch 103: Train Acc=72.92%, Val Acc=72.62%, F1=73.35%, Macro F1=73.44%
# Epoch 104: Train Acc=72.96%, Val Acc=72.84%, F1=73.27%, Macro F1=73.35%
# Epoch 105: Train Acc=72.97%, Val Acc=72.30%, F1=72.97%, Macro F1=73.06%
# Epoch 106: Train Acc=72.96%, Val Acc=72.83%, F1=73.55%, Macro F1=73.63%
# Epoch 107: Train Acc=73.04%, Val Acc=72.63%, F1=73.21%, Macro F1=73.29%
# Epoch 108: Train Acc=73.03%, Val Acc=72.58%, F1=73.15%, Macro F1=73.24%
# Epoch 109: Train Acc=73.02%, Val Acc=72.76%, F1=73.53%, Macro F1=73.61%
# Epoch 110: Train Acc=73.00%, Val Acc=72.59%, F1=73.24%, Macro F1=73.32%
# Epoch 111: Train Acc=73.03%, Val Acc=72.82%, F1=73.30%, Macro F1=73.39%
# Epoch 112: Train Acc=72.99%, Val Acc=72.52%, F1=73.30%, Macro F1=73.39%
# Epoch 113: Train Acc=73.02%, Val Acc=72.86%, F1=73.48%, Macro F1=73.56%
# Epoch 114: Train Acc=73.04%, Val Acc=72.79%, F1=73.51%, Macro F1=73.60%
# Epoch 115: Train Acc=73.05%, Val Acc=72.76%, F1=73.24%, Macro F1=73.32%
# Epoch 116: Train Acc=73.02%, Val Acc=72.77%, F1=73.52%, Macro F1=73.60%
# Epoch 117: Train Acc=73.02%, Val Acc=72.88%, F1=73.39%, Macro F1=73.48%
# Epoch 118: Train Acc=73.09%, Val Acc=72.81%, F1=73.46%, Macro F1=73.54%
# Epoch 119: Train Acc=73.07%, Val Acc=72.83%, F1=73.38%, Macro F1=73.47%
# Epoch 120: Train Acc=73.06%, Val Acc=72.85%, F1=73.53%, Macro F1=73.61%
# Epoch 121: Train Acc=73.06%, Val Acc=72.90%, F1=73.62%, Macro F1=73.70%
# Epoch 122: Train Acc=73.09%, Val Acc=72.70%, F1=73.43%, Macro F1=73.51%
# Epoch 123: Train Acc=73.11%, Val Acc=72.73%, F1=73.46%, Macro F1=73.54%
# Epoch 124: Train Acc=73.11%, Val Acc=72.73%, F1=73.01%, Macro F1=73.10%
# Epoch 125: Train Acc=73.09%, Val Acc=72.43%, F1=72.92%, Macro F1=73.00%
# Epoch 126: Train Acc=73.08%, Val Acc=72.69%, F1=72.69%, Macro F1=72.77%
# Epoch 127: Train Acc=73.14%, Val Acc=72.83%, F1=73.56%, Macro F1=73.64%
# Epoch 128: Train Acc=73.14%, Val Acc=72.89%, F1=73.50%, Macro F1=73.58%
# Epoch 129: Train Acc=73.15%, Val Acc=73.09%, F1=73.70%, Macro F1=73.78%
# Epoch 130: Train Acc=73.14%, Val Acc=72.96%, F1=73.57%, Macro F1=73.66%
# Epoch 131: Train Acc=73.17%, Val Acc=72.72%, F1=73.47%, Macro F1=73.56%
# Epoch 132: Train Acc=73.15%, Val Acc=72.82%, F1=73.48%, Macro F1=73.57%
# Epoch 133: Train Acc=73.20%, Val Acc=72.92%, F1=73.63%, Macro F1=73.72%
# Epoch 134: Train Acc=73.15%, Val Acc=72.77%, F1=73.56%, Macro F1=73.64%
# Epoch 135: Train Acc=73.16%, Val Acc=72.92%, F1=73.70%, Macro F1=73.78%
# Epoch 136: Train Acc=73.19%, Val Acc=72.73%, F1=73.44%, Macro F1=73.53%
# Epoch 137: Train Acc=73.17%, Val Acc=72.91%, F1=73.60%, Macro F1=73.68%
# Epoch 138: Train Acc=73.18%, Val Acc=72.95%, F1=73.64%, Macro F1=73.72%
# Epoch 139: Train Acc=73.22%, Val Acc=72.83%, F1=73.55%, Macro F1=73.63%
# Epoch 140: Train Acc=73.16%, Val Acc=72.92%, F1=73.63%, Macro F1=73.71%
# Epoch 141: Train Acc=73.23%, Val Acc=72.84%, F1=73.58%, Macro F1=73.66%
# Epoch 142: Train Acc=73.21%, Val Acc=72.84%, F1=73.51%, Macro F1=73.59%
# Epoch 143: Train Acc=73.18%, Val Acc=72.96%, F1=73.57%, Macro F1=73.66%
# Epoch 144: Train Acc=73.19%, Val Acc=72.98%, F1=73.28%, Macro F1=73.37%
# Epoch 145: Train Acc=73.22%, Val Acc=72.96%, F1=73.68%, Macro F1=73.77%
# Epoch 146: Train Acc=73.24%, Val Acc=73.01%, F1=73.52%, Macro F1=73.60%
# Epoch 147: Train Acc=73.21%, Val Acc=73.13%, F1=73.70%, Macro F1=73.79%
# Epoch 148: Train Acc=73.26%, Val Acc=73.04%, F1=73.48%, Macro F1=73.56%
# Epoch 149: Train Acc=73.23%, Val Acc=72.67%, F1=73.41%, Macro F1=73.50%
# Epoch 150: Train Acc=73.23%, Val Acc=72.99%, F1=73.70%, Macro F1=73.78%
# Epoch 151: Train Acc=73.30%, Val Acc=72.94%, F1=73.60%, Macro F1=73.69%
# Epoch 152: Train Acc=73.25%, Val Acc=73.02%, F1=73.71%, Macro F1=73.80%
# Epoch 153: Train Acc=73.24%, Val Acc=73.01%, F1=73.69%, Macro F1=73.77%
# Epoch 154: Train Acc=73.29%, Val Acc=73.06%, F1=73.66%, Macro F1=73.74%
# Epoch 155: Train Acc=73.33%, Val Acc=72.99%, F1=73.76%, Macro F1=73.84%
# Epoch 156: Train Acc=73.27%, Val Acc=72.91%, F1=73.62%, Macro F1=73.70%
# Epoch 157: Train Acc=73.30%, Val Acc=72.96%, F1=73.63%, Macro F1=73.71%
# Epoch 158: Train Acc=73.25%, Val Acc=73.08%, F1=73.70%, Macro F1=73.78%
# Epoch 159: Train Acc=73.28%, Val Acc=72.78%, F1=73.54%, Macro F1=73.62%
# Epoch 160: Train Acc=73.29%, Val Acc=73.02%, F1=73.76%, Macro F1=73.85%
# Epoch 161: Train Acc=73.29%, Val Acc=72.98%, F1=73.50%, Macro F1=73.59%
# Epoch 162: Train Acc=73.29%, Val Acc=72.89%, F1=73.64%, Macro F1=73.72%
# Epoch 163: Train Acc=73.29%, Val Acc=72.95%, F1=73.21%, Macro F1=73.29%
# Epoch 164: Train Acc=73.24%, Val Acc=72.91%, F1=73.65%, Macro F1=73.74%
# Epoch 165: Train Acc=73.33%, Val Acc=72.94%, F1=73.71%, Macro F1=73.79%
# Epoch 166: Train Acc=73.32%, Val Acc=73.07%, F1=73.75%, Macro F1=73.84%
# Epoch 167: Train Acc=73.30%, Val Acc=73.14%, F1=73.58%, Macro F1=73.66%
# Epoch 168: Train Acc=73.33%, Val Acc=73.06%, F1=73.67%, Macro F1=73.76%
# Epoch 169: Train Acc=73.30%, Val Acc=73.08%, F1=73.78%, Macro F1=73.87%
# Epoch 170: Train Acc=73.32%, Val Acc=73.05%, F1=73.74%, Macro F1=73.82%
# Epoch 171: Train Acc=73.35%, Val Acc=73.01%, F1=73.70%, Macro F1=73.79%
# Epoch 172: Train Acc=73.35%, Val Acc=73.17%, F1=73.72%, Macro F1=73.81%
# Epoch 173: Train Acc=73.34%, Val Acc=73.08%, F1=73.65%, Macro F1=73.73%
# Epoch 174: Train Acc=73.29%, Val Acc=73.23%, F1=73.62%, Macro F1=73.70%
# Epoch 175: Train Acc=73.29%, Val Acc=73.15%, F1=73.85%, Macro F1=73.93%
# Epoch 176: Train Acc=73.36%, Val Acc=73.15%, F1=73.87%, Macro F1=73.95%
# Epoch 177: Train Acc=73.36%, Val Acc=73.15%, F1=73.69%, Macro F1=73.77%
# Epoch 178: Train Acc=73.36%, Val Acc=73.14%, F1=73.80%, Macro F1=73.89%
# Epoch 179: Train Acc=73.30%, Val Acc=73.09%, F1=73.57%, Macro F1=73.65%
# Epoch 180: Train Acc=73.33%, Val Acc=73.19%, F1=73.72%, Macro F1=73.81%
# Epoch 181: Train Acc=73.35%, Val Acc=72.98%, F1=73.17%, Macro F1=73.26%
# Epoch 182: Train Acc=73.32%, Val Acc=73.11%, F1=73.81%, Macro F1=73.90%
# Epoch 183: Train Acc=73.39%, Val Acc=72.87%, F1=73.52%, Macro F1=73.61%
# Epoch 184: Train Acc=73.37%, Val Acc=73.19%, F1=73.68%, Macro F1=73.76%
# Epoch 185: Train Acc=73.36%, Val Acc=72.96%, F1=73.61%, Macro F1=73.69%
# Epoch 186: Train Acc=73.36%, Val Acc=73.21%, F1=73.84%, Macro F1=73.92%
# Epoch 187: Train Acc=73.35%, Val Acc=73.12%, F1=73.54%, Macro F1=73.62%
# Epoch 188: Train Acc=73.35%, Val Acc=72.99%, F1=73.73%, Macro F1=73.81%
# Epoch 189: Train Acc=73.39%, Val Acc=73.09%, F1=73.74%, Macro F1=73.82%
# Epoch 190: Train Acc=73.37%, Val Acc=73.28%, F1=73.78%, Macro F1=73.87%
# Epoch 191: Train Acc=73.38%, Val Acc=73.17%, F1=73.65%, Macro F1=73.73%
# Epoch 192: Train Acc=73.44%, Val Acc=73.18%, F1=73.82%, Macro F1=73.90%
# Epoch 193: Train Acc=73.36%, Val Acc=73.17%, F1=73.72%, Macro F1=73.80%
# Epoch 194: Train Acc=73.34%, Val Acc=73.18%, F1=73.75%, Macro F1=73.83%
# Epoch 195: Train Acc=73.36%, Val Acc=73.02%, F1=73.71%, Macro F1=73.79%
# Epoch 196: Train Acc=73.40%, Val Acc=72.93%, F1=73.68%, Macro F1=73.76%
# Epoch 197: Train Acc=73.41%, Val Acc=73.14%, F1=73.84%, Macro F1=73.92%
# Epoch 198: Train Acc=73.42%, Val Acc=73.00%, F1=73.28%, Macro F1=73.37%
# Epoch 199: Train Acc=73.45%, Val Acc=73.14%, F1=73.66%, Macro F1=73.75%
# Epoch 200: Train Acc=73.39%, Val Acc=73.16%, F1=73.90%, Macro F1=73.98%
#
# Cross-Validation Results:
# Avg Validation Accuracy: 73.24%
# Avg Weighted F1-score: 73.87%
# Avg Macro F1-score: 73.87%
# Avg Validation Loss: 0.656015

# %%
loss_fn = nn.CrossEntropyLoss()
#loss_fn = FocalLoss(alpha=0.5, gamma = 1)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001,weight_decay=1e-4) #using L2 regularization

epochs = 200
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!") #wider network
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.901785, F1-score: 71.09%, Macro_F1-Score:  41.80%
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.887541, F1-score: 71.08%, Macro_F1-Score:  42.65%
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.890812, F1-score: 71.28%, Macro_F1-Score:  42.44%
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.890898, F1-score: 71.22%, Macro_F1-Score:  42.75%
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.890682, F1-score: 71.43%, Macro_F1-Score:  42.38%
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.887698, F1-score: 71.18%, Macro_F1-Score:  42.42%
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.895796, F1-score: 71.24%, Macro_F1-Score:  42.21%
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.888631, F1-score: 71.34%, Macro_F1-Score:  42.75%
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.901912, F1-score: 71.41%, Macro_F1-Score:  42.84%
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.886111, F1-score: 71.42%, Macro_F1-Score:  42.32%
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.897005, F1-score: 71.17%, Macro_F1-Score:  42.72%
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 64.7%, Avg loss: 0.900576, F1-score: 70.89%, Macro_F1-Score:  42.33%
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.896753, F1-score: 71.01%, Macro_F1-Score:  42.03%
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.882312, F1-score: 71.04%, Macro_F1-Score:  41.94%
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.887315, F1-score: 71.29%, Macro_F1-Score:  42.83%
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.893248, F1-score: 71.22%, Macro_F1-Score:  42.40%
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.898463, F1-score: 71.12%, Macro_F1-Score:  42.21%
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.902894, F1-score: 71.25%, Macro_F1-Score:  42.16%
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.897836, F1-score: 71.50%, Macro_F1-Score:  42.41%
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.895768, F1-score: 71.16%, Macro_F1-Score:  42.59%
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 64.7%, Avg loss: 0.923157, F1-score: 70.92%, Macro_F1-Score:  42.26%
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.889157, F1-score: 71.26%, Macro_F1-Score:  42.92%
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.888073, F1-score: 71.33%, Macro_F1-Score:  42.47%
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.880852, F1-score: 71.23%, Macro_F1-Score:  42.49%
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.882618, F1-score: 71.35%, Macro_F1-Score:  42.42%
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 64.6%, Avg loss: 0.913542, F1-score: 70.82%, Macro_F1-Score:  41.81%
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.893183, F1-score: 71.30%, Macro_F1-Score:  42.74%
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.899907, F1-score: 71.10%, Macro_F1-Score:  43.19%
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.885887, F1-score: 71.02%, Macro_F1-Score:  41.76%
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.915930, F1-score: 71.06%, Macro_F1-Score:  42.42%
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.901609, F1-score: 71.17%, Macro_F1-Score:  42.45%
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.897368, F1-score: 71.21%, Macro_F1-Score:  42.27%
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.890819, F1-score: 71.29%, Macro_F1-Score:  42.77%
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 64.6%, Avg loss: 0.915212, F1-score: 70.81%, Macro_F1-Score:  42.22%
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.881613, F1-score: 71.49%, Macro_F1-Score:  42.44%
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.886202, F1-score: 71.27%, Macro_F1-Score:  42.27%
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.899571, F1-score: 71.20%, Macro_F1-Score:  42.51%
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.892059, F1-score: 71.29%, Macro_F1-Score:  42.64%
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.886867, F1-score: 71.39%, Macro_F1-Score:  42.50%
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.902299, F1-score: 71.17%, Macro_F1-Score:  42.49%
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.880148, F1-score: 71.58%, Macro_F1-Score:  43.33%
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.886175, F1-score: 71.22%, Macro_F1-Score:  42.33%
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.913803, F1-score: 71.14%, Macro_F1-Score:  42.34%
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.911763, F1-score: 71.01%, Macro_F1-Score:  42.42%
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.902660, F1-score: 71.06%, Macro_F1-Score:  41.87%
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.897642, F1-score: 71.11%, Macro_F1-Score:  42.12%
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 64.7%, Avg loss: 0.909393, F1-score: 70.85%, Macro_F1-Score:  41.86%
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.891459, F1-score: 71.29%, Macro_F1-Score:  42.70%
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.909006, F1-score: 71.17%, Macro_F1-Score:  42.40%
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.876494, F1-score: 71.52%, Macro_F1-Score:  42.57%
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.883172, F1-score: 71.55%, Macro_F1-Score:  43.20%
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.894008, F1-score: 71.01%, Macro_F1-Score:  42.40%
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.885534, F1-score: 71.30%, Macro_F1-Score:  42.69%
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.883936, F1-score: 71.37%, Macro_F1-Score:  42.70%
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.905395, F1-score: 71.19%, Macro_F1-Score:  42.80%
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.871599, F1-score: 71.28%, Macro_F1-Score:  42.17%
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.883043, F1-score: 71.33%, Macro_F1-Score:  42.76%
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.873273, F1-score: 71.67%, Macro_F1-Score:  42.71%
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.871678, F1-score: 71.60%, Macro_F1-Score:  43.13%
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.903230, F1-score: 71.17%, Macro_F1-Score:  42.07%
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.897197, F1-score: 71.27%, Macro_F1-Score:  42.65%
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.891375, F1-score: 71.36%, Macro_F1-Score:  42.95%
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.880248, F1-score: 71.38%, Macro_F1-Score:  42.92%
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.904227, F1-score: 71.03%, Macro_F1-Score:  42.76%
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.880331, F1-score: 71.50%, Macro_F1-Score:  42.80%
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.889485, F1-score: 71.23%, Macro_F1-Score:  42.43%
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.882135, F1-score: 71.55%, Macro_F1-Score:  42.71%
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.872972, F1-score: 71.60%, Macro_F1-Score:  42.97%
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.878845, F1-score: 71.55%, Macro_F1-Score:  43.22%
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 64.6%, Avg loss: 0.910135, F1-score: 70.88%, Macro_F1-Score:  42.13%
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.904020, F1-score: 71.20%, Macro_F1-Score:  42.57%
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.890763, F1-score: 71.37%, Macro_F1-Score:  42.65%
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.901874, F1-score: 71.16%, Macro_F1-Score:  43.04%
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.900068, F1-score: 71.15%, Macro_F1-Score:  42.40%
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.905694, F1-score: 71.14%, Macro_F1-Score:  42.07%
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.894296, F1-score: 71.13%, Macro_F1-Score:  42.42%
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.886845, F1-score: 71.39%, Macro_F1-Score:  41.95%
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.903187, F1-score: 71.19%, Macro_F1-Score:  42.52%
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 64.8%, Avg loss: 0.904361, F1-score: 70.97%, Macro_F1-Score:  41.81%
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.898804, F1-score: 71.30%, Macro_F1-Score:  42.84%
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.902155, F1-score: 71.20%, Macro_F1-Score:  42.61%
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.901658, F1-score: 71.26%, Macro_F1-Score:  42.75%
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.890872, F1-score: 71.34%, Macro_F1-Score:  43.07%
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.881077, F1-score: 71.41%, Macro_F1-Score:  42.81%
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.898170, F1-score: 71.64%, Macro_F1-Score:  43.01%
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 64.7%, Avg loss: 0.920606, F1-score: 70.84%, Macro_F1-Score:  41.74%
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.882771, F1-score: 71.40%, Macro_F1-Score:  42.95%
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.888032, F1-score: 71.49%, Macro_F1-Score:  43.37%
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.885872, F1-score: 71.47%, Macro_F1-Score:  43.01%
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 64.8%, Avg loss: 0.906218, F1-score: 70.94%, Macro_F1-Score:  42.16%
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.902956, F1-score: 71.08%, Macro_F1-Score:  42.13%
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.905585, F1-score: 71.20%, Macro_F1-Score:  42.69%
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.895262, F1-score: 71.46%, Macro_F1-Score:  42.90%
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.877866, F1-score: 71.35%, Macro_F1-Score:  42.46%
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.908475, F1-score: 71.08%, Macro_F1-Score:  42.38%
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.895412, F1-score: 71.15%, Macro_F1-Score:  42.57%
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.898224, F1-score: 71.37%, Macro_F1-Score:  42.83%
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.898052, F1-score: 71.35%, Macro_F1-Score:  42.28%
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.886192, F1-score: 71.34%, Macro_F1-Score:  42.78%
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.898466, F1-score: 71.25%, Macro_F1-Score:  42.92%
#
# Epoch 101
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.887760, F1-score: 71.45%, Macro_F1-Score:  42.97%
#
# Epoch 102
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.918426, F1-score: 71.28%, Macro_F1-Score:  42.74%
#
# Epoch 103
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.907068, F1-score: 71.05%, Macro_F1-Score:  42.19%
#
# Epoch 104
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.884151, F1-score: 71.64%, Macro_F1-Score:  42.30%
#
# Epoch 105
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.904775, F1-score: 71.23%, Macro_F1-Score:  42.73%
#
# Epoch 106
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.894200, F1-score: 71.53%, Macro_F1-Score:  43.40%
#
# Epoch 107
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.901008, F1-score: 71.78%, Macro_F1-Score:  43.15%
#
# Epoch 108
# -------------------------------
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.882608, F1-score: 71.79%, Macro_F1-Score:  43.10%
#
# Epoch 109
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.911469, F1-score: 71.26%, Macro_F1-Score:  42.64%
#
# Epoch 110
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.901321, F1-score: 71.38%, Macro_F1-Score:  42.66%
#
# Epoch 111
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.909943, F1-score: 71.23%, Macro_F1-Score:  42.88%
#
# Epoch 112
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.902350, F1-score: 71.32%, Macro_F1-Score:  42.57%
#
# Epoch 113
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.891121, F1-score: 71.40%, Macro_F1-Score:  42.79%
#
# Epoch 114
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.914310, F1-score: 71.34%, Macro_F1-Score:  42.89%
#
# Epoch 115
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.895664, F1-score: 71.28%, Macro_F1-Score:  42.66%
#
# Epoch 116
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.909762, F1-score: 71.00%, Macro_F1-Score:  42.29%
#
# Epoch 117
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.882940, F1-score: 71.73%, Macro_F1-Score:  43.07%
#
# Epoch 118
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.915460, F1-score: 71.35%, Macro_F1-Score:  42.93%
#
# Epoch 119
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.895902, F1-score: 71.32%, Macro_F1-Score:  42.84%
#
# Epoch 120
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.887196, F1-score: 71.68%, Macro_F1-Score:  43.08%
#
# Epoch 121
# -------------------------------
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.882586, F1-score: 71.81%, Macro_F1-Score:  43.03%
#
# Epoch 122
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.877657, F1-score: 71.63%, Macro_F1-Score:  43.07%
#
# Epoch 123
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.904870, F1-score: 71.38%, Macro_F1-Score:  42.79%
#
# Epoch 124
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.880531, F1-score: 71.54%, Macro_F1-Score:  43.12%
#
# Epoch 125
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.899154, F1-score: 71.21%, Macro_F1-Score:  42.23%
#
# Epoch 126
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.890547, F1-score: 71.56%, Macro_F1-Score:  43.24%
#
# Epoch 127
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.915186, F1-score: 71.20%, Macro_F1-Score:  42.54%
#
# Epoch 128
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.883968, F1-score: 71.64%, Macro_F1-Score:  43.52%
#
# Epoch 129
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.891632, F1-score: 71.54%, Macro_F1-Score:  42.46%
#
# Epoch 130
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.919416, F1-score: 71.30%, Macro_F1-Score:  42.98%
#
# Epoch 131
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.887298, F1-score: 71.42%, Macro_F1-Score:  42.26%
#
# Epoch 132
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.917263, F1-score: 71.11%, Macro_F1-Score:  42.44%
#
# Epoch 133
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.906089, F1-score: 71.27%, Macro_F1-Score:  43.06%
#
# Epoch 134
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.904584, F1-score: 71.40%, Macro_F1-Score:  43.01%
#
# Epoch 135
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.905490, F1-score: 71.49%, Macro_F1-Score:  43.03%
#
# Epoch 136
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.889998, F1-score: 71.36%, Macro_F1-Score:  42.67%
#
# Epoch 137
# -------------------------------
# Test Error:
#  Accuracy: 66.2%, Avg loss: 0.871394, F1-score: 71.98%, Macro_F1-Score:  43.47%
#
# Epoch 138
# -------------------------------
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.884141, F1-score: 71.84%, Macro_F1-Score:  43.12%
#
# Epoch 139
# -------------------------------
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.877809, F1-score: 71.83%, Macro_F1-Score:  42.89%
#
# Epoch 140
# -------------------------------
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.884430, F1-score: 71.77%, Macro_F1-Score:  42.90%
#
# Epoch 141
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.899079, F1-score: 71.16%, Macro_F1-Score:  42.73%
#
# Epoch 142
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.898454, F1-score: 71.41%, Macro_F1-Score:  43.23%
#
# Epoch 143
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.896092, F1-score: 71.29%, Macro_F1-Score:  42.84%
#
# Epoch 144
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.905087, F1-score: 71.42%, Macro_F1-Score:  42.75%
#
# Epoch 145
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.895055, F1-score: 71.44%, Macro_F1-Score:  42.81%
#
# Epoch 146
# -------------------------------
# Test Error:
#  Accuracy: 66.0%, Avg loss: 0.877243, F1-score: 71.87%, Macro_F1-Score:  43.38%
#
# Epoch 147
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.878841, F1-score: 71.71%, Macro_F1-Score:  42.68%
#
# Epoch 148
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.896423, F1-score: 71.33%, Macro_F1-Score:  43.02%
#
# Epoch 149
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.887394, F1-score: 71.69%, Macro_F1-Score:  43.18%
#
# Epoch 150
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.900500, F1-score: 71.48%, Macro_F1-Score:  43.20%
#
# Epoch 151
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.892086, F1-score: 71.46%, Macro_F1-Score:  42.65%
#
# Epoch 152
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.894443, F1-score: 71.47%, Macro_F1-Score:  43.04%
#
# Epoch 153
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.898567, F1-score: 71.37%, Macro_F1-Score:  43.13%
#
# Epoch 154
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.928402, F1-score: 71.05%, Macro_F1-Score:  42.57%
#
# Epoch 155
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.881078, F1-score: 71.57%, Macro_F1-Score:  43.37%
#
# Epoch 156
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.892417, F1-score: 71.38%, Macro_F1-Score:  42.92%
#
# Epoch 157
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.882785, F1-score: 71.58%, Macro_F1-Score:  43.00%
#
# Epoch 158
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.888688, F1-score: 71.47%, Macro_F1-Score:  42.62%
#
# Epoch 159
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.902619, F1-score: 71.26%, Macro_F1-Score:  42.82%
#
# Epoch 160
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.903773, F1-score: 71.39%, Macro_F1-Score:  43.20%
#
# Epoch 161
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.876600, F1-score: 71.63%, Macro_F1-Score:  42.67%
#
# Epoch 162
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.903458, F1-score: 71.28%, Macro_F1-Score:  42.92%
#
# Epoch 163
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.893960, F1-score: 71.20%, Macro_F1-Score:  42.45%
#
# Epoch 164
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.899168, F1-score: 71.57%, Macro_F1-Score:  42.75%
#
# Epoch 165
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.893346, F1-score: 71.58%, Macro_F1-Score:  43.33%
#
# Epoch 166
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.920666, F1-score: 71.10%, Macro_F1-Score:  42.46%
#
# Epoch 167
# -------------------------------
# Test Error:
#  Accuracy: 66.0%, Avg loss: 0.891945, F1-score: 72.00%, Macro_F1-Score:  43.12%
#
# Epoch 168
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.901747, F1-score: 71.21%, Macro_F1-Score:  42.45%
#
# Epoch 169
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.918348, F1-score: 71.30%, Macro_F1-Score:  42.59%
#
# Epoch 170
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.890173, F1-score: 71.30%, Macro_F1-Score:  43.07%
#
# Epoch 171
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.888464, F1-score: 71.16%, Macro_F1-Score:  42.76%
#
# Epoch 172
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.877512, F1-score: 71.59%, Macro_F1-Score:  43.10%
#
# Epoch 173
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.895960, F1-score: 71.41%, Macro_F1-Score:  42.57%
#
# Epoch 174
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.910347, F1-score: 71.37%, Macro_F1-Score:  42.89%
#
# Epoch 175
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.908024, F1-score: 71.04%, Macro_F1-Score:  42.02%
#
# Epoch 176
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.884278, F1-score: 71.61%, Macro_F1-Score:  43.31%
#
# Epoch 177
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.898720, F1-score: 71.26%, Macro_F1-Score:  42.61%
#
# Epoch 178
# -------------------------------
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.892955, F1-score: 71.28%, Macro_F1-Score:  42.77%
#
# Epoch 179
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.885789, F1-score: 71.43%, Macro_F1-Score:  42.67%
#
# Epoch 180
# -------------------------------
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.890198, F1-score: 71.64%, Macro_F1-Score:  42.99%
#
# Epoch 181
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.888829, F1-score: 71.57%, Macro_F1-Score:  42.61%
#
# Epoch 182
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.891438, F1-score: 71.41%, Macro_F1-Score:  43.02%
#
# Epoch 183
# -------------------------------
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.887275, F1-score: 71.81%, Macro_F1-Score:  43.30%
#
# Epoch 184
# -------------------------------
# Test Error:
#  Accuracy: 64.9%, Avg loss: 0.919198, F1-score: 71.05%, Macro_F1-Score:  42.45%
#
# Epoch 185
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.902309, F1-score: 71.41%, Macro_F1-Score:  43.06%
#
# Epoch 186
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.891520, F1-score: 71.42%, Macro_F1-Score:  43.39%
#
# Epoch 187
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.893436, F1-score: 71.54%, Macro_F1-Score:  42.99%
#
# Epoch 188
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.889299, F1-score: 71.45%, Macro_F1-Score:  42.83%
#
# Epoch 189
# -------------------------------
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.882624, F1-score: 71.71%, Macro_F1-Score:  42.74%
#
# Epoch 190
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.900432, F1-score: 71.63%, Macro_F1-Score:  43.30%
#
# Epoch 191
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.891401, F1-score: 71.61%, Macro_F1-Score:  43.01%
#
# Epoch 192
# -------------------------------
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.920698, F1-score: 71.15%, Macro_F1-Score:  42.50%
#
# Epoch 193
# -------------------------------
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.883524, F1-score: 71.58%, Macro_F1-Score:  43.24%
#
# Epoch 194
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.894646, F1-score: 71.43%, Macro_F1-Score:  42.65%
#
# Epoch 195
# -------------------------------
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.882103, F1-score: 71.36%, Macro_F1-Score:  42.89%
#
# Epoch 196
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.892034, F1-score: 71.51%, Macro_F1-Score:  43.43%
#
# Epoch 197
# -------------------------------
# Test Error:
#  Accuracy: 65.2%, Avg loss: 0.904481, F1-score: 71.22%, Macro_F1-Score:  42.69%
#
# Epoch 198
# -------------------------------
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.909887, F1-score: 71.17%, Macro_F1-Score:  42.62%
#
# Epoch 199
# -------------------------------
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.893613, F1-score: 71.74%, Macro_F1-Score:  43.01%
#
# Epoch 200
# -------------------------------
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.896839, F1-score: 71.52%, Macro_F1-Score:  42.89%
#
# Done!

# %%
#noise scale is low (0.2)
plt.plot(loss_over_train, label="Training Loss")
plt.plot(loss_over_test, label="Testing Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Testing Loss over Epochs")
plt.legend()
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
import pickle
import pandas as pd

# Load the LabelEncoder object from the file
with open(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess\label_encoder.pkl", "rb") as f:
    label_encoder = pickle.load(f)


# Now you can use the label_encoder object in the second notebook
original_class_labels = label_encoder.classes_
# Out:
# c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
original_labels_test = label_encoder.inverse_transform(test_data_y.values.flatten())

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Ensure the model is in evaluation mode
model.eval()

with torch.no_grad():
    y_pred = model(test_X_tensor)  # Forward pass
    y_pred = torch.argmax(y_pred, dim=1)  # Get class predictions

# Convert tensors to NumPy arrays for sklearn
y_pred = y_pred.cpu().numpy()
y_true = test_Y_tensor.cpu().numpy()

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Get class labels from the LabelEncoder
class_labels = label_encoder.classes_

fig, ax = plt.subplots(figsize=(12, 8))  #Creates both a figure and an ax

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap='Blues', values_format='d', ax=ax)

# Rotate axis labels for better visibility
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Show the plot
plt.show()

# %%
import torch.nn.functional as F

with torch.no_grad():
    y_score = F.softmax(model(test_X_tensor), dim=1)

# %%
np.average(y_score.numpy())
# Out:
# 0.1

# %%
from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(train_data_y)
y_onehot_test = label_binarizer.transform(test_labels_encoded)
y_onehot_test.shape  # (n_samples, n_classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 4
#       1 from sklearn.preprocessing import LabelBinarizer
#       3 label_binarizer = LabelBinarizer().fit(train_data_y)
# ----> 4 y_onehot_test = label_binarizer.transform(test_labels_encoded)
#       5 y_onehot_test.shape  # (n_samples, n_classes)
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:363, in LabelBinarizer.transform(self, y)
#     360 if y_is_multilabel and not self.y_type_.startswith("multilabel"):
#     361     raise ValueError("The object was not fitted with multilabel input.")
# --> 363 return label_binarize(
#     364     y,
#     365     classes=self.classes_,
#     366     pos_label=self.pos_label,
#     367     neg_label=self.neg_label,
#     368     sparse_output=self.sparse_output,
#     369 )
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:530, in label_binarize(y, classes, neg_label, pos_label, sparse_output)
#     528 y_type = type_of_target(y)
#     529 if "multioutput" in y_type:
# --> 530     raise ValueError(
#     531         "Multioutput target data is not supported with label binarization"
#     532     )
#     533 if y_type == "unknown":
#     534     raise ValueError("The type of target data is not known")
#
# ValueError: Multioutput target data is not supported with label binarization

# %%
from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test.ravel(),
    y_score.ravel(),
    name="micro-average OvR",
    color="darkorange",
    plot_chance_level=True)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title="Micro-averaged One-vs-Rest\nReceiver Operating Characteristic",
)

# %% [markdown]
# ## Feature Selection using XGBoost

# %%
import xgboost as xgb
import numpy as np

# Train an XGBoost model
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric="mlogloss", random_state=42)
xgb_model.fit(train_data_X, train_labels_encoded["label"])

# Get feature importances
feature_importances = xgb_model.feature_importances_
top_40_features = np.argsort(feature_importances)[-40:]

# Print selected features
selected_features = train_data_X.columns[top_40_features]
print("Selected Features:", selected_features.tolist())
