# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
#pip install git+https://github.com/KindXiaoming/pykan.git
import sys

# %%
import random
import numpy as np
import torch
import os

def set_global_seed(seed=42):
    """Set seed for reproducibility across NumPy, PyTorch, and OS operations."""
    
    # Set Python random seed
    random.seed(seed)
    
    # Set NumPy random seed
    np.random.seed(seed)
    
    # Set PyTorch random seed
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # If using CUDA
    
    # Ensure deterministic behavior in PyTorch (optional, can slow training)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    # Set environment variable for other libraries
    os.environ["PYTHONHASHSEED"] = str(seed)

# Set global seed
set_global_seed(42)

# %%
test_data_X = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess CICIDS2017\processed_test_data_X_data.csv")
train_data_X = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess CICIDS2017\processed_train_data_X_data.csv")
test_labels_encoded = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess CICIDS2017\processed_test_data_y_data.csv")
train_labels_encoded = pd.read_csv(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess CICIDS2017\processed_train_data_y_data.csv")

# %%
train_data_X.drop(columns=["Destination Port", "Source Port"], inplace=True)
test_data_X.drop(columns=["Destination Port", "Source Port"], inplace=True)

# %%
test_data_y = test_labels_encoded["Label"]

# %%
train_data_y = train_labels_encoded["Label"]

# %%
train_data_y.value_counts()
# Out:
# Label
# 4    20986
# 2    20790
# 5    20202
# 1     8201
# 6     1659
# 0     1499
# 3       25
# Name: count, dtype: int64

# %%
len(train_data_y.value_counts())
# Out:
# 7

# %%
train_data_y.value_counts()
# Out:
# Label
# 4    20986
# 2    20790
# 5    20202
# 1     8201
# 6     1659
# 0     1499
# 3       25
# Name: count, dtype: int64

# %% [markdown]
# # Modelling

# %%
train_data_X.shape
# Out:
# (73362, 77)

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import matplotlib.pyplot as plt

# Train a Random Forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(train_data_X, train_labels_encoded["Label"])

# Get feature importances
feature_importances = rf.feature_importances_
top_40_indices = np.argsort(feature_importances)[-30:]
selected_features = train_data_X.columns[top_40_indices]
selected_importances = feature_importances[top_40_indices]

# Print selected features
print("Selected Features:", selected_features.tolist())

# Plot the top 30 feature importances
plt.figure(figsize=(10, 8))
plt.barh(selected_features, selected_importances, color='skyblue')
plt.xlabel("Feature Importance")
plt.title("Top 30 Feature Importances (Random Forest)")
plt.tight_layout()
plt.show()
# Out:
# Selected Features: ['Flow IAT Max', 'Bwd Packet Length Max', 'Avg Fwd Segment Size', 'Fwd Packet Length Max', 'Total Length of Fwd Packets', 'Flow Duration', 'Fwd IAT Mean', 'Flow Bytess', 'Bwd Header Length', 'Fwd Packet Length Mean', 'Bwd Packet Length Std', 'Fwd Header Length', 'Bwd Packet Length Mean', 'Init_Win_bytes_backward', 'Fwd IAT Max', 'Fwd IAT Total', 'Subflow Fwd Bytes', 'Subflow Fwd Packets', 'Fwd IAT Min', 'Bwd Packet Length Min', 'Packet Length Variance', 'PSH Flag Count', 'Packet Length Std', 'Total Fwd Packets', 'Max Packet Length', 'Avg Bwd Segment Size', 'Packet Length Mean', 'Average Packet Size', 'Bwd Packetss', 'Init_Win_bytes_forward']

# %% [markdown]
# ## Modelling EfficentKan

# %%
#train_X_tensor = torch.tensor(train_data_X[features].values, dtype=torch.float32).squeeze()
#test_X_tensor = torch.tensor(test_data_X[features].values, dtype=torch.float32).squeeze() #changed to have all features

train_X_tensor = torch.tensor(train_data_X[selected_features].values, dtype=torch.float32).squeeze()
test_X_tensor = torch.tensor(test_data_X[selected_features].values, dtype=torch.float32).squeeze()

train_Y_tensor = torch.tensor(train_data_y.values, dtype=torch.long).squeeze()

test_Y_tensor = torch.tensor(test_data_y.values, dtype=torch.long).squeeze()
#a dictionary with the 4 datasets

# %%
from torch import nn
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
# Create TensorDatasets
train_dataset = TensorDataset(train_X_tensor, train_Y_tensor)
test_dataset = TensorDataset(test_X_tensor, test_Y_tensor)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# ## Modelling with efficient Kan

# %%
from efficient_kan import KAN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from tqdm import tqdm

# Define model
model = KAN([40, 64, 10])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define optimizer
optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
# Define learning rate scheduler
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.8)

# Define loss
criterion = nn.CrossEntropyLoss()

# %%
model.grid_size, model.spline_order
# Out:
# (5, 3)

# %%
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import f1_score
loss_over_train = []
loss_over_test = []
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    correct = 0  # For accuracy tracking
    total = 0
    epoch_loss = 0
    
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        epoch_loss += loss.item()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


        
        # Calculate accuracy
        _, predicted = torch.max(pred, 1)
        correct += (predicted == y).sum().item()
        total += y.size(0)
        
    mean_loss = epoch_loss / len(dataloader) 
    loss_over_train.append(mean_loss)

    accuracy = correct / total * 100
    print(f"Train Accuracy: {accuracy:.4f}%")

def test_loop(dataloader, model, loss_fn):
    model.eval()  # Set the model to evaluation mode
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            
            # Collect all predictions and true labels for F1-score calculation
            all_preds.extend(pred.argmax(1).cpu().numpy())
            all_labels.extend(y.cpu().numpy())

    mean_loss = test_loss / num_batches  # Divide by the number of batches
    loss_over_test.append(mean_loss)

    test_loss /= num_batches
    correct /= size
    f1 = f1_score(all_labels, all_preds, average='weighted') * 100  # Weighted F1-score to handle class imbalance
    f1_macro = f1_score(all_labels, all_preds, average='macro') * 100  # Macro F1-score to handle class imbalance

    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f}, F1-score: {f1:.2f}%, Macro_F1-Score: {f1_macro: .2f}%  \n")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, ConcatDataset
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score

# Number of folds
k_folds = 5
epochs = 200  # Number of training epochs per fold
batch_size = 32  # Adjust batch size as needed

# Define K-Fold cross-validator
kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# Define loss function and learning parameters
loss_fn = nn.CrossEntropyLoss()
learning_rate = 0.0001
weight_decay = 1e-4

# Combine datasets (Only Train Data)
dataset = train_dataset  # Use only training dataset

# Store results across folds
fold_accuracies = []
fold_f1_scores = []
fold_f1_macro_scores = []
fold_losses = []

# K-Fold cross-validation loop
for fold, (train_ids, val_ids) in enumerate(kfold.split(dataset)):
    print(f"\nFold {fold + 1}/{k_folds}\n" + "-" * 30)
    print("initializing model...")
    model = KAN([30, 20,10, 5,7],grid_size = 6, spline_order = 3, scale_noise=0.2, scale_base=0.2, scale_spline=0.2) #best
    # Create data subsets for the current fold
    train_subset = Subset(dataset, train_ids)
    val_subset = Subset(dataset, val_ids)

    # Create data loaders for the current fold
    train_dataloader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    # Re-initialize model and optimizer for each fold
     # Replace with your model class
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    # Training function
    def train_loop(dataloader, model, loss_fn, optimizer):
        model.train()
        correct, total = 0, 0
        epoch_loss = 0

        for batch, (X, y) in enumerate(dataloader):
            pred = model(X)
            loss = loss_fn(pred, y)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            epoch_loss += loss.item()

            _, predicted = torch.max(pred, 1)
            correct += (predicted == y).sum().item()
            total += y.size(0)

        return correct / total * 100, epoch_loss / len(dataloader)

    # Validation function
    def val_loop(dataloader, model, loss_fn):
        model.eval()
        correct, total = 0, 0
        val_loss = 0
        all_preds, all_labels = [], []

        with torch.no_grad():
            for X, y in dataloader:
                pred = model(X)
                val_loss += loss_fn(pred, y).item()
                correct += (pred.argmax(1) == y).type(torch.float).sum().item()

                all_preds.extend(pred.argmax(1).cpu().numpy())
                all_labels.extend(y.cpu().numpy())

        accuracy = correct / len(dataloader.dataset) * 100
        f1 = f1_score(all_labels, all_preds, average='weighted') * 100
        f1_macro = f1_score(all_labels, all_preds, average='macro') * 100
        mean_loss = val_loss / len(dataloader)

        return accuracy, f1, f1_macro, mean_loss

    # Train and validate for this fold
    for epoch in range(epochs):
        train_acc, train_loss = train_loop(train_dataloader, model, loss_fn, optimizer)
        val_acc, f1, f1_macro, val_loss = val_loop(val_dataloader, model, loss_fn)

        print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}%, Val Acc={val_acc:.2f}%, F1={f1:.2f}%, Macro F1={f1_macro:.2f}%")

    # Store fold results
    fold_accuracies.append(val_acc)
    fold_f1_scores.append(f1)
    fold_f1_macro_scores.append(f1_macro)
    fold_losses.append(val_loss)

# Print final results
print("\nCross-Validation Results:")
print(f"Avg Validation Accuracy: {sum(fold_accuracies) / k_folds:.2f}%")
print(f"Avg Weighted F1-score: {sum(fold_f1_scores) / k_folds:.2f}%")
print(f"Avg Macro F1-score: {sum(fold_f1_macro_scores) / k_folds:.2f}%")
print(f"Avg Validation Loss: {sum(fold_losses) / k_folds:.6f}")
# Out:
# Fold 1/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=61.46%, Val Acc=77.07%, F1=70.97%, Macro F1=35.85%
# Epoch 2: Train Acc=81.63%, Val Acc=86.89%, F1=85.70%, Macro F1=59.92%
# Epoch 3: Train Acc=88.32%, Val Acc=89.61%, F1=88.81%, Macro F1=62.87%
# Epoch 4: Train Acc=90.65%, Val Acc=91.26%, F1=90.95%, Macro F1=70.21%
# Epoch 5: Train Acc=91.90%, Val Acc=92.27%, F1=91.95%, Macro F1=71.18%
# Epoch 6: Train Acc=92.77%, Val Acc=93.03%, F1=92.77%, Macro F1=72.41%
# Epoch 7: Train Acc=93.12%, Val Acc=93.34%, F1=93.13%, Macro F1=73.04%
# Epoch 8: Train Acc=93.42%, Val Acc=93.48%, F1=93.17%, Macro F1=72.49%
# Epoch 9: Train Acc=93.63%, Val Acc=93.60%, F1=93.47%, Macro F1=73.99%
# Epoch 10: Train Acc=94.10%, Val Acc=94.36%, F1=94.30%, Macro F1=76.92%
# Epoch 11: Train Acc=94.90%, Val Acc=94.50%, F1=94.44%, Macro F1=77.32%
# Epoch 12: Train Acc=95.05%, Val Acc=94.77%, F1=94.71%, Macro F1=77.56%
# Epoch 13: Train Acc=95.29%, Val Acc=94.98%, F1=94.94%, Macro F1=78.09%
# Epoch 14: Train Acc=95.40%, Val Acc=95.23%, F1=95.19%, Macro F1=78.37%
# Epoch 15: Train Acc=95.64%, Val Acc=95.43%, F1=95.37%, Macro F1=78.75%
# Epoch 16: Train Acc=95.78%, Val Acc=95.24%, F1=95.20%, Macro F1=78.56%
# Epoch 17: Train Acc=95.86%, Val Acc=95.65%, F1=95.59%, Macro F1=78.80%
# Epoch 18: Train Acc=96.00%, Val Acc=95.80%, F1=95.75%, Macro F1=79.07%
# Epoch 19: Train Acc=96.12%, Val Acc=95.84%, F1=95.78%, Macro F1=78.98%
# Epoch 20: Train Acc=96.21%, Val Acc=95.77%, F1=95.72%, Macro F1=79.11%
# Epoch 21: Train Acc=96.24%, Val Acc=95.82%, F1=95.77%, Macro F1=79.16%
# Epoch 22: Train Acc=96.32%, Val Acc=95.73%, F1=95.67%, Macro F1=79.05%
# Epoch 23: Train Acc=96.33%, Val Acc=96.01%, F1=95.96%, Macro F1=79.35%
# Epoch 24: Train Acc=96.35%, Val Acc=96.19%, F1=96.15%, Macro F1=79.54%
# Epoch 25: Train Acc=96.38%, Val Acc=96.01%, F1=95.96%, Macro F1=79.31%
# Epoch 26: Train Acc=96.48%, Val Acc=95.79%, F1=95.75%, Macro F1=79.11%
# Epoch 27: Train Acc=96.47%, Val Acc=96.23%, F1=96.19%, Macro F1=79.63%
# Epoch 28: Train Acc=96.51%, Val Acc=96.16%, F1=96.12%, Macro F1=79.79%
# Epoch 29: Train Acc=96.59%, Val Acc=96.32%, F1=96.28%, Macro F1=80.13%
# Epoch 30: Train Acc=96.63%, Val Acc=96.40%, F1=96.36%, Macro F1=80.09%
# Epoch 31: Train Acc=96.66%, Val Acc=96.39%, F1=96.35%, Macro F1=80.17%
# Epoch 32: Train Acc=96.69%, Val Acc=96.40%, F1=96.36%, Macro F1=79.98%
# Epoch 33: Train Acc=96.78%, Val Acc=96.58%, F1=96.55%, Macro F1=80.44%
# Epoch 34: Train Acc=96.79%, Val Acc=96.24%, F1=96.20%, Macro F1=80.26%
# Epoch 35: Train Acc=96.84%, Val Acc=96.46%, F1=96.43%, Macro F1=80.36%
# Epoch 36: Train Acc=96.89%, Val Acc=96.64%, F1=96.61%, Macro F1=80.63%
# Epoch 37: Train Acc=96.89%, Val Acc=96.62%, F1=96.59%, Macro F1=80.57%
# Epoch 38: Train Acc=96.92%, Val Acc=96.67%, F1=96.64%, Macro F1=80.50%
# Epoch 39: Train Acc=96.92%, Val Acc=96.81%, F1=96.78%, Macro F1=80.93%
# Epoch 40: Train Acc=96.96%, Val Acc=96.83%, F1=96.81%, Macro F1=80.86%
# Epoch 41: Train Acc=97.04%, Val Acc=96.80%, F1=96.77%, Macro F1=80.74%
# Epoch 42: Train Acc=97.03%, Val Acc=96.85%, F1=96.83%, Macro F1=80.75%
# Epoch 43: Train Acc=97.07%, Val Acc=97.08%, F1=97.05%, Macro F1=81.36%
# Epoch 44: Train Acc=97.09%, Val Acc=96.81%, F1=96.79%, Macro F1=80.74%
# Epoch 45: Train Acc=97.09%, Val Acc=96.79%, F1=96.77%, Macro F1=80.82%
# Epoch 46: Train Acc=97.13%, Val Acc=96.89%, F1=96.87%, Macro F1=81.02%
# Epoch 47: Train Acc=97.15%, Val Acc=96.80%, F1=96.78%, Macro F1=80.88%
# Epoch 48: Train Acc=97.17%, Val Acc=96.96%, F1=96.93%, Macro F1=81.25%
# Epoch 49: Train Acc=97.20%, Val Acc=97.02%, F1=96.99%, Macro F1=81.12%
# Epoch 50: Train Acc=97.21%, Val Acc=96.88%, F1=96.86%, Macro F1=81.09%
# Epoch 51: Train Acc=97.26%, Val Acc=96.90%, F1=96.87%, Macro F1=80.89%
# Epoch 52: Train Acc=97.30%, Val Acc=97.01%, F1=96.98%, Macro F1=81.23%
# Epoch 53: Train Acc=97.33%, Val Acc=96.97%, F1=96.94%, Macro F1=81.30%
# Epoch 54: Train Acc=97.36%, Val Acc=97.06%, F1=97.03%, Macro F1=81.47%
# Epoch 55: Train Acc=97.31%, Val Acc=97.04%, F1=97.02%, Macro F1=81.23%
# Epoch 56: Train Acc=97.44%, Val Acc=97.10%, F1=97.07%, Macro F1=81.38%
# Epoch 57: Train Acc=97.44%, Val Acc=97.01%, F1=96.99%, Macro F1=81.40%
# Epoch 58: Train Acc=97.43%, Val Acc=97.23%, F1=97.21%, Macro F1=81.88%
# Epoch 59: Train Acc=97.48%, Val Acc=97.10%, F1=97.08%, Macro F1=81.57%
# Epoch 60: Train Acc=97.48%, Val Acc=97.23%, F1=97.21%, Macro F1=81.92%
# Epoch 61: Train Acc=97.54%, Val Acc=97.19%, F1=97.16%, Macro F1=81.70%
# Epoch 62: Train Acc=97.54%, Val Acc=97.17%, F1=97.15%, Macro F1=81.76%
# Epoch 63: Train Acc=97.59%, Val Acc=97.34%, F1=97.32%, Macro F1=81.98%
# Epoch 64: Train Acc=97.62%, Val Acc=97.45%, F1=97.43%, Macro F1=82.47%
# Epoch 65: Train Acc=97.63%, Val Acc=97.37%, F1=97.34%, Macro F1=81.96%
# Epoch 66: Train Acc=97.70%, Val Acc=97.34%, F1=97.32%, Macro F1=82.05%
# Epoch 67: Train Acc=97.69%, Val Acc=97.42%, F1=97.39%, Macro F1=82.25%
# Epoch 68: Train Acc=97.76%, Val Acc=97.43%, F1=97.41%, Macro F1=82.08%
# Epoch 69: Train Acc=97.72%, Val Acc=97.31%, F1=97.29%, Macro F1=82.24%
# Epoch 70: Train Acc=97.77%, Val Acc=97.48%, F1=97.46%, Macro F1=82.50%
# Epoch 71: Train Acc=97.82%, Val Acc=97.41%, F1=97.39%, Macro F1=82.08%
# Epoch 72: Train Acc=97.81%, Val Acc=97.52%, F1=97.49%, Macro F1=82.14%
# Epoch 73: Train Acc=97.84%, Val Acc=97.42%, F1=97.40%, Macro F1=82.44%
# Epoch 74: Train Acc=97.86%, Val Acc=97.47%, F1=97.45%, Macro F1=82.31%
# Epoch 75: Train Acc=97.89%, Val Acc=97.55%, F1=97.53%, Macro F1=82.39%
# Epoch 76: Train Acc=97.89%, Val Acc=97.53%, F1=97.51%, Macro F1=82.32%
# Epoch 77: Train Acc=97.92%, Val Acc=97.60%, F1=97.58%, Macro F1=82.51%
# Epoch 78: Train Acc=97.91%, Val Acc=97.47%, F1=97.45%, Macro F1=82.43%
# Epoch 79: Train Acc=97.95%, Val Acc=97.64%, F1=97.61%, Macro F1=82.68%
# Epoch 80: Train Acc=97.95%, Val Acc=97.50%, F1=97.47%, Macro F1=82.12%
# Epoch 81: Train Acc=97.97%, Val Acc=97.61%, F1=97.59%, Macro F1=82.79%
# Epoch 82: Train Acc=97.99%, Val Acc=97.62%, F1=97.60%, Macro F1=82.54%
# Epoch 83: Train Acc=97.98%, Val Acc=97.80%, F1=97.78%, Macro F1=83.03%
# Epoch 84: Train Acc=98.00%, Val Acc=97.67%, F1=97.65%, Macro F1=82.70%
# Epoch 85: Train Acc=98.01%, Val Acc=97.68%, F1=97.66%, Macro F1=82.51%
# Epoch 86: Train Acc=98.02%, Val Acc=97.70%, F1=97.68%, Macro F1=82.55%
# Epoch 87: Train Acc=98.02%, Val Acc=97.74%, F1=97.72%, Macro F1=82.87%
# Epoch 88: Train Acc=98.03%, Val Acc=97.70%, F1=97.67%, Macro F1=82.75%
# Epoch 89: Train Acc=98.03%, Val Acc=97.63%, F1=97.61%, Macro F1=82.74%
# Epoch 90: Train Acc=98.06%, Val Acc=97.58%, F1=97.56%, Macro F1=82.66%
# Epoch 91: Train Acc=98.04%, Val Acc=97.84%, F1=97.82%, Macro F1=83.03%
# Epoch 92: Train Acc=98.11%, Val Acc=97.81%, F1=97.79%, Macro F1=83.03%
# Epoch 93: Train Acc=98.06%, Val Acc=97.72%, F1=97.70%, Macro F1=83.04%
# Epoch 94: Train Acc=98.07%, Val Acc=97.77%, F1=97.75%, Macro F1=82.86%
# Epoch 95: Train Acc=98.07%, Val Acc=97.61%, F1=97.59%, Macro F1=82.81%
# Epoch 96: Train Acc=98.11%, Val Acc=97.60%, F1=97.58%, Macro F1=82.89%
# Epoch 97: Train Acc=98.09%, Val Acc=97.89%, F1=97.88%, Macro F1=83.14%
# Epoch 98: Train Acc=98.08%, Val Acc=97.81%, F1=97.79%, Macro F1=83.09%
# Epoch 99: Train Acc=98.09%, Val Acc=97.70%, F1=97.68%, Macro F1=82.91%
# Epoch 100: Train Acc=98.11%, Val Acc=97.81%, F1=97.79%, Macro F1=83.00%
# Epoch 101: Train Acc=98.13%, Val Acc=97.84%, F1=97.82%, Macro F1=83.01%
# Epoch 102: Train Acc=98.13%, Val Acc=97.79%, F1=97.77%, Macro F1=82.97%
# Epoch 103: Train Acc=98.13%, Val Acc=97.70%, F1=97.67%, Macro F1=82.55%
# Epoch 104: Train Acc=98.11%, Val Acc=97.83%, F1=97.81%, Macro F1=83.01%
# Epoch 105: Train Acc=98.13%, Val Acc=97.69%, F1=97.67%, Macro F1=82.88%
# Epoch 106: Train Acc=98.16%, Val Acc=97.66%, F1=97.64%, Macro F1=82.86%
# Epoch 107: Train Acc=98.17%, Val Acc=97.89%, F1=97.88%, Macro F1=83.04%
# Epoch 108: Train Acc=98.16%, Val Acc=97.78%, F1=97.76%, Macro F1=83.08%
# Epoch 109: Train Acc=98.15%, Val Acc=97.77%, F1=97.75%, Macro F1=83.01%
# Epoch 110: Train Acc=98.19%, Val Acc=97.68%, F1=97.66%, Macro F1=82.67%
# Epoch 111: Train Acc=98.18%, Val Acc=97.88%, F1=97.86%, Macro F1=83.17%
# Epoch 112: Train Acc=98.17%, Val Acc=97.88%, F1=97.86%, Macro F1=83.11%
# Epoch 113: Train Acc=98.16%, Val Acc=97.79%, F1=97.77%, Macro F1=82.74%
# Epoch 114: Train Acc=98.18%, Val Acc=97.86%, F1=97.84%, Macro F1=83.07%
# Epoch 115: Train Acc=98.22%, Val Acc=97.87%, F1=97.85%, Macro F1=83.09%
# Epoch 116: Train Acc=98.20%, Val Acc=97.81%, F1=97.79%, Macro F1=82.79%
# Epoch 117: Train Acc=98.21%, Val Acc=97.72%, F1=97.70%, Macro F1=82.85%
# Epoch 118: Train Acc=98.16%, Val Acc=97.89%, F1=97.87%, Macro F1=83.11%
# Epoch 119: Train Acc=98.23%, Val Acc=97.84%, F1=97.82%, Macro F1=82.97%
# Epoch 120: Train Acc=98.19%, Val Acc=97.81%, F1=97.79%, Macro F1=82.99%
# Epoch 121: Train Acc=98.22%, Val Acc=97.90%, F1=97.88%, Macro F1=82.97%
# Epoch 122: Train Acc=98.20%, Val Acc=97.76%, F1=97.74%, Macro F1=82.91%
# Epoch 123: Train Acc=98.20%, Val Acc=97.74%, F1=97.72%, Macro F1=82.95%
# Epoch 124: Train Acc=98.22%, Val Acc=97.79%, F1=97.77%, Macro F1=83.06%
# Epoch 125: Train Acc=98.20%, Val Acc=97.89%, F1=97.87%, Macro F1=83.00%
# Epoch 126: Train Acc=98.21%, Val Acc=97.83%, F1=97.81%, Macro F1=82.91%
# Epoch 127: Train Acc=98.23%, Val Acc=97.74%, F1=97.72%, Macro F1=83.02%
# Epoch 128: Train Acc=98.22%, Val Acc=97.90%, F1=97.88%, Macro F1=83.01%
# Epoch 129: Train Acc=98.23%, Val Acc=97.81%, F1=97.79%, Macro F1=83.01%
# Epoch 130: Train Acc=98.23%, Val Acc=97.93%, F1=97.92%, Macro F1=83.00%
# Epoch 131: Train Acc=98.24%, Val Acc=97.80%, F1=97.78%, Macro F1=83.09%
# Epoch 132: Train Acc=98.23%, Val Acc=97.87%, F1=97.85%, Macro F1=82.96%
# Epoch 133: Train Acc=98.20%, Val Acc=97.97%, F1=97.95%, Macro F1=83.20%
# Epoch 134: Train Acc=98.24%, Val Acc=97.84%, F1=97.82%, Macro F1=83.07%
# Epoch 135: Train Acc=98.23%, Val Acc=97.86%, F1=97.84%, Macro F1=82.85%
# Epoch 136: Train Acc=98.26%, Val Acc=97.90%, F1=97.88%, Macro F1=83.13%
# Epoch 137: Train Acc=98.26%, Val Acc=97.94%, F1=97.92%, Macro F1=83.12%
# Epoch 138: Train Acc=98.27%, Val Acc=97.72%, F1=97.71%, Macro F1=82.88%
# Epoch 139: Train Acc=98.28%, Val Acc=97.79%, F1=97.77%, Macro F1=82.89%
# Epoch 140: Train Acc=98.29%, Val Acc=97.80%, F1=97.78%, Macro F1=82.79%
# Epoch 141: Train Acc=98.27%, Val Acc=97.96%, F1=97.94%, Macro F1=83.22%
# Epoch 142: Train Acc=98.29%, Val Acc=97.73%, F1=97.71%, Macro F1=82.70%
# Epoch 143: Train Acc=98.26%, Val Acc=97.74%, F1=97.72%, Macro F1=82.86%
# Epoch 144: Train Acc=98.30%, Val Acc=97.72%, F1=97.70%, Macro F1=82.77%
# Epoch 145: Train Acc=98.28%, Val Acc=97.99%, F1=97.97%, Macro F1=83.04%
# Epoch 146: Train Acc=98.27%, Val Acc=97.91%, F1=97.89%, Macro F1=82.98%
# Epoch 147: Train Acc=98.31%, Val Acc=98.06%, F1=98.04%, Macro F1=83.36%
# Epoch 148: Train Acc=98.26%, Val Acc=97.94%, F1=97.92%, Macro F1=83.10%
# Epoch 149: Train Acc=98.28%, Val Acc=98.01%, F1=97.99%, Macro F1=83.17%
# Epoch 150: Train Acc=98.31%, Val Acc=97.79%, F1=97.77%, Macro F1=82.99%
# Epoch 151: Train Acc=98.33%, Val Acc=97.96%, F1=97.94%, Macro F1=83.16%
# Epoch 152: Train Acc=98.30%, Val Acc=97.87%, F1=97.85%, Macro F1=83.09%
# Epoch 153: Train Acc=98.31%, Val Acc=97.89%, F1=97.87%, Macro F1=83.05%
# Epoch 154: Train Acc=98.28%, Val Acc=97.98%, F1=97.96%, Macro F1=83.18%
# Epoch 155: Train Acc=98.29%, Val Acc=97.89%, F1=97.87%, Macro F1=82.90%
# Epoch 156: Train Acc=98.31%, Val Acc=98.01%, F1=97.99%, Macro F1=83.28%
# Epoch 157: Train Acc=98.32%, Val Acc=97.83%, F1=97.81%, Macro F1=83.08%
# Epoch 158: Train Acc=98.31%, Val Acc=98.04%, F1=98.03%, Macro F1=83.31%
# Epoch 159: Train Acc=98.35%, Val Acc=97.79%, F1=97.77%, Macro F1=82.92%
# Epoch 160: Train Acc=98.36%, Val Acc=97.85%, F1=97.83%, Macro F1=82.99%
# Epoch 161: Train Acc=98.32%, Val Acc=97.75%, F1=97.73%, Macro F1=83.02%
# Epoch 162: Train Acc=98.34%, Val Acc=97.88%, F1=97.86%, Macro F1=83.13%
# Epoch 163: Train Acc=98.34%, Val Acc=97.97%, F1=97.95%, Macro F1=83.21%
# Epoch 164: Train Acc=98.34%, Val Acc=98.02%, F1=98.00%, Macro F1=83.30%
# Epoch 165: Train Acc=98.35%, Val Acc=97.89%, F1=97.87%, Macro F1=82.54%
# Epoch 166: Train Acc=98.32%, Val Acc=97.93%, F1=97.91%, Macro F1=83.25%
# Epoch 167: Train Acc=98.33%, Val Acc=97.93%, F1=97.91%, Macro F1=83.18%
# Epoch 168: Train Acc=98.34%, Val Acc=98.04%, F1=98.02%, Macro F1=83.29%
# Epoch 169: Train Acc=98.34%, Val Acc=98.10%, F1=98.08%, Macro F1=83.39%
# Epoch 170: Train Acc=98.38%, Val Acc=97.98%, F1=97.96%, Macro F1=83.34%
# Epoch 171: Train Acc=98.36%, Val Acc=98.04%, F1=98.02%, Macro F1=83.42%
# Epoch 172: Train Acc=98.34%, Val Acc=98.06%, F1=98.05%, Macro F1=83.45%
# Epoch 173: Train Acc=98.37%, Val Acc=97.91%, F1=97.89%, Macro F1=83.28%
# Epoch 174: Train Acc=98.37%, Val Acc=98.06%, F1=98.04%, Macro F1=83.53%
# Epoch 175: Train Acc=98.36%, Val Acc=98.07%, F1=98.06%, Macro F1=83.46%
# Epoch 176: Train Acc=98.39%, Val Acc=98.08%, F1=98.06%, Macro F1=83.53%
# Epoch 177: Train Acc=98.41%, Val Acc=98.09%, F1=98.08%, Macro F1=83.55%
# Epoch 178: Train Acc=98.42%, Val Acc=97.94%, F1=97.93%, Macro F1=83.40%
# Epoch 179: Train Acc=98.39%, Val Acc=98.07%, F1=98.06%, Macro F1=83.52%
# Epoch 180: Train Acc=98.37%, Val Acc=98.08%, F1=98.07%, Macro F1=83.55%
# Epoch 181: Train Acc=98.40%, Val Acc=98.09%, F1=98.08%, Macro F1=83.61%
# Epoch 182: Train Acc=98.39%, Val Acc=98.12%, F1=98.10%, Macro F1=83.55%
# Epoch 183: Train Acc=98.38%, Val Acc=98.13%, F1=98.12%, Macro F1=83.57%
# Epoch 184: Train Acc=98.45%, Val Acc=98.02%, F1=98.01%, Macro F1=83.21%
# Epoch 185: Train Acc=98.41%, Val Acc=98.11%, F1=98.09%, Macro F1=83.50%
# Epoch 186: Train Acc=98.44%, Val Acc=98.13%, F1=98.12%, Macro F1=83.71%
# Epoch 187: Train Acc=98.39%, Val Acc=98.24%, F1=98.23%, Macro F1=83.89%
# Epoch 188: Train Acc=98.44%, Val Acc=98.08%, F1=98.06%, Macro F1=83.45%
# Epoch 189: Train Acc=98.42%, Val Acc=97.98%, F1=97.96%, Macro F1=83.35%
# Epoch 190: Train Acc=98.41%, Val Acc=98.09%, F1=98.08%, Macro F1=83.57%
# Epoch 191: Train Acc=98.42%, Val Acc=98.15%, F1=98.14%, Macro F1=83.77%
# Epoch 192: Train Acc=98.41%, Val Acc=98.04%, F1=98.03%, Macro F1=83.41%
# Epoch 193: Train Acc=98.45%, Val Acc=98.00%, F1=97.98%, Macro F1=83.47%
# Epoch 194: Train Acc=98.45%, Val Acc=98.10%, F1=98.08%, Macro F1=83.40%
# Epoch 195: Train Acc=98.44%, Val Acc=97.81%, F1=97.79%, Macro F1=83.30%
# Epoch 196: Train Acc=98.45%, Val Acc=98.09%, F1=98.08%, Macro F1=83.57%
# Epoch 197: Train Acc=98.46%, Val Acc=98.08%, F1=98.06%, Macro F1=83.47%
# Epoch 198: Train Acc=98.45%, Val Acc=98.15%, F1=98.13%, Macro F1=83.70%
# Epoch 199: Train Acc=98.47%, Val Acc=97.99%, F1=97.97%, Macro F1=83.54%
# Epoch 200: Train Acc=98.44%, Val Acc=98.17%, F1=98.15%, Macro F1=83.81%
#
# Fold 2/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=62.73%, Val Acc=76.71%, F1=71.08%, Macro F1=36.23%
# Epoch 2: Train Acc=82.11%, Val Acc=85.80%, F1=83.93%, Macro F1=48.74%
# Epoch 3: Train Acc=88.47%, Val Acc=89.84%, F1=89.01%, Macro F1=63.29%
# Epoch 4: Train Acc=90.56%, Val Acc=91.29%, F1=90.92%, Macro F1=69.71%
# Epoch 5: Train Acc=91.32%, Val Acc=91.59%, F1=91.47%, Macro F1=71.99%
# Epoch 6: Train Acc=91.73%, Val Acc=91.76%, F1=91.67%, Macro F1=72.25%
# Epoch 7: Train Acc=92.32%, Val Acc=92.88%, F1=92.86%, Macro F1=76.48%
# Epoch 8: Train Acc=93.27%, Val Acc=93.74%, F1=93.70%, Macro F1=77.21%
# Epoch 9: Train Acc=93.90%, Val Acc=92.80%, F1=92.76%, Macro F1=76.40%
# Epoch 10: Train Acc=94.17%, Val Acc=94.46%, F1=94.39%, Macro F1=77.91%
# Epoch 11: Train Acc=94.28%, Val Acc=94.38%, F1=94.33%, Macro F1=77.79%
# Epoch 12: Train Acc=94.42%, Val Acc=94.55%, F1=94.49%, Macro F1=77.88%
# Epoch 13: Train Acc=94.53%, Val Acc=94.89%, F1=94.81%, Macro F1=78.45%
# Epoch 14: Train Acc=94.72%, Val Acc=94.84%, F1=94.79%, Macro F1=78.27%
# Epoch 15: Train Acc=94.84%, Val Acc=94.85%, F1=94.80%, Macro F1=78.24%
# Epoch 16: Train Acc=94.94%, Val Acc=94.67%, F1=94.63%, Macro F1=78.17%
# Epoch 17: Train Acc=95.02%, Val Acc=95.18%, F1=95.13%, Macro F1=78.74%
# Epoch 18: Train Acc=95.19%, Val Acc=95.13%, F1=95.08%, Macro F1=78.68%
# Epoch 19: Train Acc=95.26%, Val Acc=95.39%, F1=95.33%, Macro F1=79.05%
# Epoch 20: Train Acc=95.28%, Val Acc=95.29%, F1=95.24%, Macro F1=78.87%
# Epoch 21: Train Acc=95.35%, Val Acc=95.56%, F1=95.49%, Macro F1=79.25%
# Epoch 22: Train Acc=95.42%, Val Acc=95.52%, F1=95.45%, Macro F1=79.22%
# Epoch 23: Train Acc=95.43%, Val Acc=95.36%, F1=95.32%, Macro F1=78.82%
# Epoch 24: Train Acc=95.54%, Val Acc=95.60%, F1=95.55%, Macro F1=79.33%
# Epoch 25: Train Acc=95.58%, Val Acc=95.45%, F1=95.40%, Macro F1=79.12%
# Epoch 26: Train Acc=95.66%, Val Acc=95.98%, F1=95.95%, Macro F1=79.51%
# Epoch 27: Train Acc=95.73%, Val Acc=95.42%, F1=95.38%, Macro F1=79.08%
# Epoch 28: Train Acc=95.76%, Val Acc=95.88%, F1=95.85%, Macro F1=79.51%
# Epoch 29: Train Acc=95.86%, Val Acc=95.78%, F1=95.76%, Macro F1=79.58%
# Epoch 30: Train Acc=95.92%, Val Acc=95.66%, F1=95.63%, Macro F1=79.37%
# Epoch 31: Train Acc=95.98%, Val Acc=95.96%, F1=95.92%, Macro F1=79.99%
# Epoch 32: Train Acc=96.04%, Val Acc=95.95%, F1=95.91%, Macro F1=79.65%
# Epoch 33: Train Acc=96.12%, Val Acc=96.14%, F1=96.10%, Macro F1=80.46%
# Epoch 34: Train Acc=96.17%, Val Acc=96.18%, F1=96.15%, Macro F1=80.13%
# Epoch 35: Train Acc=96.23%, Val Acc=96.33%, F1=96.31%, Macro F1=80.30%
# Epoch 36: Train Acc=96.27%, Val Acc=96.39%, F1=96.35%, Macro F1=80.26%
# Epoch 37: Train Acc=96.33%, Val Acc=96.29%, F1=96.26%, Macro F1=80.59%
# Epoch 38: Train Acc=96.38%, Val Acc=96.49%, F1=96.48%, Macro F1=80.34%
# Epoch 39: Train Acc=96.43%, Val Acc=96.38%, F1=96.35%, Macro F1=80.39%
# Epoch 40: Train Acc=96.41%, Val Acc=96.48%, F1=96.44%, Macro F1=80.53%
# Epoch 41: Train Acc=96.47%, Val Acc=96.50%, F1=96.48%, Macro F1=80.55%
# Epoch 42: Train Acc=96.55%, Val Acc=96.33%, F1=96.27%, Macro F1=80.47%
# Epoch 43: Train Acc=96.54%, Val Acc=96.79%, F1=96.75%, Macro F1=81.11%
# Epoch 44: Train Acc=96.56%, Val Acc=96.38%, F1=96.31%, Macro F1=80.31%
# Epoch 45: Train Acc=96.63%, Val Acc=96.52%, F1=96.52%, Macro F1=80.54%
# Epoch 46: Train Acc=96.64%, Val Acc=96.80%, F1=96.76%, Macro F1=81.27%
# Epoch 47: Train Acc=96.66%, Val Acc=96.54%, F1=96.53%, Macro F1=80.50%
# Epoch 48: Train Acc=96.72%, Val Acc=96.67%, F1=96.64%, Macro F1=81.03%
# Epoch 49: Train Acc=96.66%, Val Acc=96.80%, F1=96.78%, Macro F1=80.97%
# Epoch 50: Train Acc=96.68%, Val Acc=96.48%, F1=96.45%, Macro F1=80.66%
# Epoch 51: Train Acc=96.78%, Val Acc=96.60%, F1=96.56%, Macro F1=80.90%
# Epoch 52: Train Acc=96.78%, Val Acc=96.61%, F1=96.60%, Macro F1=80.67%
# Epoch 53: Train Acc=96.76%, Val Acc=96.76%, F1=96.71%, Macro F1=81.09%
# Epoch 54: Train Acc=96.79%, Val Acc=96.34%, F1=96.33%, Macro F1=80.64%
# Epoch 55: Train Acc=96.81%, Val Acc=96.91%, F1=96.88%, Macro F1=81.14%
# Epoch 56: Train Acc=96.84%, Val Acc=96.74%, F1=96.72%, Macro F1=81.02%
# Epoch 57: Train Acc=96.82%, Val Acc=96.74%, F1=96.70%, Macro F1=81.09%
# Epoch 58: Train Acc=96.85%, Val Acc=96.84%, F1=96.81%, Macro F1=81.31%
# Epoch 59: Train Acc=96.89%, Val Acc=96.72%, F1=96.68%, Macro F1=80.99%
# Epoch 60: Train Acc=96.80%, Val Acc=96.64%, F1=96.61%, Macro F1=81.25%
# Epoch 61: Train Acc=96.93%, Val Acc=96.62%, F1=96.59%, Macro F1=81.25%
# Epoch 62: Train Acc=96.93%, Val Acc=96.87%, F1=96.84%, Macro F1=81.34%
# Epoch 63: Train Acc=96.92%, Val Acc=96.90%, F1=96.87%, Macro F1=81.27%
# Epoch 64: Train Acc=96.95%, Val Acc=96.78%, F1=96.75%, Macro F1=81.26%
# Epoch 65: Train Acc=96.96%, Val Acc=96.83%, F1=96.80%, Macro F1=81.20%
# Epoch 66: Train Acc=96.96%, Val Acc=96.91%, F1=96.88%, Macro F1=81.36%
# Epoch 67: Train Acc=96.98%, Val Acc=96.93%, F1=96.90%, Macro F1=81.22%
# Epoch 68: Train Acc=97.05%, Val Acc=96.98%, F1=96.95%, Macro F1=81.43%
# Epoch 69: Train Acc=97.05%, Val Acc=96.92%, F1=96.90%, Macro F1=81.31%
# Epoch 70: Train Acc=97.04%, Val Acc=96.91%, F1=96.88%, Macro F1=81.39%
# Epoch 71: Train Acc=97.05%, Val Acc=96.91%, F1=96.88%, Macro F1=81.35%
# Epoch 72: Train Acc=97.07%, Val Acc=97.18%, F1=97.14%, Macro F1=81.97%
# Epoch 73: Train Acc=97.07%, Val Acc=96.96%, F1=96.94%, Macro F1=81.46%
# Epoch 74: Train Acc=97.08%, Val Acc=96.82%, F1=96.80%, Macro F1=81.39%
# Epoch 75: Train Acc=97.11%, Val Acc=96.78%, F1=96.76%, Macro F1=81.36%
# Epoch 76: Train Acc=97.06%, Val Acc=96.90%, F1=96.87%, Macro F1=81.42%
# Epoch 77: Train Acc=97.12%, Val Acc=96.87%, F1=96.85%, Macro F1=81.28%
# Epoch 78: Train Acc=97.13%, Val Acc=96.95%, F1=96.94%, Macro F1=81.15%
# Epoch 79: Train Acc=97.17%, Val Acc=97.15%, F1=97.11%, Macro F1=81.61%
# Epoch 80: Train Acc=97.16%, Val Acc=97.10%, F1=97.08%, Macro F1=81.76%
# Epoch 81: Train Acc=97.15%, Val Acc=96.84%, F1=96.82%, Macro F1=81.14%
# Epoch 82: Train Acc=97.19%, Val Acc=97.11%, F1=97.07%, Macro F1=81.97%
# Epoch 83: Train Acc=97.23%, Val Acc=97.15%, F1=97.12%, Macro F1=81.84%
# Epoch 84: Train Acc=97.23%, Val Acc=97.05%, F1=97.03%, Macro F1=81.58%
# Epoch 85: Train Acc=97.21%, Val Acc=97.20%, F1=97.17%, Macro F1=82.05%
# Epoch 86: Train Acc=97.23%, Val Acc=97.14%, F1=97.11%, Macro F1=82.21%
# Epoch 87: Train Acc=97.27%, Val Acc=97.27%, F1=97.24%, Macro F1=82.04%
# Epoch 88: Train Acc=97.27%, Val Acc=97.23%, F1=97.20%, Macro F1=82.00%
# Epoch 89: Train Acc=97.23%, Val Acc=97.34%, F1=97.31%, Macro F1=82.42%
# Epoch 90: Train Acc=97.33%, Val Acc=97.26%, F1=97.23%, Macro F1=82.26%
# Epoch 91: Train Acc=97.29%, Val Acc=96.89%, F1=96.84%, Macro F1=80.69%
# Epoch 92: Train Acc=97.32%, Val Acc=97.21%, F1=97.17%, Macro F1=81.67%
# Epoch 93: Train Acc=97.29%, Val Acc=97.29%, F1=97.25%, Macro F1=81.93%
# Epoch 94: Train Acc=97.38%, Val Acc=97.27%, F1=97.25%, Macro F1=82.12%
# Epoch 95: Train Acc=97.35%, Val Acc=97.31%, F1=97.28%, Macro F1=82.49%
# Epoch 96: Train Acc=97.35%, Val Acc=97.36%, F1=97.34%, Macro F1=82.15%
# Epoch 97: Train Acc=97.41%, Val Acc=97.26%, F1=97.23%, Macro F1=82.32%
# Epoch 98: Train Acc=97.45%, Val Acc=97.16%, F1=97.13%, Macro F1=82.35%
# Epoch 99: Train Acc=97.44%, Val Acc=97.25%, F1=97.23%, Macro F1=82.12%
# Epoch 100: Train Acc=97.51%, Val Acc=97.21%, F1=97.18%, Macro F1=82.45%
# Epoch 101: Train Acc=97.48%, Val Acc=97.39%, F1=97.36%, Macro F1=82.52%
# Epoch 102: Train Acc=97.54%, Val Acc=97.43%, F1=97.40%, Macro F1=82.54%
# Epoch 103: Train Acc=97.60%, Val Acc=97.64%, F1=97.61%, Macro F1=83.00%
# Epoch 104: Train Acc=97.57%, Val Acc=97.31%, F1=97.28%, Macro F1=81.97%
# Epoch 105: Train Acc=97.58%, Val Acc=97.57%, F1=97.55%, Macro F1=83.07%
# Epoch 106: Train Acc=97.57%, Val Acc=97.68%, F1=97.65%, Macro F1=83.04%
# Epoch 107: Train Acc=97.61%, Val Acc=97.34%, F1=97.31%, Macro F1=82.49%
# Epoch 108: Train Acc=97.57%, Val Acc=97.61%, F1=97.59%, Macro F1=82.80%
# Epoch 109: Train Acc=97.62%, Val Acc=97.47%, F1=97.45%, Macro F1=82.73%
# Epoch 110: Train Acc=97.70%, Val Acc=97.32%, F1=97.29%, Macro F1=82.61%
# Epoch 111: Train Acc=97.66%, Val Acc=97.41%, F1=97.38%, Macro F1=83.09%
# Epoch 112: Train Acc=97.69%, Val Acc=97.61%, F1=97.58%, Macro F1=83.29%
# Epoch 113: Train Acc=97.70%, Val Acc=97.51%, F1=97.48%, Macro F1=82.67%
# Epoch 114: Train Acc=97.72%, Val Acc=97.78%, F1=97.75%, Macro F1=83.41%
# Epoch 115: Train Acc=97.67%, Val Acc=97.40%, F1=97.37%, Macro F1=82.58%
# Epoch 116: Train Acc=97.73%, Val Acc=97.75%, F1=97.72%, Macro F1=83.44%
# Epoch 117: Train Acc=97.75%, Val Acc=97.76%, F1=97.74%, Macro F1=83.57%
# Epoch 118: Train Acc=97.78%, Val Acc=97.81%, F1=97.78%, Macro F1=83.43%
# Epoch 119: Train Acc=97.74%, Val Acc=97.55%, F1=97.52%, Macro F1=83.00%
# Epoch 120: Train Acc=97.77%, Val Acc=97.61%, F1=97.58%, Macro F1=83.39%
# Epoch 121: Train Acc=97.76%, Val Acc=97.75%, F1=97.72%, Macro F1=83.31%
# Epoch 122: Train Acc=97.78%, Val Acc=97.92%, F1=97.90%, Macro F1=83.73%
# Epoch 123: Train Acc=97.80%, Val Acc=97.87%, F1=97.85%, Macro F1=83.69%
# Epoch 124: Train Acc=97.79%, Val Acc=97.88%, F1=97.85%, Macro F1=83.74%
# Epoch 125: Train Acc=97.86%, Val Acc=97.81%, F1=97.78%, Macro F1=83.65%
# Epoch 126: Train Acc=97.70%, Val Acc=97.49%, F1=97.46%, Macro F1=82.60%
# Epoch 127: Train Acc=97.77%, Val Acc=97.52%, F1=97.50%, Macro F1=82.67%
# Epoch 128: Train Acc=97.79%, Val Acc=97.76%, F1=97.73%, Macro F1=83.50%
# Epoch 129: Train Acc=97.81%, Val Acc=97.89%, F1=97.87%, Macro F1=83.67%
# Epoch 130: Train Acc=97.86%, Val Acc=97.04%, F1=96.97%, Macro F1=80.58%
# Epoch 131: Train Acc=97.84%, Val Acc=97.73%, F1=97.70%, Macro F1=83.67%
# Epoch 132: Train Acc=97.85%, Val Acc=97.90%, F1=97.87%, Macro F1=83.66%
# Epoch 133: Train Acc=97.89%, Val Acc=97.72%, F1=97.70%, Macro F1=83.25%
# Epoch 134: Train Acc=97.89%, Val Acc=97.76%, F1=97.74%, Macro F1=83.29%
# Epoch 135: Train Acc=97.92%, Val Acc=97.59%, F1=97.57%, Macro F1=82.62%
# Epoch 136: Train Acc=97.91%, Val Acc=97.96%, F1=97.93%, Macro F1=83.77%
# Epoch 137: Train Acc=97.95%, Val Acc=97.93%, F1=97.91%, Macro F1=83.72%
# Epoch 138: Train Acc=97.96%, Val Acc=97.92%, F1=97.90%, Macro F1=83.79%
# Epoch 139: Train Acc=97.98%, Val Acc=97.87%, F1=97.85%, Macro F1=87.93%
# Epoch 140: Train Acc=97.96%, Val Acc=97.90%, F1=97.88%, Macro F1=83.78%
# Epoch 141: Train Acc=98.00%, Val Acc=97.91%, F1=97.88%, Macro F1=83.72%
# Epoch 142: Train Acc=98.03%, Val Acc=97.88%, F1=97.86%, Macro F1=83.88%
# Epoch 143: Train Acc=98.00%, Val Acc=98.02%, F1=97.99%, Macro F1=84.01%
# Epoch 144: Train Acc=98.00%, Val Acc=98.00%, F1=97.97%, Macro F1=83.92%
# Epoch 145: Train Acc=98.00%, Val Acc=97.99%, F1=97.96%, Macro F1=83.94%
# Epoch 146: Train Acc=98.05%, Val Acc=98.02%, F1=98.00%, Macro F1=83.99%
# Epoch 147: Train Acc=98.04%, Val Acc=98.04%, F1=98.02%, Macro F1=84.01%
# Epoch 148: Train Acc=98.05%, Val Acc=97.67%, F1=97.65%, Macro F1=83.08%
# Epoch 149: Train Acc=98.08%, Val Acc=98.02%, F1=98.00%, Macro F1=83.97%
# Epoch 150: Train Acc=98.06%, Val Acc=97.71%, F1=97.70%, Macro F1=87.07%
# Epoch 151: Train Acc=98.06%, Val Acc=98.02%, F1=97.99%, Macro F1=83.95%
# Epoch 152: Train Acc=98.08%, Val Acc=97.59%, F1=97.58%, Macro F1=87.06%
# Epoch 153: Train Acc=98.08%, Val Acc=97.96%, F1=97.94%, Macro F1=83.96%
# Epoch 154: Train Acc=98.11%, Val Acc=98.02%, F1=98.00%, Macro F1=87.99%
# Epoch 155: Train Acc=98.07%, Val Acc=97.81%, F1=97.79%, Macro F1=87.71%
# Epoch 156: Train Acc=98.07%, Val Acc=97.96%, F1=97.93%, Macro F1=83.97%
# Epoch 157: Train Acc=98.07%, Val Acc=97.97%, F1=97.94%, Macro F1=83.83%
# Epoch 158: Train Acc=98.12%, Val Acc=98.06%, F1=98.03%, Macro F1=84.14%
# Epoch 159: Train Acc=98.09%, Val Acc=97.82%, F1=97.80%, Macro F1=87.76%
# Epoch 160: Train Acc=98.10%, Val Acc=98.02%, F1=97.99%, Macro F1=83.99%
# Epoch 161: Train Acc=98.14%, Val Acc=98.00%, F1=97.98%, Macro F1=88.16%
# Epoch 162: Train Acc=98.13%, Val Acc=97.85%, F1=97.83%, Macro F1=88.07%
# Epoch 163: Train Acc=98.12%, Val Acc=98.05%, F1=98.03%, Macro F1=87.92%
# Epoch 164: Train Acc=98.12%, Val Acc=98.08%, F1=98.05%, Macro F1=84.02%
# Epoch 165: Train Acc=98.14%, Val Acc=98.02%, F1=98.01%, Macro F1=88.04%
# Epoch 166: Train Acc=98.12%, Val Acc=98.02%, F1=98.01%, Macro F1=88.11%
# Epoch 167: Train Acc=98.15%, Val Acc=98.06%, F1=98.03%, Macro F1=83.93%
# Epoch 168: Train Acc=98.13%, Val Acc=98.08%, F1=98.06%, Macro F1=84.08%
# Epoch 169: Train Acc=98.13%, Val Acc=98.11%, F1=98.09%, Macro F1=84.12%
# Epoch 170: Train Acc=98.15%, Val Acc=97.85%, F1=97.84%, Macro F1=87.31%
# Epoch 171: Train Acc=98.13%, Val Acc=98.04%, F1=98.02%, Macro F1=84.10%
# Epoch 172: Train Acc=98.14%, Val Acc=98.02%, F1=98.01%, Macro F1=88.05%
# Epoch 173: Train Acc=98.18%, Val Acc=97.93%, F1=97.91%, Macro F1=87.98%
# Epoch 174: Train Acc=98.16%, Val Acc=98.09%, F1=98.07%, Macro F1=84.03%
# Epoch 175: Train Acc=98.15%, Val Acc=98.00%, F1=97.98%, Macro F1=88.06%
# Epoch 176: Train Acc=98.12%, Val Acc=97.98%, F1=97.97%, Macro F1=88.04%
# Epoch 177: Train Acc=98.17%, Val Acc=97.96%, F1=97.95%, Macro F1=88.02%
# Epoch 178: Train Acc=98.15%, Val Acc=98.07%, F1=98.06%, Macro F1=88.09%
# Epoch 179: Train Acc=98.16%, Val Acc=98.08%, F1=98.06%, Macro F1=88.11%
# Epoch 180: Train Acc=98.16%, Val Acc=97.93%, F1=97.91%, Macro F1=88.07%
# Epoch 181: Train Acc=98.17%, Val Acc=98.07%, F1=98.06%, Macro F1=88.16%
# Epoch 182: Train Acc=98.17%, Val Acc=97.99%, F1=97.97%, Macro F1=88.02%
# Epoch 183: Train Acc=98.19%, Val Acc=98.04%, F1=98.02%, Macro F1=84.07%
# Epoch 184: Train Acc=98.16%, Val Acc=98.06%, F1=98.04%, Macro F1=88.17%
# Epoch 185: Train Acc=98.16%, Val Acc=98.08%, F1=98.05%, Macro F1=83.95%
# Epoch 186: Train Acc=98.16%, Val Acc=98.06%, F1=98.05%, Macro F1=87.83%
# Epoch 187: Train Acc=98.19%, Val Acc=98.04%, F1=98.01%, Macro F1=83.86%
# Epoch 188: Train Acc=98.20%, Val Acc=98.21%, F1=98.19%, Macro F1=88.19%
# Epoch 189: Train Acc=98.18%, Val Acc=97.97%, F1=97.94%, Macro F1=83.94%
# Epoch 190: Train Acc=98.19%, Val Acc=98.08%, F1=98.05%, Macro F1=84.12%
# Epoch 191: Train Acc=98.21%, Val Acc=98.07%, F1=98.06%, Macro F1=88.16%
# Epoch 192: Train Acc=98.16%, Val Acc=98.12%, F1=98.10%, Macro F1=84.18%
# Epoch 193: Train Acc=98.18%, Val Acc=98.12%, F1=98.10%, Macro F1=84.14%
# Epoch 194: Train Acc=98.17%, Val Acc=98.10%, F1=98.08%, Macro F1=88.03%
# Epoch 195: Train Acc=98.21%, Val Acc=97.91%, F1=97.89%, Macro F1=87.80%
# Epoch 196: Train Acc=98.22%, Val Acc=98.11%, F1=98.09%, Macro F1=87.92%
# Epoch 197: Train Acc=98.19%, Val Acc=98.15%, F1=98.13%, Macro F1=88.25%
# Epoch 198: Train Acc=98.19%, Val Acc=98.15%, F1=98.13%, Macro F1=84.10%
# Epoch 199: Train Acc=98.20%, Val Acc=98.12%, F1=98.10%, Macro F1=88.20%
# Epoch 200: Train Acc=98.20%, Val Acc=98.11%, F1=98.10%, Macro F1=88.20%
#
# Fold 3/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=62.12%, Val Acc=79.44%, F1=73.15%, Macro F1=37.19%
# Epoch 2: Train Acc=80.19%, Val Acc=81.65%, F1=77.99%, Macro F1=41.96%
# Epoch 3: Train Acc=86.00%, Val Acc=89.24%, F1=87.43%, Macro F1=51.80%
# Epoch 4: Train Acc=90.57%, Val Acc=91.15%, F1=90.19%, Macro F1=64.27%
# Epoch 5: Train Acc=91.13%, Val Acc=92.24%, F1=91.21%, Macro F1=65.03%
# Epoch 6: Train Acc=92.43%, Val Acc=93.08%, F1=92.57%, Macro F1=70.53%
# Epoch 7: Train Acc=93.17%, Val Acc=93.45%, F1=92.93%, Macro F1=70.82%
# Epoch 8: Train Acc=93.72%, Val Acc=94.04%, F1=93.79%, Macro F1=74.20%
# Epoch 9: Train Acc=94.34%, Val Acc=95.04%, F1=94.96%, Macro F1=78.17%
# Epoch 10: Train Acc=94.94%, Val Acc=94.86%, F1=94.75%, Macro F1=76.93%
# Epoch 11: Train Acc=95.27%, Val Acc=95.54%, F1=95.45%, Macro F1=78.10%
# Epoch 12: Train Acc=95.47%, Val Acc=95.90%, F1=95.85%, Macro F1=79.07%
# Epoch 13: Train Acc=95.59%, Val Acc=95.82%, F1=95.77%, Macro F1=79.08%
# Epoch 14: Train Acc=95.69%, Val Acc=95.67%, F1=95.57%, Macro F1=78.21%
# Epoch 15: Train Acc=95.73%, Val Acc=95.99%, F1=95.94%, Macro F1=79.45%
# Epoch 16: Train Acc=95.86%, Val Acc=95.75%, F1=95.68%, Macro F1=78.72%
# Epoch 17: Train Acc=95.94%, Val Acc=96.07%, F1=96.02%, Macro F1=79.38%
# Epoch 18: Train Acc=95.99%, Val Acc=95.86%, F1=95.75%, Macro F1=77.97%
# Epoch 19: Train Acc=95.97%, Val Acc=96.05%, F1=95.99%, Macro F1=78.93%
# Epoch 20: Train Acc=96.09%, Val Acc=96.12%, F1=96.07%, Macro F1=79.65%
# Epoch 21: Train Acc=96.11%, Val Acc=96.28%, F1=96.22%, Macro F1=79.65%
# Epoch 22: Train Acc=96.23%, Val Acc=96.37%, F1=96.31%, Macro F1=79.56%
# Epoch 23: Train Acc=96.29%, Val Acc=96.37%, F1=96.32%, Macro F1=79.97%
# Epoch 24: Train Acc=96.35%, Val Acc=96.59%, F1=96.53%, Macro F1=80.08%
# Epoch 25: Train Acc=96.32%, Val Acc=96.45%, F1=96.41%, Macro F1=80.11%
# Epoch 26: Train Acc=96.38%, Val Acc=96.48%, F1=96.42%, Macro F1=79.94%
# Epoch 27: Train Acc=96.38%, Val Acc=96.37%, F1=96.32%, Macro F1=80.06%
# Epoch 28: Train Acc=96.51%, Val Acc=96.33%, F1=96.28%, Macro F1=79.82%
# Epoch 29: Train Acc=96.49%, Val Acc=96.63%, F1=96.60%, Macro F1=80.38%
# Epoch 30: Train Acc=96.46%, Val Acc=96.75%, F1=96.71%, Macro F1=80.52%
# Epoch 31: Train Acc=96.51%, Val Acc=96.53%, F1=96.49%, Macro F1=80.12%
# Epoch 32: Train Acc=96.60%, Val Acc=96.61%, F1=96.56%, Macro F1=80.00%
# Epoch 33: Train Acc=96.62%, Val Acc=96.72%, F1=96.68%, Macro F1=80.55%
# Epoch 34: Train Acc=96.67%, Val Acc=96.68%, F1=96.63%, Macro F1=80.28%
# Epoch 35: Train Acc=96.68%, Val Acc=96.84%, F1=96.79%, Macro F1=80.63%
# Epoch 36: Train Acc=96.70%, Val Acc=96.78%, F1=96.74%, Macro F1=80.61%
# Epoch 37: Train Acc=96.70%, Val Acc=96.91%, F1=96.89%, Macro F1=80.76%
# Epoch 38: Train Acc=96.80%, Val Acc=96.82%, F1=96.78%, Macro F1=80.62%
# Epoch 39: Train Acc=96.78%, Val Acc=96.86%, F1=96.81%, Macro F1=80.64%
# Epoch 40: Train Acc=96.83%, Val Acc=96.89%, F1=96.86%, Macro F1=80.88%
# Epoch 41: Train Acc=96.76%, Val Acc=96.95%, F1=96.90%, Macro F1=80.62%
# Epoch 42: Train Acc=96.82%, Val Acc=96.96%, F1=96.93%, Macro F1=80.91%
# Epoch 43: Train Acc=96.81%, Val Acc=96.96%, F1=96.92%, Macro F1=80.92%
# Epoch 44: Train Acc=96.86%, Val Acc=96.80%, F1=96.75%, Macro F1=80.45%
# Epoch 45: Train Acc=96.88%, Val Acc=96.96%, F1=96.92%, Macro F1=80.86%
# Epoch 46: Train Acc=96.87%, Val Acc=96.97%, F1=96.92%, Macro F1=80.86%
# Epoch 47: Train Acc=96.88%, Val Acc=96.87%, F1=96.85%, Macro F1=81.13%
# Epoch 48: Train Acc=96.95%, Val Acc=97.01%, F1=96.97%, Macro F1=81.08%
# Epoch 49: Train Acc=96.94%, Val Acc=96.97%, F1=96.94%, Macro F1=81.01%
# Epoch 50: Train Acc=96.99%, Val Acc=97.08%, F1=97.05%, Macro F1=81.31%
# Epoch 51: Train Acc=97.00%, Val Acc=97.05%, F1=97.01%, Macro F1=81.22%
# Epoch 52: Train Acc=97.04%, Val Acc=97.04%, F1=97.02%, Macro F1=81.35%
# Epoch 53: Train Acc=97.05%, Val Acc=97.09%, F1=97.06%, Macro F1=81.37%
# Epoch 54: Train Acc=97.06%, Val Acc=97.16%, F1=97.13%, Macro F1=81.46%
# Epoch 55: Train Acc=97.06%, Val Acc=97.08%, F1=97.05%, Macro F1=81.30%
# Epoch 56: Train Acc=97.15%, Val Acc=97.15%, F1=97.12%, Macro F1=81.52%
# Epoch 57: Train Acc=97.16%, Val Acc=97.12%, F1=97.09%, Macro F1=81.56%
# Epoch 58: Train Acc=97.12%, Val Acc=96.99%, F1=96.96%, Macro F1=81.21%
# Epoch 59: Train Acc=97.15%, Val Acc=97.16%, F1=97.13%, Macro F1=81.48%
# Epoch 60: Train Acc=97.18%, Val Acc=97.30%, F1=97.28%, Macro F1=81.87%
# Epoch 61: Train Acc=97.18%, Val Acc=97.12%, F1=97.09%, Macro F1=81.40%
# Epoch 62: Train Acc=97.21%, Val Acc=97.14%, F1=97.11%, Macro F1=81.48%
# Epoch 63: Train Acc=97.25%, Val Acc=97.31%, F1=97.29%, Macro F1=81.88%
# Epoch 64: Train Acc=97.23%, Val Acc=97.23%, F1=97.21%, Macro F1=81.77%
# Epoch 65: Train Acc=97.28%, Val Acc=97.31%, F1=97.28%, Macro F1=82.01%
# Epoch 66: Train Acc=97.29%, Val Acc=97.27%, F1=97.25%, Macro F1=82.00%
# Epoch 67: Train Acc=97.29%, Val Acc=97.19%, F1=97.16%, Macro F1=81.71%
# Epoch 68: Train Acc=97.33%, Val Acc=97.25%, F1=97.22%, Macro F1=81.69%
# Epoch 69: Train Acc=97.32%, Val Acc=97.32%, F1=97.29%, Macro F1=81.93%
# Epoch 70: Train Acc=97.35%, Val Acc=97.44%, F1=97.42%, Macro F1=82.23%
# Epoch 71: Train Acc=97.40%, Val Acc=97.25%, F1=97.23%, Macro F1=81.92%
# Epoch 72: Train Acc=97.45%, Val Acc=97.43%, F1=97.40%, Macro F1=82.27%
# Epoch 73: Train Acc=97.43%, Val Acc=97.31%, F1=97.27%, Macro F1=82.03%
# Epoch 74: Train Acc=97.48%, Val Acc=97.35%, F1=97.32%, Macro F1=82.01%
# Epoch 75: Train Acc=97.45%, Val Acc=97.49%, F1=97.47%, Macro F1=82.51%
# Epoch 76: Train Acc=97.50%, Val Acc=97.40%, F1=97.37%, Macro F1=82.10%
# Epoch 77: Train Acc=97.50%, Val Acc=97.51%, F1=97.48%, Macro F1=82.58%
# Epoch 78: Train Acc=97.53%, Val Acc=97.51%, F1=97.49%, Macro F1=82.43%
# Epoch 79: Train Acc=97.59%, Val Acc=97.55%, F1=97.52%, Macro F1=82.83%
# Epoch 80: Train Acc=97.62%, Val Acc=97.56%, F1=97.54%, Macro F1=82.86%
# Epoch 81: Train Acc=97.58%, Val Acc=97.63%, F1=97.61%, Macro F1=83.03%
# Epoch 82: Train Acc=97.68%, Val Acc=97.66%, F1=97.64%, Macro F1=83.06%
# Epoch 83: Train Acc=97.67%, Val Acc=97.70%, F1=97.68%, Macro F1=83.06%
# Epoch 84: Train Acc=97.67%, Val Acc=97.46%, F1=97.44%, Macro F1=82.42%
# Epoch 85: Train Acc=97.69%, Val Acc=97.67%, F1=97.65%, Macro F1=83.03%
# Epoch 86: Train Acc=97.70%, Val Acc=97.49%, F1=97.46%, Macro F1=82.75%
# Epoch 87: Train Acc=97.72%, Val Acc=97.48%, F1=97.45%, Macro F1=82.45%
# Epoch 88: Train Acc=97.74%, Val Acc=97.78%, F1=97.76%, Macro F1=83.17%
# Epoch 89: Train Acc=97.75%, Val Acc=97.74%, F1=97.71%, Macro F1=82.86%
# Epoch 90: Train Acc=97.80%, Val Acc=97.76%, F1=97.74%, Macro F1=83.05%
# Epoch 91: Train Acc=97.75%, Val Acc=97.73%, F1=97.71%, Macro F1=83.01%
# Epoch 92: Train Acc=97.79%, Val Acc=97.71%, F1=97.69%, Macro F1=82.71%
# Epoch 93: Train Acc=97.77%, Val Acc=97.76%, F1=97.74%, Macro F1=82.99%
# Epoch 94: Train Acc=97.81%, Val Acc=97.84%, F1=97.82%, Macro F1=83.30%
# Epoch 95: Train Acc=97.83%, Val Acc=97.83%, F1=97.81%, Macro F1=83.03%
# Epoch 96: Train Acc=97.87%, Val Acc=97.73%, F1=97.71%, Macro F1=83.17%
# Epoch 97: Train Acc=97.84%, Val Acc=97.76%, F1=97.74%, Macro F1=82.92%
# Epoch 98: Train Acc=97.92%, Val Acc=97.89%, F1=97.87%, Macro F1=83.31%
# Epoch 99: Train Acc=97.89%, Val Acc=97.89%, F1=97.87%, Macro F1=83.29%
# Epoch 100: Train Acc=97.94%, Val Acc=97.79%, F1=97.77%, Macro F1=83.36%
# Epoch 101: Train Acc=97.99%, Val Acc=97.95%, F1=97.93%, Macro F1=83.43%
# Epoch 102: Train Acc=98.03%, Val Acc=97.96%, F1=97.94%, Macro F1=83.53%
# Epoch 103: Train Acc=98.01%, Val Acc=97.91%, F1=97.89%, Macro F1=83.33%
# Epoch 104: Train Acc=98.04%, Val Acc=97.98%, F1=97.97%, Macro F1=83.58%
# Epoch 105: Train Acc=98.09%, Val Acc=97.91%, F1=97.90%, Macro F1=83.50%
# Epoch 106: Train Acc=98.07%, Val Acc=97.99%, F1=97.97%, Macro F1=83.61%
# Epoch 107: Train Acc=98.12%, Val Acc=97.97%, F1=97.95%, Macro F1=83.63%
# Epoch 108: Train Acc=98.10%, Val Acc=98.03%, F1=98.01%, Macro F1=83.48%
# Epoch 109: Train Acc=98.12%, Val Acc=98.04%, F1=98.02%, Macro F1=83.72%
# Epoch 110: Train Acc=98.16%, Val Acc=98.06%, F1=98.05%, Macro F1=83.65%
# Epoch 111: Train Acc=98.12%, Val Acc=98.00%, F1=97.98%, Macro F1=83.57%
# Epoch 112: Train Acc=98.16%, Val Acc=97.90%, F1=97.88%, Macro F1=83.62%
# Epoch 113: Train Acc=98.21%, Val Acc=98.03%, F1=98.01%, Macro F1=83.82%
# Epoch 114: Train Acc=98.21%, Val Acc=98.01%, F1=97.99%, Macro F1=83.65%
# Epoch 115: Train Acc=98.18%, Val Acc=98.02%, F1=98.01%, Macro F1=83.76%
# Epoch 116: Train Acc=98.19%, Val Acc=98.11%, F1=98.09%, Macro F1=83.73%
# Epoch 117: Train Acc=98.20%, Val Acc=98.11%, F1=98.10%, Macro F1=83.86%
# Epoch 118: Train Acc=98.22%, Val Acc=98.21%, F1=98.20%, Macro F1=83.86%
# Epoch 119: Train Acc=98.20%, Val Acc=98.12%, F1=98.10%, Macro F1=83.71%
# Epoch 120: Train Acc=98.22%, Val Acc=98.09%, F1=98.07%, Macro F1=83.73%
# Epoch 121: Train Acc=98.20%, Val Acc=97.88%, F1=97.86%, Macro F1=83.44%
# Epoch 122: Train Acc=98.22%, Val Acc=98.00%, F1=97.99%, Macro F1=83.85%
# Epoch 123: Train Acc=98.23%, Val Acc=98.19%, F1=98.17%, Macro F1=83.94%
# Epoch 124: Train Acc=98.24%, Val Acc=98.04%, F1=98.02%, Macro F1=83.64%
# Epoch 125: Train Acc=98.24%, Val Acc=98.14%, F1=98.12%, Macro F1=83.97%
# Epoch 126: Train Acc=98.25%, Val Acc=98.25%, F1=98.23%, Macro F1=83.93%
# Epoch 127: Train Acc=98.25%, Val Acc=98.26%, F1=98.24%, Macro F1=83.79%
# Epoch 128: Train Acc=98.29%, Val Acc=98.11%, F1=98.10%, Macro F1=83.66%
# Epoch 129: Train Acc=98.23%, Val Acc=98.03%, F1=98.01%, Macro F1=83.66%
# Epoch 130: Train Acc=98.26%, Val Acc=98.01%, F1=97.99%, Macro F1=83.73%
# Epoch 131: Train Acc=98.23%, Val Acc=98.04%, F1=98.02%, Macro F1=83.64%
# Epoch 132: Train Acc=98.28%, Val Acc=98.25%, F1=98.23%, Macro F1=84.03%
# Epoch 133: Train Acc=98.29%, Val Acc=97.98%, F1=97.96%, Macro F1=83.82%
# Epoch 134: Train Acc=98.26%, Val Acc=98.11%, F1=98.10%, Macro F1=83.76%
# Epoch 135: Train Acc=98.28%, Val Acc=98.08%, F1=98.06%, Macro F1=83.86%
# Epoch 136: Train Acc=98.26%, Val Acc=98.20%, F1=98.18%, Macro F1=83.99%
# Epoch 137: Train Acc=98.24%, Val Acc=98.11%, F1=98.09%, Macro F1=83.80%
# Epoch 138: Train Acc=98.28%, Val Acc=97.90%, F1=97.88%, Macro F1=83.49%
# Epoch 139: Train Acc=98.31%, Val Acc=98.17%, F1=98.15%, Macro F1=83.95%
# Epoch 140: Train Acc=98.33%, Val Acc=98.17%, F1=98.16%, Macro F1=83.79%
# Epoch 141: Train Acc=98.29%, Val Acc=98.12%, F1=98.10%, Macro F1=83.74%
# Epoch 142: Train Acc=98.29%, Val Acc=98.12%, F1=98.10%, Macro F1=83.73%
# Epoch 143: Train Acc=98.33%, Val Acc=98.23%, F1=98.22%, Macro F1=83.98%
# Epoch 144: Train Acc=98.32%, Val Acc=98.26%, F1=98.24%, Macro F1=83.92%
# Epoch 145: Train Acc=98.33%, Val Acc=98.17%, F1=98.16%, Macro F1=83.82%
# Epoch 146: Train Acc=98.31%, Val Acc=98.28%, F1=98.26%, Macro F1=83.88%
# Epoch 147: Train Acc=98.33%, Val Acc=98.10%, F1=98.08%, Macro F1=83.73%
# Epoch 148: Train Acc=98.32%, Val Acc=98.26%, F1=98.24%, Macro F1=83.97%
# Epoch 149: Train Acc=98.32%, Val Acc=98.11%, F1=98.10%, Macro F1=83.90%
# Epoch 150: Train Acc=98.36%, Val Acc=98.08%, F1=98.07%, Macro F1=83.75%
# Epoch 151: Train Acc=98.33%, Val Acc=98.20%, F1=98.18%, Macro F1=83.91%
# Epoch 152: Train Acc=98.33%, Val Acc=98.20%, F1=98.18%, Macro F1=83.85%
# Epoch 153: Train Acc=98.33%, Val Acc=98.13%, F1=98.12%, Macro F1=84.00%
# Epoch 154: Train Acc=98.34%, Val Acc=97.58%, F1=97.57%, Macro F1=83.36%
# Epoch 155: Train Acc=98.33%, Val Acc=98.17%, F1=98.16%, Macro F1=83.62%
# Epoch 156: Train Acc=98.37%, Val Acc=98.11%, F1=98.09%, Macro F1=83.69%
# Epoch 157: Train Acc=98.34%, Val Acc=98.27%, F1=98.25%, Macro F1=84.00%
# Epoch 158: Train Acc=98.36%, Val Acc=98.24%, F1=98.22%, Macro F1=83.81%
# Epoch 159: Train Acc=98.37%, Val Acc=98.24%, F1=98.22%, Macro F1=83.92%
# Epoch 160: Train Acc=98.39%, Val Acc=98.31%, F1=98.29%, Macro F1=83.96%
# Epoch 161: Train Acc=98.37%, Val Acc=98.36%, F1=98.35%, Macro F1=84.01%
# Epoch 162: Train Acc=98.36%, Val Acc=98.30%, F1=98.28%, Macro F1=84.00%
# Epoch 163: Train Acc=98.37%, Val Acc=98.22%, F1=98.20%, Macro F1=83.92%
# Epoch 164: Train Acc=98.39%, Val Acc=98.21%, F1=98.20%, Macro F1=83.89%
# Epoch 165: Train Acc=98.38%, Val Acc=98.11%, F1=98.10%, Macro F1=83.97%
# Epoch 166: Train Acc=98.41%, Val Acc=98.24%, F1=98.23%, Macro F1=83.97%
# Epoch 167: Train Acc=98.38%, Val Acc=98.21%, F1=98.20%, Macro F1=83.88%
# Epoch 168: Train Acc=98.39%, Val Acc=98.23%, F1=98.21%, Macro F1=83.79%
# Epoch 169: Train Acc=98.37%, Val Acc=98.20%, F1=98.19%, Macro F1=83.87%
# Epoch 170: Train Acc=98.40%, Val Acc=98.23%, F1=98.22%, Macro F1=83.99%
# Epoch 171: Train Acc=98.37%, Val Acc=98.24%, F1=98.22%, Macro F1=83.92%
# Epoch 172: Train Acc=98.40%, Val Acc=98.16%, F1=98.14%, Macro F1=83.84%
# Epoch 173: Train Acc=98.39%, Val Acc=98.33%, F1=98.31%, Macro F1=83.89%
# Epoch 174: Train Acc=98.40%, Val Acc=98.11%, F1=98.09%, Macro F1=83.84%
# Epoch 175: Train Acc=98.41%, Val Acc=98.24%, F1=98.22%, Macro F1=83.77%
# Epoch 176: Train Acc=98.39%, Val Acc=98.12%, F1=98.10%, Macro F1=83.97%
# Epoch 177: Train Acc=98.39%, Val Acc=98.27%, F1=98.25%, Macro F1=83.94%
# Epoch 178: Train Acc=98.40%, Val Acc=98.17%, F1=98.15%, Macro F1=83.65%
# Epoch 179: Train Acc=98.46%, Val Acc=98.16%, F1=98.14%, Macro F1=83.93%
# Epoch 180: Train Acc=98.42%, Val Acc=98.16%, F1=98.14%, Macro F1=83.84%
# Epoch 181: Train Acc=98.39%, Val Acc=98.11%, F1=98.10%, Macro F1=83.83%
# Epoch 182: Train Acc=98.42%, Val Acc=98.26%, F1=98.24%, Macro F1=83.73%
# Epoch 183: Train Acc=98.44%, Val Acc=98.32%, F1=98.31%, Macro F1=83.93%
# Epoch 184: Train Acc=98.44%, Val Acc=98.31%, F1=98.29%, Macro F1=83.93%
# Epoch 185: Train Acc=98.40%, Val Acc=98.19%, F1=98.18%, Macro F1=83.86%
# Epoch 186: Train Acc=98.39%, Val Acc=98.11%, F1=98.09%, Macro F1=83.72%
# Epoch 187: Train Acc=98.43%, Val Acc=98.14%, F1=98.12%, Macro F1=83.79%
# Epoch 188: Train Acc=98.44%, Val Acc=98.28%, F1=98.26%, Macro F1=83.80%
# Epoch 189: Train Acc=98.42%, Val Acc=98.13%, F1=98.11%, Macro F1=83.81%
# Epoch 190: Train Acc=98.43%, Val Acc=98.19%, F1=98.17%, Macro F1=83.88%
# Epoch 191: Train Acc=98.44%, Val Acc=98.30%, F1=98.28%, Macro F1=83.98%
# Epoch 192: Train Acc=98.43%, Val Acc=98.19%, F1=98.17%, Macro F1=83.93%
# Epoch 193: Train Acc=98.42%, Val Acc=98.32%, F1=98.30%, Macro F1=84.10%
# Epoch 194: Train Acc=98.44%, Val Acc=98.37%, F1=98.35%, Macro F1=84.08%
# Epoch 195: Train Acc=98.42%, Val Acc=98.33%, F1=98.31%, Macro F1=84.08%
# Epoch 196: Train Acc=98.43%, Val Acc=98.23%, F1=98.22%, Macro F1=83.74%
# Epoch 197: Train Acc=98.45%, Val Acc=98.29%, F1=98.27%, Macro F1=84.00%
# Epoch 198: Train Acc=98.45%, Val Acc=98.30%, F1=98.29%, Macro F1=84.07%
# Epoch 199: Train Acc=98.47%, Val Acc=98.24%, F1=98.23%, Macro F1=83.70%
# Epoch 200: Train Acc=98.46%, Val Acc=98.32%, F1=98.30%, Macro F1=84.09%
#
# Fold 4/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=64.21%, Val Acc=82.69%, F1=81.05%, Macro F1=47.08%
# Epoch 2: Train Acc=85.13%, Val Acc=87.13%, F1=85.43%, Macro F1=50.53%
# Epoch 3: Train Acc=89.20%, Val Acc=90.01%, F1=89.12%, Macro F1=63.76%
# Epoch 4: Train Acc=90.41%, Val Acc=90.81%, F1=90.36%, Macro F1=69.13%
# Epoch 5: Train Acc=91.16%, Val Acc=91.45%, F1=90.99%, Macro F1=69.58%
# Epoch 6: Train Acc=91.65%, Val Acc=92.14%, F1=91.69%, Macro F1=70.13%
# Epoch 7: Train Acc=92.66%, Val Acc=93.16%, F1=93.03%, Macro F1=75.72%
# Epoch 8: Train Acc=93.79%, Val Acc=94.08%, F1=93.94%, Macro F1=76.15%
# Epoch 9: Train Acc=94.31%, Val Acc=94.53%, F1=94.47%, Macro F1=78.00%
# Epoch 10: Train Acc=94.63%, Val Acc=94.60%, F1=94.52%, Macro F1=77.28%
# Epoch 11: Train Acc=94.75%, Val Acc=94.48%, F1=94.42%, Macro F1=77.81%
# Epoch 12: Train Acc=94.89%, Val Acc=94.84%, F1=94.78%, Macro F1=78.08%
# Epoch 13: Train Acc=95.02%, Val Acc=95.17%, F1=95.13%, Macro F1=78.46%
# Epoch 14: Train Acc=95.20%, Val Acc=95.16%, F1=95.12%, Macro F1=78.60%
# Epoch 15: Train Acc=95.37%, Val Acc=95.35%, F1=95.31%, Macro F1=78.89%
# Epoch 16: Train Acc=95.42%, Val Acc=95.43%, F1=95.39%, Macro F1=78.96%
# Epoch 17: Train Acc=95.52%, Val Acc=95.45%, F1=95.40%, Macro F1=78.78%
# Epoch 18: Train Acc=95.61%, Val Acc=95.72%, F1=95.66%, Macro F1=79.13%
# Epoch 19: Train Acc=95.76%, Val Acc=95.75%, F1=95.70%, Macro F1=79.21%
# Epoch 20: Train Acc=95.87%, Val Acc=95.90%, F1=95.86%, Macro F1=79.48%
# Epoch 21: Train Acc=95.95%, Val Acc=95.97%, F1=95.92%, Macro F1=79.35%
# Epoch 22: Train Acc=95.99%, Val Acc=95.79%, F1=95.75%, Macro F1=79.61%
# Epoch 23: Train Acc=96.09%, Val Acc=96.17%, F1=96.14%, Macro F1=80.08%
# Epoch 24: Train Acc=96.17%, Val Acc=96.09%, F1=96.05%, Macro F1=79.95%
# Epoch 25: Train Acc=96.29%, Val Acc=96.06%, F1=96.02%, Macro F1=79.83%
# Epoch 26: Train Acc=96.29%, Val Acc=96.22%, F1=96.17%, Macro F1=80.22%
# Epoch 27: Train Acc=96.38%, Val Acc=96.43%, F1=96.40%, Macro F1=80.86%
# Epoch 28: Train Acc=96.47%, Val Acc=96.41%, F1=96.38%, Macro F1=80.68%
# Epoch 29: Train Acc=96.58%, Val Acc=96.61%, F1=96.58%, Macro F1=80.66%
# Epoch 30: Train Acc=96.59%, Val Acc=96.59%, F1=96.55%, Macro F1=81.16%
# Epoch 31: Train Acc=96.72%, Val Acc=96.67%, F1=96.63%, Macro F1=81.39%
# Epoch 32: Train Acc=96.74%, Val Acc=96.80%, F1=96.77%, Macro F1=81.32%
# Epoch 33: Train Acc=96.83%, Val Acc=96.69%, F1=96.66%, Macro F1=81.54%
# Epoch 34: Train Acc=96.83%, Val Acc=96.97%, F1=96.95%, Macro F1=81.74%
# Epoch 35: Train Acc=96.95%, Val Acc=97.00%, F1=96.97%, Macro F1=81.86%
# Epoch 36: Train Acc=96.97%, Val Acc=96.99%, F1=96.96%, Macro F1=81.79%
# Epoch 37: Train Acc=97.02%, Val Acc=96.90%, F1=96.87%, Macro F1=81.94%
# Epoch 38: Train Acc=97.09%, Val Acc=97.04%, F1=97.02%, Macro F1=82.09%
# Epoch 39: Train Acc=97.13%, Val Acc=97.24%, F1=97.22%, Macro F1=82.56%
# Epoch 40: Train Acc=97.19%, Val Acc=96.90%, F1=96.88%, Macro F1=82.11%
# Epoch 41: Train Acc=97.25%, Val Acc=97.27%, F1=97.24%, Macro F1=82.24%
# Epoch 42: Train Acc=97.30%, Val Acc=97.27%, F1=97.25%, Macro F1=82.57%
# Epoch 43: Train Acc=97.33%, Val Acc=97.31%, F1=97.29%, Macro F1=82.59%
# Epoch 44: Train Acc=97.37%, Val Acc=96.97%, F1=96.95%, Macro F1=81.91%
# Epoch 45: Train Acc=97.37%, Val Acc=97.45%, F1=97.43%, Macro F1=82.96%
# Epoch 46: Train Acc=97.43%, Val Acc=97.44%, F1=97.42%, Macro F1=82.85%
# Epoch 47: Train Acc=97.48%, Val Acc=97.49%, F1=97.47%, Macro F1=82.72%
# Epoch 48: Train Acc=97.47%, Val Acc=97.50%, F1=97.48%, Macro F1=83.00%
# Epoch 49: Train Acc=97.49%, Val Acc=97.55%, F1=97.54%, Macro F1=83.11%
# Epoch 50: Train Acc=97.56%, Val Acc=97.38%, F1=97.35%, Macro F1=82.84%
# Epoch 51: Train Acc=97.55%, Val Acc=97.46%, F1=97.44%, Macro F1=82.93%
# Epoch 52: Train Acc=97.61%, Val Acc=97.60%, F1=97.58%, Macro F1=83.02%
# Epoch 53: Train Acc=97.63%, Val Acc=97.58%, F1=97.56%, Macro F1=83.09%
# Epoch 54: Train Acc=97.61%, Val Acc=97.63%, F1=97.61%, Macro F1=83.11%
# Epoch 55: Train Acc=97.61%, Val Acc=97.64%, F1=97.63%, Macro F1=83.32%
# Epoch 56: Train Acc=97.72%, Val Acc=97.62%, F1=97.61%, Macro F1=83.13%
# Epoch 57: Train Acc=97.69%, Val Acc=97.70%, F1=97.68%, Macro F1=83.31%
# Epoch 58: Train Acc=97.71%, Val Acc=97.70%, F1=97.69%, Macro F1=83.34%
# Epoch 59: Train Acc=97.74%, Val Acc=97.72%, F1=97.71%, Macro F1=83.49%
# Epoch 60: Train Acc=97.75%, Val Acc=97.78%, F1=97.76%, Macro F1=83.61%
# Epoch 61: Train Acc=97.77%, Val Acc=97.61%, F1=97.59%, Macro F1=83.31%
# Epoch 62: Train Acc=97.78%, Val Acc=97.53%, F1=97.51%, Macro F1=83.23%
# Epoch 63: Train Acc=97.76%, Val Acc=97.72%, F1=97.71%, Macro F1=83.65%
# Epoch 64: Train Acc=97.79%, Val Acc=97.79%, F1=97.78%, Macro F1=83.66%
# Epoch 65: Train Acc=97.80%, Val Acc=97.85%, F1=97.83%, Macro F1=83.79%
# Epoch 66: Train Acc=97.83%, Val Acc=97.87%, F1=97.85%, Macro F1=83.75%
# Epoch 67: Train Acc=97.85%, Val Acc=97.59%, F1=97.57%, Macro F1=83.18%
# Epoch 68: Train Acc=97.83%, Val Acc=97.81%, F1=97.79%, Macro F1=83.51%
# ...
# Epoch 181: Train Acc=98.31%, Val Acc=98.25%, F1=98.24%, Macro F1=84.11%
# Epoch 182: Train Acc=98.32%, Val Acc=98.33%, F1=98.32%, Macro F1=84.21%
# Epoch 183: Train Acc=98.39%, Val Acc=98.19%, F1=98.18%, Macro F1=84.23%
# Epoch 184: Train Acc=98.38%, Val Acc=98.12%, F1=98.11%, Macro F1=83.95%
# Epoch 185: Train Acc=98.40%, Val Acc=98.23%, F1=98.22%, Macro F1=84.02%
# Epoch 186: Train Acc=98.37%, Val Acc=98.26%, F1=98.24%, Macro F1=83.96%
# Epoch 187: Train Acc=98.36%, Val Acc=98.28%, F1=98.27%, Macro F1=84.26%
# Epoch 188: Train Acc=98.38%, Val Acc=98.14%, F1=98.13%, Macro F1=84.03%
# Epoch 189: Train Acc=98.36%, Val Acc=98.11%, F1=98.09%, Macro F1=84.05%
# Epoch 190: Train Acc=98.38%, Val Acc=98.29%, F1=98.28%, Macro F1=84.04%
# Epoch 191: Train Acc=98.38%, Val Acc=98.38%, F1=98.37%, Macro F1=84.26%
# Epoch 192: Train Acc=98.37%, Val Acc=98.31%, F1=98.30%, Macro F1=84.13%
# Epoch 193: Train Acc=98.38%, Val Acc=98.33%, F1=98.32%, Macro F1=84.21%
# Epoch 194: Train Acc=98.38%, Val Acc=98.29%, F1=98.28%, Macro F1=83.99%
# Epoch 195: Train Acc=98.38%, Val Acc=98.37%, F1=98.36%, Macro F1=84.32%
# Epoch 196: Train Acc=98.40%, Val Acc=98.28%, F1=98.26%, Macro F1=84.07%
# Epoch 197: Train Acc=98.39%, Val Acc=98.11%, F1=98.09%, Macro F1=83.94%
# Epoch 198: Train Acc=98.38%, Val Acc=98.13%, F1=98.11%, Macro F1=84.01%
# Epoch 199: Train Acc=98.40%, Val Acc=98.32%, F1=98.31%, Macro F1=84.22%
# Epoch 200: Train Acc=98.39%, Val Acc=98.26%, F1=98.25%, Macro F1=84.07%
#
# Fold 5/5
# ------------------------------
# initializing model...
# Epoch 1: Train Acc=62.03%, Val Acc=78.27%, F1=72.34%, Macro F1=36.88%
# Epoch 2: Train Acc=79.30%, Val Acc=79.74%, F1=73.64%, Macro F1=37.53%
# Epoch 3: Train Acc=85.41%, Val Acc=88.41%, F1=86.94%, Macro F1=56.50%
# Epoch 4: Train Acc=90.75%, Val Acc=90.86%, F1=90.44%, Macro F1=69.96%
# Epoch 5: Train Acc=91.51%, Val Acc=91.83%, F1=91.56%, Macro F1=72.20%
# Epoch 6: Train Acc=92.41%, Val Acc=92.59%, F1=92.24%, Macro F1=71.95%
# Epoch 7: Train Acc=93.09%, Val Acc=92.92%, F1=92.54%, Macro F1=72.03%
# Epoch 8: Train Acc=93.56%, Val Acc=93.37%, F1=92.99%, Macro F1=72.38%
# Epoch 9: Train Acc=94.14%, Val Acc=93.95%, F1=93.85%, Macro F1=77.55%
# Epoch 10: Train Acc=94.75%, Val Acc=94.85%, F1=94.77%, Macro F1=78.37%
# Epoch 11: Train Acc=94.95%, Val Acc=95.04%, F1=94.97%, Macro F1=78.99%
# Epoch 12: Train Acc=95.08%, Val Acc=95.02%, F1=94.93%, Macro F1=78.57%
# Epoch 13: Train Acc=95.22%, Val Acc=95.53%, F1=95.46%, Macro F1=79.12%
# Epoch 14: Train Acc=95.40%, Val Acc=95.39%, F1=95.31%, Macro F1=79.12%
# Epoch 15: Train Acc=95.62%, Val Acc=95.79%, F1=95.72%, Macro F1=79.24%
# Epoch 16: Train Acc=95.81%, Val Acc=95.89%, F1=95.83%, Macro F1=79.45%
# Epoch 17: Train Acc=95.88%, Val Acc=95.85%, F1=95.79%, Macro F1=79.62%
# Epoch 18: Train Acc=96.00%, Val Acc=95.86%, F1=95.80%, Macro F1=79.54%
# Epoch 19: Train Acc=96.07%, Val Acc=96.01%, F1=95.94%, Macro F1=79.73%
# Epoch 20: Train Acc=96.18%, Val Acc=96.14%, F1=96.07%, Macro F1=79.77%
# Epoch 21: Train Acc=96.23%, Val Acc=96.37%, F1=96.30%, Macro F1=80.04%
# Epoch 22: Train Acc=96.26%, Val Acc=96.19%, F1=96.14%, Macro F1=80.10%
# Epoch 23: Train Acc=96.29%, Val Acc=96.26%, F1=96.21%, Macro F1=80.01%
# Epoch 24: Train Acc=96.33%, Val Acc=96.41%, F1=96.35%, Macro F1=80.14%
# Epoch 25: Train Acc=96.40%, Val Acc=96.43%, F1=96.38%, Macro F1=80.21%
# Epoch 26: Train Acc=96.45%, Val Acc=96.49%, F1=96.43%, Macro F1=80.20%
# Epoch 27: Train Acc=96.51%, Val Acc=96.43%, F1=96.37%, Macro F1=80.33%
# Epoch 28: Train Acc=96.56%, Val Acc=96.60%, F1=96.54%, Macro F1=80.48%
# Epoch 29: Train Acc=96.58%, Val Acc=96.33%, F1=96.27%, Macro F1=79.96%
# Epoch 30: Train Acc=96.63%, Val Acc=96.50%, F1=96.44%, Macro F1=80.27%
# Epoch 31: Train Acc=96.66%, Val Acc=96.52%, F1=96.47%, Macro F1=80.24%
# Epoch 32: Train Acc=96.70%, Val Acc=96.74%, F1=96.70%, Macro F1=80.77%
# Epoch 33: Train Acc=96.77%, Val Acc=96.69%, F1=96.64%, Macro F1=80.73%
# Epoch 34: Train Acc=96.77%, Val Acc=96.64%, F1=96.59%, Macro F1=80.84%
# Epoch 35: Train Acc=96.85%, Val Acc=96.76%, F1=96.71%, Macro F1=81.19%
# Epoch 36: Train Acc=96.83%, Val Acc=96.73%, F1=96.67%, Macro F1=80.70%
# Epoch 37: Train Acc=96.89%, Val Acc=96.78%, F1=96.74%, Macro F1=81.14%
# Epoch 38: Train Acc=96.90%, Val Acc=96.81%, F1=96.76%, Macro F1=81.24%
# Epoch 39: Train Acc=96.95%, Val Acc=96.95%, F1=96.90%, Macro F1=81.39%
# Epoch 40: Train Acc=96.96%, Val Acc=97.02%, F1=96.98%, Macro F1=81.50%
# Epoch 41: Train Acc=96.99%, Val Acc=96.72%, F1=96.64%, Macro F1=80.18%
# Epoch 42: Train Acc=97.00%, Val Acc=97.03%, F1=96.98%, Macro F1=81.41%
# Epoch 43: Train Acc=97.03%, Val Acc=96.90%, F1=96.84%, Macro F1=80.93%
# Epoch 44: Train Acc=97.04%, Val Acc=96.95%, F1=96.90%, Macro F1=81.59%
# Epoch 45: Train Acc=97.01%, Val Acc=96.89%, F1=96.85%, Macro F1=81.57%
# Epoch 46: Train Acc=97.07%, Val Acc=97.06%, F1=97.01%, Macro F1=81.55%
# Epoch 47: Train Acc=97.06%, Val Acc=96.78%, F1=96.72%, Macro F1=80.91%
# Epoch 48: Train Acc=97.11%, Val Acc=96.90%, F1=96.86%, Macro F1=81.31%
# Epoch 49: Train Acc=97.11%, Val Acc=97.03%, F1=96.97%, Macro F1=81.25%
# Epoch 50: Train Acc=97.08%, Val Acc=96.98%, F1=96.92%, Macro F1=81.18%
# Epoch 51: Train Acc=97.13%, Val Acc=96.94%, F1=96.89%, Macro F1=81.31%
# Epoch 52: Train Acc=97.16%, Val Acc=96.97%, F1=96.92%, Macro F1=81.44%
# Epoch 53: Train Acc=97.21%, Val Acc=96.86%, F1=96.78%, Macro F1=80.50%
# Epoch 54: Train Acc=97.23%, Val Acc=96.65%, F1=96.61%, Macro F1=80.93%
# Epoch 55: Train Acc=97.20%, Val Acc=97.09%, F1=97.05%, Macro F1=81.65%
# Epoch 56: Train Acc=97.22%, Val Acc=97.13%, F1=97.09%, Macro F1=81.73%
# Epoch 57: Train Acc=97.20%, Val Acc=97.04%, F1=97.00%, Macro F1=81.65%
# Epoch 58: Train Acc=97.27%, Val Acc=97.01%, F1=96.96%, Macro F1=81.20%
# Epoch 59: Train Acc=97.23%, Val Acc=96.96%, F1=96.91%, Macro F1=81.12%
# Epoch 60: Train Acc=97.26%, Val Acc=97.06%, F1=97.01%, Macro F1=81.10%
# Epoch 61: Train Acc=97.29%, Val Acc=97.23%, F1=97.19%, Macro F1=81.92%
# Epoch 62: Train Acc=97.31%, Val Acc=97.08%, F1=97.03%, Macro F1=81.44%
# Epoch 63: Train Acc=97.35%, Val Acc=97.28%, F1=97.24%, Macro F1=81.85%
# Epoch 64: Train Acc=97.35%, Val Acc=97.13%, F1=97.09%, Macro F1=81.69%
# Epoch 65: Train Acc=97.40%, Val Acc=97.32%, F1=97.29%, Macro F1=82.12%
# Epoch 66: Train Acc=97.42%, Val Acc=97.41%, F1=97.37%, Macro F1=82.16%
# Epoch 67: Train Acc=97.49%, Val Acc=97.45%, F1=97.41%, Macro F1=82.25%
# Epoch 68: Train Acc=97.46%, Val Acc=97.42%, F1=97.38%, Macro F1=82.05%
# Epoch 69: Train Acc=97.48%, Val Acc=97.42%, F1=97.38%, Macro F1=82.19%
# Epoch 70: Train Acc=97.54%, Val Acc=97.33%, F1=97.29%, Macro F1=82.05%
# Epoch 71: Train Acc=97.52%, Val Acc=97.16%, F1=97.13%, Macro F1=81.75%
# Epoch 72: Train Acc=97.58%, Val Acc=97.50%, F1=97.47%, Macro F1=82.36%
# Epoch 73: Train Acc=97.58%, Val Acc=97.38%, F1=97.34%, Macro F1=82.08%
# Epoch 74: Train Acc=97.59%, Val Acc=97.51%, F1=97.47%, Macro F1=82.16%
# Epoch 75: Train Acc=97.61%, Val Acc=97.36%, F1=97.30%, Macro F1=81.69%
# Epoch 76: Train Acc=97.62%, Val Acc=97.59%, F1=97.56%, Macro F1=82.62%
# Epoch 77: Train Acc=97.60%, Val Acc=97.50%, F1=97.46%, Macro F1=82.26%
# Epoch 78: Train Acc=97.67%, Val Acc=97.44%, F1=97.41%, Macro F1=82.41%
# Epoch 79: Train Acc=97.67%, Val Acc=97.36%, F1=97.32%, Macro F1=81.95%
# Epoch 80: Train Acc=97.70%, Val Acc=97.62%, F1=97.59%, Macro F1=82.62%
# Epoch 81: Train Acc=97.66%, Val Acc=97.52%, F1=97.48%, Macro F1=82.34%
# Epoch 82: Train Acc=97.72%, Val Acc=97.57%, F1=97.54%, Macro F1=82.32%
# Epoch 83: Train Acc=97.78%, Val Acc=97.69%, F1=97.65%, Macro F1=82.62%
# Epoch 84: Train Acc=97.74%, Val Acc=97.70%, F1=97.67%, Macro F1=82.56%
# Epoch 85: Train Acc=97.74%, Val Acc=97.57%, F1=97.55%, Macro F1=85.34%
# Epoch 86: Train Acc=97.76%, Val Acc=97.73%, F1=97.70%, Macro F1=82.76%
# Epoch 87: Train Acc=97.78%, Val Acc=97.82%, F1=97.80%, Macro F1=85.85%
# Epoch 88: Train Acc=97.80%, Val Acc=97.70%, F1=97.66%, Macro F1=82.71%
# Epoch 89: Train Acc=97.83%, Val Acc=97.76%, F1=97.73%, Macro F1=82.99%
# Epoch 90: Train Acc=97.88%, Val Acc=97.67%, F1=97.64%, Macro F1=82.78%
# Epoch 91: Train Acc=97.86%, Val Acc=97.70%, F1=97.66%, Macro F1=82.59%
# Epoch 92: Train Acc=97.87%, Val Acc=97.97%, F1=97.94%, Macro F1=83.27%
# Epoch 93: Train Acc=97.91%, Val Acc=97.91%, F1=97.89%, Macro F1=88.54%
# Epoch 94: Train Acc=97.94%, Val Acc=97.85%, F1=97.82%, Macro F1=86.09%
# Epoch 95: Train Acc=97.97%, Val Acc=97.77%, F1=97.74%, Macro F1=83.38%
# Epoch 96: Train Acc=97.97%, Val Acc=97.83%, F1=97.81%, Macro F1=86.18%
# Epoch 97: Train Acc=98.01%, Val Acc=97.80%, F1=97.79%, Macro F1=90.78%
# Epoch 98: Train Acc=98.06%, Val Acc=98.03%, F1=98.02%, Macro F1=90.97%
# Epoch 99: Train Acc=98.06%, Val Acc=98.02%, F1=98.00%, Macro F1=90.46%
# Epoch 100: Train Acc=98.12%, Val Acc=97.87%, F1=97.84%, Macro F1=86.51%
# Epoch 101: Train Acc=98.12%, Val Acc=98.13%, F1=98.11%, Macro F1=86.84%
# Epoch 102: Train Acc=98.11%, Val Acc=98.00%, F1=97.98%, Macro F1=90.70%
# Epoch 103: Train Acc=98.12%, Val Acc=98.13%, F1=98.11%, Macro F1=89.17%
# Epoch 104: Train Acc=98.15%, Val Acc=98.08%, F1=98.05%, Macro F1=86.84%
# Epoch 105: Train Acc=98.17%, Val Acc=97.98%, F1=97.96%, Macro F1=88.86%
# Epoch 106: Train Acc=98.16%, Val Acc=98.01%, F1=98.00%, Macro F1=90.77%
# Epoch 107: Train Acc=98.19%, Val Acc=98.17%, F1=98.16%, Macro F1=91.15%
# Epoch 108: Train Acc=98.21%, Val Acc=98.19%, F1=98.17%, Macro F1=89.03%
# Epoch 109: Train Acc=98.16%, Val Acc=98.23%, F1=98.22%, Macro F1=91.17%
# Epoch 110: Train Acc=98.19%, Val Acc=98.18%, F1=98.16%, Macro F1=89.10%
# Epoch 111: Train Acc=98.19%, Val Acc=98.07%, F1=98.06%, Macro F1=89.09%
# Epoch 112: Train Acc=98.21%, Val Acc=98.11%, F1=98.08%, Macro F1=86.85%
# Epoch 113: Train Acc=98.23%, Val Acc=98.08%, F1=98.06%, Macro F1=86.59%
# Epoch 114: Train Acc=98.25%, Val Acc=98.27%, F1=98.25%, Macro F1=89.09%
# Epoch 115: Train Acc=98.23%, Val Acc=98.23%, F1=98.22%, Macro F1=91.15%
# Epoch 116: Train Acc=98.22%, Val Acc=98.15%, F1=98.13%, Macro F1=89.11%
# Epoch 117: Train Acc=98.25%, Val Acc=98.23%, F1=98.20%, Macro F1=86.90%
# Epoch 118: Train Acc=98.28%, Val Acc=98.26%, F1=98.24%, Macro F1=86.95%
# Epoch 119: Train Acc=98.25%, Val Acc=98.34%, F1=98.32%, Macro F1=89.30%
# Epoch 120: Train Acc=98.27%, Val Acc=97.87%, F1=97.86%, Macro F1=88.96%
# Epoch 121: Train Acc=98.29%, Val Acc=98.34%, F1=98.33%, Macro F1=91.38%
# Epoch 122: Train Acc=98.29%, Val Acc=98.38%, F1=98.37%, Macro F1=91.34%
# Epoch 123: Train Acc=98.30%, Val Acc=98.19%, F1=98.17%, Macro F1=86.72%
# Epoch 124: Train Acc=98.30%, Val Acc=98.39%, F1=98.37%, Macro F1=89.35%
# Epoch 125: Train Acc=98.30%, Val Acc=98.30%, F1=98.29%, Macro F1=91.24%
# Epoch 126: Train Acc=98.30%, Val Acc=98.06%, F1=98.05%, Macro F1=91.00%
# Epoch 127: Train Acc=98.31%, Val Acc=98.34%, F1=98.33%, Macro F1=89.33%
# Epoch 128: Train Acc=98.35%, Val Acc=98.15%, F1=98.14%, Macro F1=91.13%
# Epoch 129: Train Acc=98.34%, Val Acc=98.06%, F1=98.04%, Macro F1=86.94%
# Epoch 130: Train Acc=98.34%, Val Acc=98.34%, F1=98.33%, Macro F1=91.28%
# Epoch 131: Train Acc=98.35%, Val Acc=98.39%, F1=98.38%, Macro F1=91.29%
# Epoch 132: Train Acc=98.36%, Val Acc=98.40%, F1=98.38%, Macro F1=89.43%
# Epoch 133: Train Acc=98.36%, Val Acc=98.19%, F1=98.17%, Macro F1=86.76%
# Epoch 134: Train Acc=98.33%, Val Acc=98.34%, F1=98.33%, Macro F1=91.30%
# Epoch 135: Train Acc=98.39%, Val Acc=98.25%, F1=98.22%, Macro F1=86.98%
# Epoch 136: Train Acc=98.37%, Val Acc=98.38%, F1=98.37%, Macro F1=91.34%
# Epoch 137: Train Acc=98.38%, Val Acc=98.43%, F1=98.42%, Macro F1=91.47%
# Epoch 138: Train Acc=98.38%, Val Acc=98.21%, F1=98.20%, Macro F1=91.32%
# Epoch 139: Train Acc=98.35%, Val Acc=98.26%, F1=98.24%, Macro F1=91.22%
# Epoch 140: Train Acc=98.39%, Val Acc=98.46%, F1=98.44%, Macro F1=89.42%
# Epoch 141: Train Acc=98.41%, Val Acc=98.33%, F1=98.32%, Macro F1=91.33%
# Epoch 142: Train Acc=98.41%, Val Acc=98.32%, F1=98.30%, Macro F1=86.92%
# Epoch 143: Train Acc=98.38%, Val Acc=98.28%, F1=98.25%, Macro F1=86.93%
# Epoch 144: Train Acc=98.41%, Val Acc=98.42%, F1=98.41%, Macro F1=91.37%
# Epoch 145: Train Acc=98.40%, Val Acc=98.26%, F1=98.25%, Macro F1=91.26%
# Epoch 146: Train Acc=98.39%, Val Acc=98.45%, F1=98.43%, Macro F1=91.35%
# Epoch 147: Train Acc=98.43%, Val Acc=98.20%, F1=98.18%, Macro F1=86.98%
# Epoch 148: Train Acc=98.40%, Val Acc=98.47%, F1=98.46%, Macro F1=91.41%
# Epoch 149: Train Acc=98.42%, Val Acc=98.41%, F1=98.40%, Macro F1=89.37%
# Epoch 150: Train Acc=98.42%, Val Acc=98.39%, F1=98.38%, Macro F1=91.35%
# Epoch 151: Train Acc=98.42%, Val Acc=98.40%, F1=98.39%, Macro F1=91.41%
# Epoch 152: Train Acc=98.41%, Val Acc=98.48%, F1=98.47%, Macro F1=91.39%
# Epoch 153: Train Acc=98.38%, Val Acc=98.41%, F1=98.40%, Macro F1=91.28%
# Epoch 154: Train Acc=98.43%, Val Acc=98.36%, F1=98.34%, Macro F1=87.09%
# Epoch 155: Train Acc=98.43%, Val Acc=98.30%, F1=98.27%, Macro F1=86.96%
# Epoch 156: Train Acc=98.45%, Val Acc=98.33%, F1=98.31%, Macro F1=89.33%
# Epoch 157: Train Acc=98.45%, Val Acc=98.41%, F1=98.39%, Macro F1=91.43%
# Epoch 158: Train Acc=98.41%, Val Acc=98.33%, F1=98.32%, Macro F1=91.33%
# Epoch 159: Train Acc=98.44%, Val Acc=98.26%, F1=98.25%, Macro F1=89.42%
# Epoch 160: Train Acc=98.45%, Val Acc=98.47%, F1=98.45%, Macro F1=91.40%
# Epoch 161: Train Acc=98.43%, Val Acc=98.45%, F1=98.44%, Macro F1=91.48%
# Epoch 162: Train Acc=98.44%, Val Acc=98.38%, F1=98.36%, Macro F1=87.12%
# Epoch 163: Train Acc=98.47%, Val Acc=98.31%, F1=98.30%, Macro F1=91.34%
# Epoch 164: Train Acc=98.44%, Val Acc=98.51%, F1=98.50%, Macro F1=91.52%
# Epoch 165: Train Acc=98.43%, Val Acc=98.40%, F1=98.39%, Macro F1=91.37%
# Epoch 166: Train Acc=98.42%, Val Acc=98.43%, F1=98.41%, Macro F1=91.39%
# Epoch 167: Train Acc=98.43%, Val Acc=98.45%, F1=98.43%, Macro F1=91.54%
# Epoch 168: Train Acc=98.43%, Val Acc=98.41%, F1=98.40%, Macro F1=91.40%
# Epoch 169: Train Acc=98.48%, Val Acc=98.47%, F1=98.46%, Macro F1=91.43%
# Epoch 170: Train Acc=98.46%, Val Acc=98.48%, F1=98.47%, Macro F1=91.48%
# Epoch 171: Train Acc=98.47%, Val Acc=98.44%, F1=98.42%, Macro F1=89.41%
# Epoch 172: Train Acc=98.44%, Val Acc=98.32%, F1=98.31%, Macro F1=91.34%
# Epoch 173: Train Acc=98.48%, Val Acc=98.47%, F1=98.44%, Macro F1=87.29%
# Epoch 174: Train Acc=98.50%, Val Acc=98.45%, F1=98.43%, Macro F1=91.48%
# Epoch 175: Train Acc=98.43%, Val Acc=98.34%, F1=98.33%, Macro F1=91.37%
# Epoch 176: Train Acc=98.45%, Val Acc=98.36%, F1=98.34%, Macro F1=89.49%
# Epoch 177: Train Acc=98.45%, Val Acc=98.39%, F1=98.38%, Macro F1=91.45%
# Epoch 178: Train Acc=98.44%, Val Acc=98.41%, F1=98.40%, Macro F1=91.49%
# Epoch 179: Train Acc=98.47%, Val Acc=98.28%, F1=98.27%, Macro F1=91.33%
# Epoch 180: Train Acc=98.46%, Val Acc=98.44%, F1=98.43%, Macro F1=91.42%
# Epoch 181: Train Acc=98.43%, Val Acc=98.45%, F1=98.43%, Macro F1=91.41%
# Epoch 182: Train Acc=98.48%, Val Acc=98.45%, F1=98.44%, Macro F1=91.45%
# Epoch 183: Train Acc=98.46%, Val Acc=98.12%, F1=98.10%, Macro F1=86.93%
# Epoch 184: Train Acc=98.48%, Val Acc=98.08%, F1=98.06%, Macro F1=86.75%
# Epoch 185: Train Acc=98.45%, Val Acc=98.38%, F1=98.36%, Macro F1=87.18%
# Epoch 186: Train Acc=98.48%, Val Acc=98.33%, F1=98.32%, Macro F1=91.37%
# Epoch 187: Train Acc=98.49%, Val Acc=98.49%, F1=98.47%, Macro F1=91.49%
# Epoch 188: Train Acc=98.44%, Val Acc=98.48%, F1=98.47%, Macro F1=91.48%
# Epoch 189: Train Acc=98.45%, Val Acc=98.41%, F1=98.38%, Macro F1=87.17%
# Epoch 190: Train Acc=98.48%, Val Acc=98.43%, F1=98.41%, Macro F1=86.96%
# Epoch 191: Train Acc=98.49%, Val Acc=98.49%, F1=98.48%, Macro F1=91.50%
# Epoch 192: Train Acc=98.50%, Val Acc=98.38%, F1=98.36%, Macro F1=87.20%
# Epoch 193: Train Acc=98.47%, Val Acc=98.41%, F1=98.39%, Macro F1=91.40%
# Epoch 194: Train Acc=98.50%, Val Acc=98.36%, F1=98.35%, Macro F1=89.44%
# Epoch 195: Train Acc=98.48%, Val Acc=98.45%, F1=98.43%, Macro F1=91.42%
# Epoch 196: Train Acc=98.50%, Val Acc=98.41%, F1=98.40%, Macro F1=91.36%
# Epoch 197: Train Acc=98.46%, Val Acc=98.37%, F1=98.35%, Macro F1=87.08%
# Epoch 198: Train Acc=98.49%, Val Acc=98.43%, F1=98.40%, Macro F1=87.19%
# Epoch 199: Train Acc=98.48%, Val Acc=98.42%, F1=98.40%, Macro F1=87.03%
# Epoch 200: Train Acc=98.49%, Val Acc=98.40%, F1=98.39%, Macro F1=91.45%
#
# Cross-Validation Results:
# Avg Validation Accuracy: 98.25%
# Avg Weighted F1-score: 98.24%
# Avg Macro F1-score: 86.32%
# Avg Validation Loss: 0.053203

# %%
loss_fn = nn.CrossEntropyLoss()
#loss_fn = FocalLoss(alpha=0.5, gamma = 1)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001,weight_decay=1e-4) #using L2 regularization

epochs = 200
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!") #wider network
# Out:
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045790, F1-score: 98.42%, Macro_F1-Score:  89.89%
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045880, F1-score: 98.37%, Macro_F1-Score:  93.77%
#
# Epoch 3
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045750, F1-score: 98.38%, Macro_F1-Score:  89.94%
#
# Epoch 4
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044884, F1-score: 98.41%, Macro_F1-Score:  90.00%
#
# Epoch 5
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.046615, F1-score: 98.18%, Macro_F1-Score:  89.83%
#
# Epoch 6
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045204, F1-score: 98.38%, Macro_F1-Score:  90.04%
#
# Epoch 7
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.047902, F1-score: 98.20%, Macro_F1-Score:  89.82%
#
# Epoch 8
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044106, F1-score: 98.40%, Macro_F1-Score:  90.09%
#
# Epoch 9
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045865, F1-score: 98.38%, Macro_F1-Score:  89.78%
#
# Epoch 10
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043742, F1-score: 98.42%, Macro_F1-Score:  89.98%
#
# Epoch 11
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044112, F1-score: 98.42%, Macro_F1-Score:  89.96%
#
# Epoch 12
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043409, F1-score: 98.44%, Macro_F1-Score:  89.98%
#
# Epoch 13
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.047049, F1-score: 98.26%, Macro_F1-Score:  89.82%
#
# Epoch 14
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044520, F1-score: 98.43%, Macro_F1-Score:  93.81%
#
# Epoch 15
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045017, F1-score: 98.35%, Macro_F1-Score:  89.71%
#
# Epoch 16
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.045932, F1-score: 98.24%, Macro_F1-Score:  89.68%
#
# Epoch 17
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044650, F1-score: 98.41%, Macro_F1-Score:  89.88%
#
# Epoch 18
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044308, F1-score: 98.43%, Macro_F1-Score:  89.92%
#
# Epoch 19
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044221, F1-score: 98.43%, Macro_F1-Score:  89.92%
#
# Epoch 20
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043762, F1-score: 98.40%, Macro_F1-Score:  89.88%
#
# Epoch 21
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.043459, F1-score: 98.46%, Macro_F1-Score:  90.08%
#
# Epoch 22
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045376, F1-score: 98.36%, Macro_F1-Score:  89.79%
#
# Epoch 23
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.045674, F1-score: 98.32%, Macro_F1-Score:  89.80%
#
# Epoch 24
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045566, F1-score: 98.38%, Macro_F1-Score:  89.85%
#
# Epoch 25
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043911, F1-score: 98.35%, Macro_F1-Score:  89.91%
#
# Epoch 26
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.046268, F1-score: 98.21%, Macro_F1-Score:  89.62%
#
# Epoch 27
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.047554, F1-score: 98.21%, Macro_F1-Score:  89.68%
#
# Epoch 28
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.043274, F1-score: 98.49%, Macro_F1-Score:  90.10%
#
# Epoch 29
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044925, F1-score: 98.37%, Macro_F1-Score:  89.80%
#
# Epoch 30
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044131, F1-score: 98.42%, Macro_F1-Score:  89.98%
#
# Epoch 31
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.046999, F1-score: 98.26%, Macro_F1-Score:  89.82%
#
# Epoch 32
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.044196, F1-score: 98.45%, Macro_F1-Score:  93.79%
#
# Epoch 33
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.048379, F1-score: 98.36%, Macro_F1-Score:  89.76%
#
# Epoch 34
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044348, F1-score: 98.40%, Macro_F1-Score:  89.91%
#
# Epoch 35
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.045666, F1-score: 98.29%, Macro_F1-Score:  89.92%
#
# Epoch 36
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044950, F1-score: 98.39%, Macro_F1-Score:  89.88%
#
# Epoch 37
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.046272, F1-score: 98.28%, Macro_F1-Score:  89.83%
#
# Epoch 38
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042812, F1-score: 98.39%, Macro_F1-Score:  89.94%
#
# Epoch 39
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044867, F1-score: 98.41%, Macro_F1-Score:  89.97%
#
# Epoch 40
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.047587, F1-score: 98.35%, Macro_F1-Score:  89.82%
#
# Epoch 41
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043565, F1-score: 98.36%, Macro_F1-Score:  90.01%
#
# Epoch 42
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.044500, F1-score: 98.31%, Macro_F1-Score:  84.10%
#
# Epoch 43
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.043537, F1-score: 98.46%, Macro_F1-Score:  93.76%
#
# Epoch 44
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045645, F1-score: 98.41%, Macro_F1-Score:  89.90%
#
# Epoch 45
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044530, F1-score: 98.36%, Macro_F1-Score:  89.86%
#
# Epoch 46
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042955, F1-score: 98.43%, Macro_F1-Score:  89.94%
#
# Epoch 47
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043417, F1-score: 98.43%, Macro_F1-Score:  89.94%
#
# Epoch 48
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042624, F1-score: 98.45%, Macro_F1-Score:  90.03%
#
# Epoch 49
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042359, F1-score: 98.42%, Macro_F1-Score:  89.95%
#
# Epoch 50
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044321, F1-score: 98.37%, Macro_F1-Score:  89.86%
#
# Epoch 51
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.043951, F1-score: 98.33%, Macro_F1-Score:  89.86%
#
# Epoch 52
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044419, F1-score: 98.42%, Macro_F1-Score:  89.91%
#
# Epoch 53
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.045236, F1-score: 98.28%, Macro_F1-Score:  89.85%
#
# Epoch 54
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043594, F1-score: 98.37%, Macro_F1-Score:  84.25%
#
# Epoch 55
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044492, F1-score: 98.35%, Macro_F1-Score:  89.83%
#
# Epoch 56
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043836, F1-score: 98.37%, Macro_F1-Score:  89.79%
#
# Epoch 57
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043172, F1-score: 98.43%, Macro_F1-Score:  90.01%
#
# Epoch 58
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.044296, F1-score: 98.46%, Macro_F1-Score:  90.03%
#
# Epoch 59
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044770, F1-score: 98.42%, Macro_F1-Score:  93.81%
#
# Epoch 60
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044708, F1-score: 98.36%, Macro_F1-Score:  89.73%
#
# Epoch 61
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044821, F1-score: 98.38%, Macro_F1-Score:  89.95%
#
# Epoch 62
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044780, F1-score: 98.41%, Macro_F1-Score:  89.89%
#
# Epoch 63
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045711, F1-score: 98.43%, Macro_F1-Score:  89.92%
#
# Epoch 64
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.046093, F1-score: 98.29%, Macro_F1-Score:  89.75%
#
# Epoch 65
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042734, F1-score: 98.41%, Macro_F1-Score:  89.92%
#
# Epoch 66
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.043301, F1-score: 98.33%, Macro_F1-Score:  89.82%
#
# Epoch 67
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043460, F1-score: 98.42%, Macro_F1-Score:  89.93%
#
# Epoch 68
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044468, F1-score: 98.36%, Macro_F1-Score:  89.86%
#
# Epoch 69
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.044681, F1-score: 98.33%, Macro_F1-Score:  93.74%
#
# Epoch 70
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.043048, F1-score: 98.31%, Macro_F1-Score:  84.09%
#
# Epoch 71
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043726, F1-score: 98.41%, Macro_F1-Score:  84.30%
#
# Epoch 72
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043394, F1-score: 98.38%, Macro_F1-Score:  89.90%
#
# Epoch 73
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.044516, F1-score: 98.46%, Macro_F1-Score:  89.95%
#
# Epoch 74
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.043220, F1-score: 98.45%, Macro_F1-Score:  90.02%
#
# Epoch 75
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043884, F1-score: 98.35%, Macro_F1-Score:  89.85%
#
# Epoch 76
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042887, F1-score: 98.42%, Macro_F1-Score:  90.00%
#
# Epoch 77
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.046087, F1-score: 98.20%, Macro_F1-Score:  89.77%
#
# Epoch 78
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042316, F1-score: 98.43%, Macro_F1-Score:  89.93%
#
# Epoch 79
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043334, F1-score: 98.39%, Macro_F1-Score:  89.84%
#
# Epoch 80
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043132, F1-score: 98.42%, Macro_F1-Score:  90.08%
#
# Epoch 81
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043624, F1-score: 98.37%, Macro_F1-Score:  89.89%
#
# Epoch 82
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.048356, F1-score: 98.25%, Macro_F1-Score:  89.84%
#
# Epoch 83
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042801, F1-score: 98.38%, Macro_F1-Score:  89.97%
#
# Epoch 84
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042189, F1-score: 98.42%, Macro_F1-Score:  89.96%
#
# Epoch 85
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042484, F1-score: 98.39%, Macro_F1-Score:  89.99%
#
# Epoch 86
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042639, F1-score: 98.46%, Macro_F1-Score:  90.03%
#
# Epoch 87
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.043079, F1-score: 98.48%, Macro_F1-Score:  89.95%
#
# Epoch 88
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.046138, F1-score: 98.28%, Macro_F1-Score:  89.86%
#
# Epoch 89
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.043986, F1-score: 98.34%, Macro_F1-Score:  89.88%
#
# Epoch 90
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041949, F1-score: 98.46%, Macro_F1-Score:  90.05%
#
# Epoch 91
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042812, F1-score: 98.41%, Macro_F1-Score:  89.94%
#
# Epoch 92
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042015, F1-score: 98.42%, Macro_F1-Score:  89.93%
#
# Epoch 93
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042216, F1-score: 98.43%, Macro_F1-Score:  89.97%
#
# Epoch 94
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043544, F1-score: 98.41%, Macro_F1-Score:  89.89%
#
# Epoch 95
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042460, F1-score: 98.40%, Macro_F1-Score:  89.91%
#
# Epoch 96
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043118, F1-score: 98.35%, Macro_F1-Score:  89.91%
#
# Epoch 97
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.047194, F1-score: 98.29%, Macro_F1-Score:  89.95%
#
# Epoch 98
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043524, F1-score: 98.40%, Macro_F1-Score:  90.04%
#
# Epoch 99
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.046267, F1-score: 98.44%, Macro_F1-Score:  89.96%
#
# Epoch 100
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.044369, F1-score: 98.31%, Macro_F1-Score:  89.76%
#
# Epoch 101
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041414, F1-score: 98.45%, Macro_F1-Score:  90.10%
#
# Epoch 102
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.047052, F1-score: 98.23%, Macro_F1-Score:  89.90%
#
# Epoch 103
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.045329, F1-score: 98.38%, Macro_F1-Score:  90.01%
#
# Epoch 104
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042299, F1-score: 98.47%, Macro_F1-Score:  90.03%
#
# Epoch 105
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044852, F1-score: 98.39%, Macro_F1-Score:  93.78%
#
# Epoch 106
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042868, F1-score: 98.41%, Macro_F1-Score:  89.83%
#
# Epoch 107
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.044883, F1-score: 98.34%, Macro_F1-Score:  89.76%
#
# Epoch 108
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041581, F1-score: 98.49%, Macro_F1-Score:  90.11%
#
# Epoch 109
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042292, F1-score: 98.46%, Macro_F1-Score:  93.80%
#
# Epoch 110
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042045, F1-score: 98.42%, Macro_F1-Score:  89.95%
#
# Epoch 111
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042389, F1-score: 98.38%, Macro_F1-Score:  89.81%
#
# Epoch 112
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.044471, F1-score: 98.17%, Macro_F1-Score:  89.74%
#
# Epoch 113
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041924, F1-score: 98.46%, Macro_F1-Score:  89.88%
#
# Epoch 114
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042448, F1-score: 98.44%, Macro_F1-Score:  89.89%
#
# Epoch 115
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041347, F1-score: 98.48%, Macro_F1-Score:  90.08%
#
# Epoch 116
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042248, F1-score: 98.48%, Macro_F1-Score:  89.98%
#
# Epoch 117
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041536, F1-score: 98.45%, Macro_F1-Score:  93.90%
#
# Epoch 118
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041702, F1-score: 98.47%, Macro_F1-Score:  90.00%
#
# Epoch 119
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.043913, F1-score: 98.47%, Macro_F1-Score:  89.92%
#
# Epoch 120
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.040951, F1-score: 98.50%, Macro_F1-Score:  90.06%
#
# Epoch 121
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.043116, F1-score: 98.44%, Macro_F1-Score:  89.94%
#
# Epoch 122
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044870, F1-score: 98.40%, Macro_F1-Score:  89.93%
#
# Epoch 123
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.044075, F1-score: 98.34%, Macro_F1-Score:  89.96%
#
# Epoch 124
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043577, F1-score: 98.43%, Macro_F1-Score:  90.04%
#
# Epoch 125
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043224, F1-score: 98.41%, Macro_F1-Score:  90.07%
#
# Epoch 126
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042574, F1-score: 98.44%, Macro_F1-Score:  90.04%
#
# Epoch 127
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043215, F1-score: 98.36%, Macro_F1-Score:  90.02%
#
# Epoch 128
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.043388, F1-score: 98.32%, Macro_F1-Score:  89.77%
#
# Epoch 129
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042308, F1-score: 98.37%, Macro_F1-Score:  89.84%
#
# Epoch 130
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042804, F1-score: 98.42%, Macro_F1-Score:  89.97%
#
# Epoch 131
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044820, F1-score: 98.38%, Macro_F1-Score:  89.95%
#
# Epoch 132
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041367, F1-score: 98.46%, Macro_F1-Score:  90.06%
#
# Epoch 133
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041792, F1-score: 98.43%, Macro_F1-Score:  90.07%
#
# Epoch 134
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042084, F1-score: 98.43%, Macro_F1-Score:  89.91%
#
# Epoch 135
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042198, F1-score: 98.47%, Macro_F1-Score:  90.00%
#
# Epoch 136
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042976, F1-score: 98.44%, Macro_F1-Score:  89.92%
#
# Epoch 137
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.040756, F1-score: 98.47%, Macro_F1-Score:  90.06%
#
# Epoch 138
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043433, F1-score: 98.41%, Macro_F1-Score:  90.00%
#
# Epoch 139
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042558, F1-score: 98.37%, Macro_F1-Score:  89.85%
#
# Epoch 140
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042070, F1-score: 98.40%, Macro_F1-Score:  89.90%
#
# Epoch 141
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.042722, F1-score: 98.32%, Macro_F1-Score:  89.81%
#
# Epoch 142
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043491, F1-score: 98.40%, Macro_F1-Score:  89.94%
#
# Epoch 143
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043590, F1-score: 98.39%, Macro_F1-Score:  93.76%
#
# Epoch 144
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042421, F1-score: 98.41%, Macro_F1-Score:  89.99%
#
# Epoch 145
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042001, F1-score: 98.47%, Macro_F1-Score:  90.01%
#
# Epoch 146
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041369, F1-score: 98.43%, Macro_F1-Score:  89.88%
#
# Epoch 147
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042291, F1-score: 98.41%, Macro_F1-Score:  93.81%
#
# Epoch 148
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041473, F1-score: 98.42%, Macro_F1-Score:  90.01%
#
# Epoch 149
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042201, F1-score: 98.42%, Macro_F1-Score:  89.88%
#
# Epoch 150
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.045571, F1-score: 98.32%, Macro_F1-Score:  89.81%
#
# Epoch 151
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042511, F1-score: 98.43%, Macro_F1-Score:  90.08%
#
# Epoch 152
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041588, F1-score: 98.36%, Macro_F1-Score:  89.82%
#
# Epoch 153
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.043471, F1-score: 98.32%, Macro_F1-Score:  89.99%
#
# Epoch 154
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043123, F1-score: 98.42%, Macro_F1-Score:  89.88%
#
# Epoch 155
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043992, F1-score: 98.35%, Macro_F1-Score:  89.81%
#
# Epoch 156
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042138, F1-score: 98.46%, Macro_F1-Score:  90.07%
#
# Epoch 157
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041184, F1-score: 98.46%, Macro_F1-Score:  93.87%
#
# Epoch 158
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042117, F1-score: 98.51%, Macro_F1-Score:  90.14%
#
# Epoch 159
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043563, F1-score: 98.41%, Macro_F1-Score:  93.85%
#
# Epoch 160
# -------------------------------
# Test Error:
#  Accuracy: 98.2%, Avg loss: 0.045602, F1-score: 98.25%, Macro_F1-Score:  93.61%
#
# Epoch 161
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042531, F1-score: 98.46%, Macro_F1-Score:  90.05%
#
# Epoch 162
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043434, F1-score: 98.36%, Macro_F1-Score:  89.89%
#
# Epoch 163
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042284, F1-score: 98.45%, Macro_F1-Score:  93.86%
#
# Epoch 164
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042052, F1-score: 98.42%, Macro_F1-Score:  89.84%
#
# Epoch 165
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042436, F1-score: 98.47%, Macro_F1-Score:  90.08%
#
# Epoch 166
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042278, F1-score: 98.36%, Macro_F1-Score:  93.76%
#
# Epoch 167
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043977, F1-score: 98.40%, Macro_F1-Score:  90.08%
#
# Epoch 168
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043744, F1-score: 98.38%, Macro_F1-Score:  89.80%
#
# Epoch 169
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041913, F1-score: 98.49%, Macro_F1-Score:  90.02%
#
# Epoch 170
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042506, F1-score: 98.43%, Macro_F1-Score:  90.03%
#
# Epoch 171
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.043729, F1-score: 98.40%, Macro_F1-Score:  93.81%
#
# Epoch 172
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041735, F1-score: 98.43%, Macro_F1-Score:  93.75%
#
# Epoch 173
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041578, F1-score: 98.41%, Macro_F1-Score:  89.92%
#
# Epoch 174
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042868, F1-score: 98.41%, Macro_F1-Score:  89.99%
#
# Epoch 175
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042356, F1-score: 98.47%, Macro_F1-Score:  90.16%
#
# Epoch 176
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041296, F1-score: 98.47%, Macro_F1-Score:  90.08%
#
# Epoch 177
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042531, F1-score: 98.49%, Macro_F1-Score:  93.82%
#
# Epoch 178
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041127, F1-score: 98.53%, Macro_F1-Score:  93.81%
#
# Epoch 179
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041784, F1-score: 98.49%, Macro_F1-Score:  93.86%
#
# Epoch 180
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.040926, F1-score: 98.49%, Macro_F1-Score:  90.06%
#
# Epoch 181
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.040991, F1-score: 98.53%, Macro_F1-Score:  93.93%
#
# Epoch 182
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041353, F1-score: 98.43%, Macro_F1-Score:  89.95%
#
# Epoch 183
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041039, F1-score: 98.46%, Macro_F1-Score:  93.90%
#
# Epoch 184
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041246, F1-score: 98.51%, Macro_F1-Score:  96.63%
#
# Epoch 185
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.044600, F1-score: 98.36%, Macro_F1-Score:  96.36%
#
# Epoch 186
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041513, F1-score: 98.47%, Macro_F1-Score:  93.81%
#
# Epoch 187
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.044261, F1-score: 98.32%, Macro_F1-Score:  96.37%
#
# Epoch 188
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041115, F1-score: 98.45%, Macro_F1-Score:  96.44%
#
# Epoch 189
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042134, F1-score: 98.43%, Macro_F1-Score:  96.61%
#
# Epoch 190
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041351, F1-score: 98.48%, Macro_F1-Score:  96.56%
#
# Epoch 191
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.045802, F1-score: 98.29%, Macro_F1-Score:  96.49%
#
# Epoch 192
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.045141, F1-score: 98.27%, Macro_F1-Score:  89.77%
#
# Epoch 193
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.041510, F1-score: 98.44%, Macro_F1-Score:  93.80%
#
# Epoch 194
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.047291, F1-score: 98.27%, Macro_F1-Score:  93.67%
#
# Epoch 195
# -------------------------------
# Test Error:
#  Accuracy: 98.3%, Avg loss: 0.042160, F1-score: 98.33%, Macro_F1-Score:  93.72%
#
# Epoch 196
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042774, F1-score: 98.35%, Macro_F1-Score:  96.44%
#
# Epoch 197
# -------------------------------
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.042982, F1-score: 98.42%, Macro_F1-Score:  96.48%
#
# Epoch 198
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041525, F1-score: 98.46%, Macro_F1-Score:  96.49%
#
# Epoch 199
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.042600, F1-score: 98.45%, Macro_F1-Score:  93.82%
#
# Epoch 200
# -------------------------------
# Test Error:
#  Accuracy: 98.5%, Avg loss: 0.041589, F1-score: 98.46%, Macro_F1-Score:  93.79%
#
# Done!

# %%
#noise scale is low (0.2)
plt.plot(loss_over_train, label="Training Loss")
plt.plot(loss_over_test, label="Testing Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Testing Loss over Epochs")
plt.legend()
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
import pickle
import pandas as pd

# Load the LabelEncoder object from the file
with open(r"C:\Users\TESTER\OneDrive\Ambiente de Trabalho\Thesis Folder\Data After Preprocess\label_encoder.pkl", "rb") as f:
    label_encoder = pickle.load(f)


# Now you can use the label_encoder object in the second notebook
original_class_labels = label_encoder.classes_
# Out:
# c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.6.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
original_labels_test = label_encoder.inverse_transform(test_data_y.values.flatten())

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Ensure the model is in evaluation mode
model.eval()

with torch.no_grad():
    y_pred = model(test_X_tensor)  # Forward pass
    y_pred = torch.argmax(y_pred, dim=1)  # Get class predictions

# Convert tensors to NumPy arrays for sklearn
y_pred = y_pred.cpu().numpy()
y_true = test_Y_tensor.cpu().numpy()

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Get class labels from the LabelEncoder
class_labels = label_encoder.classes_

fig, ax = plt.subplots(figsize=(12, 8))  #Creates both a figure and an ax

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap='Blues', values_format='d', ax=ax)

# Rotate axis labels for better visibility
plt.xticks(rotation=45)
plt.yticks(rotation=45)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 25
#      22 fig, ax = plt.subplots(figsize=(12, 8))  #Creates both a figure and an ax
#      24 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
# ---> 25 disp.plot(cmap='Blues', values_format='d', ax=ax)
#      27 # Rotate axis labels for better visibility
#      28 plt.xticks(rotation=45)
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py:185, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     183 if colorbar:
#     184     fig.colorbar(self.im_, ax=ax)
# --> 185 ax.set(
#     186     xticks=np.arange(n_classes),
#     187     yticks=np.arange(n_classes),
#     188     xticklabels=display_labels,
#     189     yticklabels=display_labels,
#     190     ylabel="True label",
#     191     xlabel="Predicted label",
#     192 )
#     194 ax.set_ylim((n_classes - 0.5, -0.5))
#     195 plt.setp(ax.get_xticklabels(), rotation=xticks_rotation)
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:1209, in Artist._update_props(self, props, errfmt)
#    1205             if not callable(func):
#    1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
# -> 1209             ret.append(func(v))
#    1210 if ret:
#    1211     self.pchanged()
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:2117, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2113 elif isinstance(locator, mticker.FixedLocator):
#    2114     # Passing [] as a list of labels is often used as a way to
#    2115     # remove all tick labels, so only error for > 0 labels
#    2116     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2117         raise ValueError(
#    2118             "The number of FixedLocator locations"
#    2119             f" ({len(locator.locs)}), usually from a call to"
#    2120             " set_ticks, does not match"
#    2121             f" the number of labels ({len(labels)}).")
#    2122     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2123     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (7), usually from a call to set_ticks, does not match the number of labels (10).

# %%
import torch.nn.functional as F

with torch.no_grad():
    y_score = F.softmax(model(test_X_tensor), dim=1)

# %%
np.average(y_score.numpy())
# Out:
# 0.10000002

# %%
from sklearn.preprocessing import LabelBinarizer

label_binarizer = LabelBinarizer().fit(train_data_y)
y_onehot_test = label_binarizer.transform(test_labels_encoded)
y_onehot_test.shape  # (n_samples, n_classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 4
#       1 from sklearn.preprocessing import LabelBinarizer
#       3 label_binarizer = LabelBinarizer().fit(train_data_y)
# ----> 4 y_onehot_test = label_binarizer.transform(test_labels_encoded)
#       5 y_onehot_test.shape  # (n_samples, n_classes)
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:363, in LabelBinarizer.transform(self, y)
#     360 if y_is_multilabel and not self.y_type_.startswith("multilabel"):
#     361     raise ValueError("The object was not fitted with multilabel input.")
# --> 363 return label_binarize(
#     364     y,
#     365     classes=self.classes_,
#     366     pos_label=self.pos_label,
#     367     neg_label=self.neg_label,
#     368     sparse_output=self.sparse_output,
#     369 )
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\TESTER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:530, in label_binarize(y, classes, neg_label, pos_label, sparse_output)
#     528 y_type = type_of_target(y)
#     529 if "multioutput" in y_type:
# --> 530     raise ValueError(
#     531         "Multioutput target data is not supported with label binarization"
#     532     )
#     533 if y_type == "unknown":
#     534     raise ValueError("The type of target data is not known")
#
# ValueError: Multioutput target data is not supported with label binarization

# %%
from sklearn.metrics import RocCurveDisplay

display = RocCurveDisplay.from_predictions(
    y_onehot_test.ravel(),
    y_score.ravel(),
    name="micro-average OvR",
    color="darkorange",
    plot_chance_level=True)
_ = display.ax_.set(
    xlabel="False Positive Rate",
    ylabel="True Positive Rate",
    title="Micro-averaged One-vs-Rest\nReceiver Operating Characteristic",
)

# %% [markdown]
# ## Feature Selection using Random Forest
